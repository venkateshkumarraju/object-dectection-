# %% [markdown]
# ### <font style="color:purple">Download the Dataset</font>
#
# **[Download the Vehicle registration plate](https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1)**
#
#
# Download the Vehicle Registration Plate dataset from [here](https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1) and unzip it.
#
# We will have the following directory structure:
#
# ```
# Dataset
# ├── train
# │   └── Vehicle registration plate
# │       └── Label
# └── validation
#     └── Vehicle registration plate
#         └── Label
# ```
#
# Unzipping the file will give you a directory `Dataset`. This directory has two folder `train` and `validation`. Each train and validation folder has `Vehicle registration plate`  folder with `.jpg` images and a folder `Labels`.  `Labels` folder has bounding box data for the images.
#
#
# For example,
# For image: `Dataset/train/Vehicle registration plate/bf4689922cdfd532.jpg`
# Label file is  `Dataset/train/Vehicle registration plate/Label/bf4689922cdfd532.txt`
#
# There are one or more lines in each `.txt` file. Each line represents one bounding box.
# For example,
# ```
# Vehicle registration plate 385.28 445.15 618.24 514.225
# Vehicle registration plate 839.68 266.066462 874.24 289.091462
# ```
#
# We have a single class detection (`Vehicle registration plate detection`) problem. So bounding box details start from the fourth column in each row.
#
# Representation is in `xmin`, `ymin`, `xmax`, and `ymax` format.
#
# **It has `5308` training and `386` validation dataset.**
#
# Data is downloaded from [Open Images Dataset](https://storage.googleapis.com/openimages/web/index.html)

# %% [markdown]
# # <font style="color:blue">Project 3: Object Detection</font>
#
#
# #### Maximum Points: 100
#
# <div>
#     <table>
#         <tr><td><h3>Sr. no.</h3></td> <td><h3>Section</h3></td> <td><h3>Points</h3></td> </tr>
#         <tr><td><h3>1</h3></td> <td><h3>Plot Ground Truth Bounding Boxes</h3></td> <td><h3>20</h3></td> </tr>
#         <tr><td><h3>2</h3></td> <td><h3>Training</h3></td> <td><h3>25</h3></td> </tr>
#         <tr><td><h3>3</h3></td> <td><h3>Inference</h3></td> <td><h3>15</h3></td> </tr>
#         <tr><td><h3>4</h3></td> <td><h3>COCO Detection Evaluation</h3></td> <td><h3>25</h3></td> </tr>
#         <tr><td><h3>5</h3></td> <td><h3>Run Inference on a Video</h3></td> <td><h3>15</h3></td> </tr>
#     </table>
# </div>

# %% [markdown]
# #  <font style="color:green">1. Plot Ground Truth Bounding Boxes [20 Points]</font>
#
# **You have to show three images from validation data with the bounding boxes.**
#
# The plotted images should be similar to the following:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-g1.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-g2.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-g3.png'>

# %%
import os
import glob
import cv2
import matplotlib.pyplot as plt

# Function to read and process each label file
def read_label_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        boxes = []
        for line in lines:
            parts = line.strip().split()
            x_min = float(parts[3])
            y_min = float(parts[4])
            x_max = float(parts[5])
            y_max = float(parts[6])
            boxes.append((x_min, y_min, x_max, y_max))
    return boxes

# Function to draw bounding boxes on an image
def draw_bounding_boxes(image_path, boxes):
    image = cv2.imread(image_path)
    label='reg_plate'
    for (x_min, y_min, x_max, y_max) in boxes:
        cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)
        cv2.putText(image, label, (int(x_min), int(y_min) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return image

# Paths to the validation directories
validation_dir = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate'
label_dir = os.path.join(validation_dir, 'Label')

# Get a list of all image files and their corresponding label files
image_files = glob.glob(os.path.join(validation_dir, '*.jpg'))
label_files = [os.path.join(label_dir, os.path.basename(f).replace('.jpg', '.txt')) for f in image_files]

# Display three images with bounding boxes
plt.figure(figsize=(15, 10))
for i in range(3):
    image_path = image_files[i]
    label_path = label_files[i]
    boxes = read_label_file(label_path)
    image_with_boxes = draw_bounding_boxes(image_path, boxes)
    
    plt.subplot(1, 3, i+1)
    plt.imshow(cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB))
    plt.title(f'Image {i+1}')
    plt.axis('off')

plt.show()

# %%
import os
import shutil

def copy_files(src_dir, dst_dir):
    # Create the destination directory if it doesn't exist
    if not os.path.exists(dst_dir):
        os.makedirs(dst_dir)

    # Walk through the source directory
    for root, dirs, files in os.walk(src_dir):
        for dir_name in dirs:
            src_subdir = os.path.join(root, dir_name)
            dst_subdir = os.path.join(dst_dir, dir_name)
            shutil.copytree(src_subdir, dst_subdir)

# Specify your source and destination directories
src_dataset_dir = '/kaggle/input/object-dectection-num-plate/Dataset'  # Replace with your actual dataset path
dst_copy_dir = '/kaggle/working/datatset'  # Replace with your desired copy destination

# Copy the dataset without label folders
copy_files(os.path.join(src_dataset_dir, 'train'), os.path.join(dst_copy_dir, 'train'))
copy_files(os.path.join(src_dataset_dir, 'validation'), os.path.join(dst_copy_dir, 'validation'))

print("Dataset copied")
# Out:
# Dataset copied

# %%
import os
import glob
import cv2

# Function to read and process each label file
def read_label_file(file_path, image_width, image_height):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        boxes = []
        for line in lines:
            parts = line.strip().split()
            x_min = float(parts[3])
            y_min = float(parts[4])
            x_max = float(parts[5])
            y_max = float(parts[6])

            x_center = ((x_min + x_max) / 2) / image_width
            y_center = ((y_min + y_max) / 2) / image_height
            width = (x_max - x_min) / image_width
            height = (y_max - y_min) / image_height

            boxes.append(f"0 {x_center} {y_center} {width} {height}")
    return boxes

# Paths to the directories
train_images_dir = '/kaggle/working/datatset/train/Vehicle registration plate'
train_labels_dir = '/kaggle/input/object-dectection-num-plate/Dataset/train/Vehicle registration plate/Label'

# Get a list of all image files and their corresponding label files
image_files = glob.glob(os.path.join(train_images_dir, '*.jpg'))
label_files = [os.path.join(train_labels_dir, os.path.basename(f).replace('.jpg', '.txt')) for f in image_files]

for i in range(len(image_files)):
    image_path = image_files[i]
    label_path = label_files[i]
    
    # Get image dimensions
    image = cv2.imread(image_path)
    image_height, image_width, _ = image.shape

    # Create the output directory if it doesn't exist
    output_dir = "/kaggle/working/datatset/train/Vehicle registration plate"
    os.makedirs(output_dir, exist_ok=True)

    # Create the output label file path
    output_label_path = os.path.join(output_dir, os.path.basename(label_path))
    
    boxes = read_label_file(label_path, image_width, image_height)
    
    with open(output_label_path, 'w') as f:
        for box in boxes:
            f.write(box + '\n')

# %%
# Paths to the directories
val_images_dir = '/kaggle/working/datatset/validation/Vehicle registration plate'
val_labels_dir = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate/Label'

# Get a list of all image files and their corresponding label files
image_files = glob.glob(os.path.join(val_images_dir, '*.jpg'))
label_files = [os.path.join(val_labels_dir, os.path.basename(f).replace('.jpg', '.txt')) for f in image_files]

for i in range(len(image_files)):
    image_path = image_files[i]
    label_path = label_files[i]
    
    # Get image dimensions
    image = cv2.imread(image_path)
    image_height, image_width, _ = image.shape

    # Create the output directory if it doesn't exist
    output_dir = "/kaggle/working/datatset/validation/Vehicle registration plate"
    os.makedirs(output_dir, exist_ok=True)

    # Create the output label file path
    output_label_path = os.path.join(output_dir, os.path.basename(label_path))
    
    boxes = read_label_file(label_path, image_width, image_height)
    
    with open(output_label_path, 'w') as f:
        for box in boxes:
            
            f.write(box + '\n')

# %%
import os
import glob

def read_and_print_labels(folder_path):
  """
  Reads and prints the contents of all label files in the specified folder.

  Args:
    folder_path: The path to the folder containing the label files.
  """
  for filename in glob.glob(os.path.join(folder_path, '*.txt')):
    with open(filename, 'r') as f:
        print(f'Filename: {filename}')
        print(f.read())

# Example usage:
folder_path = '/kaggle/working/datatset/train/Vehicle registration plate'
read_and_print_labels(folder_path)
folder_path = '/kaggle/working/datatset/validation/Vehicle registration plate'
read_and_print_labels(folder_path)
# Out:
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5b8c53dd8a300d6e.txt
# 0 0.053633499999999994 0.6206895 0.091119 0.039654999999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/29d4a1543ff5d6c0.txt
# 0 0.158228 0.4609375 0.271248 0.13812500000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9ed6b914e4fa8695.txt
# 0 0.3628125 0.632917 0.114375 0.08749999999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/55b7083bd34b9566.txt
# 0 0.8825000000000001 0.5732395 0.01749999999999996 0.019718999999999893
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4f83766bc0fa553c.txt
# 0 0.1546875 0.505662 0.03937499999999999 0.028745999999999997
# 0 0.78625 0.744338 0.10749999999999993 0.1036579999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/bacde20005949116.txt
# 0 0.2059375 0.6408335 0.018125000000000002 0.01166700000000002
# 0 0.3584375 0.6329165 0.015625 0.01416700000000004
# 0 0.5037499999999999 0.62375 0.016249999999999987 0.01250000000000003
# 0 0.6387499999999999 0.62375 0.012500000000000067 0.009166000000000007
# 0 0.7646875 0.8741669999999999 0.04312499999999997 0.045000000000000075
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6cf4713c95d8e532.txt
# 0 0.1296875 0.653333 0.089375 0.10000000000000009
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/8118b1ace832b9e5.txt
# 0 0.026366999999999998 0.7161455 0.044922 0.046875
# 0 0.690918 0.7115885000000001 0.06738200000000005 0.03515700000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/30f5a0a961202c1b.txt
# 0 0.2734375 0.7083335000000001 0.371093 0.16406299999999993
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e39a552b47f07ae8.txt
# 0 0.141875 0.6587500000000001 0.07 0.027500000000000007
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/21f0ffcb4ba5d81c.txt
# 0 0.235547 0.7406250000000001 0.07578200000000002 0.05833400000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/381233ba551661ad.txt
# 0 0.5953125 0.167144 0.026874999999999982 0.021012000000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/afbbe6f624f39b85.txt
# 0 0.21125 0.4733335 0.022499999999999992 0.008332999999999998
# 0 0.43843750000000004 0.6791665 0.09562500000000002 0.048333000000000036
# 0 0.908125 0.452083 0.030000000000000027 0.017499999999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1f7f79b4ae841e63.txt
# 0 0.49468749999999995 0.5759434999999999 0.190625 0.076415
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/8355b6b9f83fd072.txt
# 0 0.0765625 0.275417 0.056874999999999995 0.027500000000000042
# 0 0.1334375 0.54875 0.081875 0.1108340000000001
# 0 0.463125 0.17583349999999998 0.030000000000000027 0.013333000000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/df376871348e2c31.txt
# 0 0.27923699999999996 0.7222580000000001 0.15822399999999998 0.06799199999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ebc5ca345a5603d7.txt
# 0 0.5578125 0.7050635 0.03187499999999999 0.010971000000000035
# 0 0.7734375 0.7029540000000001 0.03562500000000002 0.013502000000000002
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5a44dbe713274c35.txt
# 0 0.484221 0.823588 0.309664 0.12487600000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/fa66dceec038aaba.txt
# 0 0.5509375000000001 0.6449345 0.03312499999999996 0.029081000000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/41f4356da2f7221f.txt
# 0 0.48366000000000003 0.8986930000000001 0.019607999999999997 0.009804000000000071
# 0 0.625 0.9207519999999999 0.05065400000000005 0.021242000000000132
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6085738ac0c207bf.txt
# 0 0.0615625 0.627197 0.030625 0.022593999999999975
# 0 0.3578125 0.7811715 0.09187499999999998 0.07112899999999998
# 0 0.79375 0.624686 0.03375000000000006 0.024267999999999856
# 0 0.9478125 0.6154815 0.02312499999999995 0.019246999999999986
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/3e72eaaf070e9f6c.txt
# 0 0.4783335 0.7237035 0.281111 0.07851900000000016
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/63f9d2ff812794a7.txt
# 0 0.1821875 0.7497225000000001 0.104375 0.08990099999999993
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9c7be0cfdf9c3224.txt
# 0 0.633984 0.838021 0.02265600000000001 0.01770800000000013
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b28949ba8202a637.txt
# 0 0.8190625 0.6696934999999999 0.11687499999999995 0.07264499999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/aaa591e61575f966.txt
# 0 0.8406865 0.7957515 0.0833330000000001 0.05228700000000008
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/19a7cbd15bbc3d1f.txt
# 0 0.223171 0.7752444999999999 0.029268000000000016 0.022800999999999905
# 0 0.6481705 0.9723125 0.108537 0.05211699999999988
# 0 0.875 0.7467425000000001 0.020731999999999973 0.02117299999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0670b29f926e5259.txt
# 0 0.41228899999999996 0.6971875000000001 0.199812 0.04937500000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4c8a22025046dc66.txt
# 0 0.38625000000000004 0.632929 0.24375000000000002 0.07697800000000017
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/31c8f86a68921243.txt
# 0 0.7703125 0.6879165 0.08812500000000001 0.0208330000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/562f507ac62ddbab.txt
# 0 0.6643749999999999 0.895 0.039999999999999925 0.013334000000000104
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/00103aa8df33633a.txt
# 0 0.43875 0.6992484999999999 0.185 0.120301
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9fa8eeb810673cfd.txt
# 0 0.8637695000000001 0.8134219999999999 0.09863300000000008 0.05162200000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/cb8841da456cccc8.txt
# 0 0.5196995 0.7646875 0.6866789999999998 0.22687500000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/29e2dc0cf0d61bf3.txt
# 0 0.1015625 0.9000649999999999 0.049478999999999995 0.020182000000000033
# 0 0.7096355000000001 0.892578 0.05468700000000004 0.02864600000000017
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/004aebeb3dea697a.txt
# 0 0.5028125 0.7664165 0.620625 0.4652910000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9ee58f7621b441c7.txt
# 0 0.3284375 0.7584459999999998 0.03187499999999999 0.07094599999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ce586bf3b6024f7b.txt
# 0 0.485937 0.6489585 0.475 0.31458300000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6c092d5c7056b9e5.txt
# 0 0.6343749999999999 0.7358330000000001 0.11124999999999996 0.034999999999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/fdc25bf5cc57bc0a.txt
# 0 0.26123050000000003 0.43619800000000003 0.020506999999999997 0.00781199999999993
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/de707769dd419777.txt
# 0 0.625 0.6387499999999999 0.15749999999999997 0.08083399999999992
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/af8af8379d11e103.txt
# 0 0.428024 0.6596875 0.034924000000000024 0.010624999999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/befc108c8c65519a.txt
# 0 0.10718749999999999 0.794559 0.111875 0.05065600000000009
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/eb0c295d14590820.txt
# 0 0.9493750000000001 0.8670835 0.04874999999999996 0.024167000000000122
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/021a3f4ad16708b8.txt
# 0 0.343125 0.6217104999999999 0.05125000000000002 0.038533
# 0 0.644375 0.6170114999999999 0.053749999999999964 0.04229300000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/365054866af7f7e8.txt
# 0 0.188125 0.6091665 0.037500000000000006 0.01666700000000006
# 0 0.4253125 0.5816665 0.02437499999999998 0.0066669999999999785
# 0 0.5390625 0.55375 0.016874999999999973 0.007499999999999914
# 0 0.6834374999999999 0.60125 0.020625000000000004 0.015833999999999977
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/caa032f8a90b3765.txt
# 0 0.36750000000000005 0.7941664999999999 0.04999999999999999 0.08166699999999993
# 0 0.9725 0.3741670000000001 0.05249999999999999 0.045000000000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/021b3c3c66e93910.txt
# 0 0.353285 0.6430665 0.04087600000000007 0.018554999999999877
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/93446b88730467cd.txt
# 0 0.594238 0.5709639999999999 0.06933600000000006 0.03255200000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a5a21b7eb6b33243.txt
# 0 0.2109375 0.8366665 0.019374999999999976 0.024444999999999852
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/fbda298ae0c95d43.txt
# 0 0.319336 0.762887 0.02148400000000006 0.02356399999999991
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/2403a98ffb148d44.txt
# 0 0.4319085 0.8233489999999999 0.044730999999999965 0.033793999999999894
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/8b7a1f0583466498.txt
# 0 0.1775 0.11 0.0975 0.04
# 0 0.9575 0.070417 0.036250000000000004 0.017500000000000016
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/eb29734eac16f813.txt
# 0 0.7168749999999999 0.7753284999999999 0.27749999999999997 0.1153849999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4c2990341a491a57.txt
# 0 0.482031 0.5882815 0.14218799999999998 0.10156300000000007
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1a47acd8e0d07441.txt
# 0 0.5121875 0.6458335000000001 0.974375 0.33833299999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/22a74841a6af3806.txt
# 0 0.0615625 0.6654165 0.095625 0.03416699999999991
# 0 0.419375 0.7999999999999999 0.13375000000000004 0.04833399999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0f7c680f1c4e1008.txt
# 0 0.0071875 0.5155305 0.014375 0.038826999999999945
# 0 0.259375 0.7510789999999999 0.12374999999999997 0.10612600000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b8fb2437d32027e2.txt
# 0 0.188125 0.5278565 0.047500000000000014 0.03210499999999988
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/087e4df170d637fd.txt
# 0 0.183125 0.5766665 0.10125 0.09333299999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1ac5b485b95c9f00.txt
# 0 0.4790625 0.6049335 0.790625 0.49247499999999983
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9c260a332da322d7.txt
# 0 0.5408335000000001 0.6684375 0.09333300000000004 0.021874999999999978
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/faac71b806eea5bb.txt
# 0 0.288281 0.515625 0.04531199999999996 0.06458399999999997
# 0 0.5585935 0.5208335000000001 0.017186999999999952 0.03333299999999991
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c724d198376baaeb.txt
# 0 0.178125 0.7830920000000001 0.05249999999999999 0.020021999999999984
# 0 0.43625 0.6979975 0.048750000000000016 0.023359000000000033
# 0 0.6653125 0.7269185 0.03187499999999999 0.04115700000000011
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1feb4b3b55eeb71b.txt
# 0 0.2875 0.4660039999999999 0.04999999999999999 0.02405800000000002
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/70071b59db057be0.txt
# 0 0.12156249999999999 0.6295885 0.023124999999999993 0.020022999999999926
# 0 0.8215625 0.5956614999999998 0.02937500000000004 0.02780900000000002
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ef27d9126de485d8.txt
# 0 0.5783335 0.21968749999999998 0.06833300000000005 0.040624999999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/f9774e7ecd7c68a6.txt
# 0 0.950625 0.895417 0.057499999999999996 0.03749999999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e1af4aa839ab62ee.txt
# 0 0.715686 0.7197715 0.2581699999999999 0.106209
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/727efc7df20c07e6.txt
# 0 0.5153125000000001 0.4616665 0.16812499999999997 0.106667
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c3143ee1463616fe.txt
# 0 0.1828125 0.666192 0.028124999999999983 0.029439999999999904
# 0 0.7778125 0.7364669999999999 0.06937499999999996 0.044634000000000035
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/92961b10deb98891.txt
# 0 0.5584374999999999 0.7396809999999999 0.07062500000000005 0.06285199999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/063b8572725e4df0.txt
# 0 0.060547 0.6803385 0.054688 0.022135000000000165
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a7749fc3bf9e778d.txt
# 0 0.47851600000000005 0.671875 0.017577999999999983 0.013020000000000032
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b6b20bae1bc049e1.txt
# 0 0.1078125 0.37250000000000005 0.016875 0.018334
# 0 0.8353125 0.37666700000000003 0.014375000000000027 0.010000000000000009
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5b7bac79f8e23602.txt
# 0 0.6810430000000001 0.6176470000000001 0.06619800000000009 0.04298600000000002
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/7b6890d8e5e24b35.txt
# 0 0.4890625 0.723156 0.028125000000000067 0.014006000000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1ddb26e43325d784.txt
# 0 0.7575000000000001 0.6257199999999999 0.17499999999999993 0.13627599999999992
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/284dba33c25d3fee.txt
# 0 0.77875 0.7251405 0.11625000000000008 0.09193299999999997
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/fd6e5ae4940655f2.txt
# 0 0.765 0.5687500000000001 0.18500000000000005 0.12916600000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/7892f62c41dd60a8.txt
# 0 0.024687499999999998 0.665572 0.021875 0.019700000000000023
# 0 0.14156249999999998 0.6454035 0.02687500000000001 0.01313299999999997
# 0 0.2815625 0.6566605 0.020625000000000004 0.013133000000000053
# 0 0.3671875 0.5825515 0.014375000000000027 0.011257000000000017
# 0 0.5059374999999999 0.8142590000000001 0.055624999999999925 0.022514000000000034
# 0 0.6671875 0.6674479999999999 0.011874999999999969 0.019700000000000023
# 0 0.8090625 0.7565670000000001 0.03187499999999999 0.021576000000000057
# 0 0.8646875 0.7331145 0.02312499999999995 0.030957000000000123
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/2c5bd0bdf15c84f0.txt
# 0 0.02375 0.813419 0.045 0.020220000000000026
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/2c9b3c365aa3ed8f.txt
# 0 0.1021875 0.8988710000000001 0.134375 0.05738399999999993
# 0 0.7396875 0.6843840000000001 0.038125000000000075 0.017873999999999904
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/31cbe9cca83813fa.txt
# 0 0.8209375 0.52587 0.06437500000000007 0.05079999999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/bc6a97ed90125ad7.txt
# 0 0.41125 0.8389530000000001 0.08250000000000002 0.031055999999999893
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0b44fbeef729264a.txt
# 0 0.8496874999999999 0.64875 0.2881250000000001 0.2858340000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a515e53db7680fab.txt
# 0 0.96875 0.6704165 0.04125000000000001 0.024166999999999977
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c8034242faa5e51f.txt
# 0 0.16749999999999998 0.774829 0.012499999999999983 0.010273999999999785
# 0 0.2265625 0.770548 0.015625 0.011985999999999932
# 0 0.2996875 0.8116439999999999 0.023125000000000007 0.020548000000000025
# 0 0.364375 0.755565 0.011249999999999982 0.014554000000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9c71134d1af9b7d1.txt
# 0 0.032812499999999994 0.6862499999999999 0.020624999999999998 0.01750000000000007
# 0 0.228125 0.69125 0.028749999999999998 0.024166000000000132
# 0 0.6315625 0.6645835 0.02562500000000001 0.014166999999999966
# 0 0.965625 0.677917 0.028749999999999942 0.022499999999999964
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/594af9572dce5138.txt
# 0 0.7571875 0.665932 0.193125 0.11907399999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/8b364a9a7d1e2ef0.txt
# 0 0.0384375 0.455 0.076875 0.04999999999999997
# 0 0.385625 0.3645835 0.043749999999999956 0.03416700000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b137e636883a1a6f.txt
# 0 0.5910905 0.7080000000000001 0.03324500000000008 0.01600000000000002
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b0fa23a7a94861b3.txt
# 0 0.019375 0.809167 0.03625 0.040000000000000036
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e7eb488376b353b1.txt
# 0 0.5259375 0.7679165 0.010624999999999996 0.020832999999999952
# 0 0.79375 0.9012500000000001 0.061249999999999916 0.04583400000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/82083fb9bb4fa0ba.txt
# 0 0.503125 0.6726075 0.17499999999999993 0.056285000000000085
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/87f8156408df8ce3.txt
# 0 0.6978125 0.429395 0.014374999999999916 0.00960599999999989
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b467dd77efa4830a.txt
# 0 0.7615624999999999 0.7304165 0.083125 0.09083299999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/7194ba9a1be02dfa.txt
# 0 0.8159179999999999 0.9270835 0.05566400000000005 0.05208300000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/312559b88a4ac48c.txt
# 0 0.685625 0.8173255 0.030000000000000027 0.013182999999999953
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ea71379a55835d17.txt
# 0 0.50375 0.521667 0.98625 0.6849999999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/65e557f6ae6a5ce6.txt
# 0 0.45098 0.7802290000000001 0.029411999999999994 0.021242000000000094
# 0 0.74183 0.8031045000000001 0.045752000000000015 0.024509000000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0b236de97c622942.txt
# 0 0.7540625 0.48968100000000003 0.06937499999999996 0.06191400000000008
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/afce38e569fd15a6.txt
# 0 0.056874999999999995 0.360417 0.09 0.03750000000000001
# 0 0.47875 0.8795835 0.28624999999999995 0.07583299999999997
# 0 0.973125 0.107083 0.05249999999999999 0.017499999999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/aea21ac231ef6ca0.txt
# 0 0.41781250000000003 0.8352005000000001 0.06812500000000005 0.034546999999999745
# 0 0.9096875 0.739029 0.073125 0.030812000000000176
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c977e0645aa11eee.txt
# 0 0.1890625 0.987917 0.05437500000000001 0.022500000000000114
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/88c807407f8428ce.txt
# 0 0.0325 0.6556249999999999 0.063334 0.015000000000000013
# 0 0.16916699999999998 0.7406250000000001 0.05000000000000001 0.03749999999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/eee32434d2e4ab59.txt
# 0 0.39937500000000004 0.67625 0.024999999999999967 0.01750000000000007
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5e2ed81ccffae3bf.txt
# 0 0.6540625 0.6008445 0.030625000000000013 0.036584999999999895
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0cc84896161a0f1f.txt
# 0 0.734991 0.8275 0.10975599999999991 0.022499999999999964
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e2299cb8a23727f7.txt
# 0 0.026875 0.4520834999999999 0.05375 0.03916700000000003
# 0 0.1134375 0.3916665 0.023125000000000007 0.02166700000000003
# 0 0.9593750000000001 0.3229165 0.03749999999999998 0.019167000000000045
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5f15f6d4a9f06ae1.txt
# 0 0.09843750000000001 0.5409725 0.034375 0.026388999999999996
# 0 0.33645800000000003 0.478472 0.012500000000000011 0.012499999999999956
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6351b17194ba4b17.txt
# 0 0.0790625 0.842083 0.04687499999999999 0.027499999999999858
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/40594908d62ec9da.txt
# 0 0.0071875 0.870649 0.014375 0.02916199999999997
# 0 0.180625 0.8443085 0.03375 0.031044999999999965
# 0 0.4434375 0.8490125000000001 0.020625000000000004 0.021636999999999858
# 0 0.6225 0.9336785000000001 0.0412499999999999 0.02916299999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/95fa33240de709aa.txt
# 0 0.48906299999999997 0.43958349999999996 0.50625 0.341667
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/66c25bcb99b1b814.txt
# 0 0.3640625 0.5616665 0.015625 0.0033329999999998825
# 0 0.53375 0.613333 0.021250000000000102 0.010000000000000009
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/85e6087e6014fffc.txt
# 0 0.122302 0.647626 0.057553999999999994 0.07270000000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0c0ac55f447972cd.txt
# 0 0.4996875 0.5549999999999999 0.999375 0.483334
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0e1a7255004820e3.txt
# 0 0.4675 0.4179165 0.10250000000000004 0.06583299999999996
# 0 0.8331249999999999 0.34874999999999995 0.036250000000000004 0.03083399999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/390de04bf6ead781.txt
# 0 0.793125 0.21388349999999998 0.10250000000000004 0.075047
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/7bc934ccabf502a5.txt
# 0 0.4965625 0.48875 0.20437500000000003 0.160834
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1dc7671de1865230.txt
# 0 0.549375 0.4725 0.29625 0.305
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1364fc9ce7034c9c.txt
# 0 0.3140625 0.811458 0.09531300000000004 0.04374999999999988
# 0 0.8691405 0.5203125000000001 0.019530999999999965 0.01354099999999995
# 0 0.9214845 0.5348955 0.025780999999999943 0.015625
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/f00c8fb7f7098727.txt
# 0 0.83375 0.7777255 0.33125000000000004 0.44266900000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c0261737a26537f1.txt
# 0 0.23781249999999998 0.8147279999999999 0.02562499999999998 0.01594800000000012
# 0 0.528125 0.9113510000000001 0.04500000000000004 0.023451999999999928
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9ead2683d36b6457.txt
# 0 0.24281250000000001 0.6959390000000001 0.09062500000000001 0.05989799999999999
# 0 0.711875 0.317259 0.06500000000000006 0.03959400000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/914f462f4363c2f2.txt
# 0 0.6608335 0.23125 0.02666700000000007 0.012499999999999983
# 0 0.9733335000000002 0.281875 0.051666999999999984 0.028749999999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/00494d0811b9e652.txt
# 0 0.4015625 0.646899 0.009375000000000022 0.005426000000000069
# 0 0.40156250000000004 0.6445735 0.008124999999999993 0.005426999999999883
# 0 0.48125 0.6670539999999999 0.011249999999999982 0.005426000000000069
# 0 0.4828125 0.6647285 0.009374999999999967 0.008527000000000048
# 0 0.6959375000000001 0.743023 0.04062500000000002 0.028682000000000124
# 0 0.9271875 0.711628 0.021874999999999978 0.015503999999999945
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6c0be2bb62c5f31a.txt
# 0 0.171875 0.6520834999999999 0.03125 0.029167000000000092
# 0 0.4146875 0.645417 0.02812500000000001 0.022499999999999964
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1e935b0107c51ddc.txt
# 0 0.46406200000000003 0.6520835 0.7375000000000002 0.5166670000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1dd15c8b9d674b7b.txt
# 0 0.10500999999999999 0.9403125 0.03568999999999999 0.015625
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/28bfd90e2c96bad3.txt
# 0 0.8189495 0.1672915 0.028142999999999918 0.025305
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/56d3bea0f4e410a3.txt
# 0 0.63875 0.5956845 0.08374999999999999 0.056285
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/01e2315172fea9e4.txt
# 0 0.20937499999999998 0.666146 0.0875 0.06354199999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/912bb88ab06023fc.txt
# 0 0.2496875 0.4520834999999999 0.08812500000000001 0.10083299999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/aef5cb6745fa64a1.txt
# 0 0.0875 0.6529170000000001 0.05625000000000001 0.017499999999999922
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e4110c0a189e5054.txt
# 0 0.5078125 0.8398439999999999 0.350001 0.09218799999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/aea98ee48c9dc672.txt
# 0 0.4196875 0.6969985000000001 0.016874999999999973 0.009380999999999898
# 0 0.5790625 0.71576 0.015625 0.003751999999999987
# 0 0.7696875000000001 0.6660415 0.013124999999999942 0.005628999999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1901a3a525f8bdb6.txt
# 0 0.2390625 0.5875 0.18437499999999998 0.13333400000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/f697fb4349472b75.txt
# 0 0.63625 0.5970835 0.028750000000000053 0.010833000000000018
# 0 0.7659374999999999 0.633333 0.02937500000000004 0.010000000000000009
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ff9858fc49202cb1.txt
# 0 0.21531250000000002 0.6003755 0.06812500000000002 0.056285000000000085
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5a6c57b6002e2536.txt
# 0 0.755371 0.9023435000000001 0.03417999999999988 0.013021000000000171
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c01427390e6fe7d7.txt
# 0 0.82666 0.440755 0.08300799999999986 0.055989999999999984
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/768f4e2df4f13edb.txt
# 0 0.6396875 0.5138014999999999 0.07437499999999997 0.06148100000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/22c9c7c27a200e0e.txt
# 0 0.0384615 0.82125 0.048781000000000005 0.015000000000000013
# 0 0.5337710000000001 0.8021875 0.028142000000000056 0.016875000000000084
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/247b74ca4fd19931.txt
# 0 0.51875 0.45125 0.88 0.630834
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/482fc7a8e76df6ca.txt
# 0 0.0278125 0.8216665000000001 0.055625 0.051666999999999984
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/67bfd80a41b6c25a.txt
# 0 0.4878125 0.723684 0.09687499999999999 0.03571399999999992
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a7bc44745b1763a3.txt
# 0 0.035625000000000004 0.634744 0.010000000000000002 0.011135999999999948
# 0 0.550625 0.7255009999999998 0.05125000000000002 0.025611999999999902
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9ad67645ac60c4a1.txt
# 0 0.79375 0.5725 0.09750000000000003 0.08666599999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/bbf8d0ba75ab10e8.txt
# 0 0.8087500000000001 0.5733945 0.11875000000000002 0.10275299999999997
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4f927baad53ed8f1.txt
# 0 0.6475 0.8441665 0.03125 0.011666999999999947
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/42f3c780f23f327a.txt
# 0 0.2709375 0.48269399999999996 0.16937500000000003 0.15341400000000002
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b782d02ca5ca55af.txt
# 0 0.4490625 0.732242 0.17687499999999998 0.08844
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b92271a7728835d3.txt
# 0 0.1171875 0.56875 0.03187499999999999 0.018750000000000044
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4e40fcde84677d90.txt
# 0 0.50125 0.48625 0.885 0.3175
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ec8319b578b56ea7.txt
# 0 0.6071875 0.6233335000000001 0.08562500000000006 0.05166700000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/338747e8c02c884b.txt
# 0 0.24 0.5587405 0.007500000000000007 0.004698999999999997
# 0 0.41500000000000004 0.6771615 0.019999999999999962 0.015977000000000078
# 0 0.5231250000000001 0.6973685 0.01749999999999996 0.007518999999999965
# 0 0.7871875 0.8768794999999999 0.02562500000000001 0.007518999999999882
# 0 0.8359375 0.7847745 0.02562500000000001 0.007519000000000048
# 0 0.9809375 0.6889095 0.016874999999999973 0.0056390000000000415
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6313f52f59f1c2eb.txt
# 0 0.776562 0.211458 0.41875000000000007 0.39375
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/7e87b3dc35faff09.txt
# 0 0.5839845 0.8001304999999999 0.140625 0.0742190000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b5cee67c8bcc6ad6.txt
# 0 0.076 0.6635 0.037334 0.025000000000000022
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4c9c066c75afc238.txt
# 0 0.897917 0.82375 0.06750000000000005 0.03374999999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ea005023cfbf38be.txt
# 0 0.4975 0.1383335 0.13875000000000004 0.08666699999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/05d3c22f2e2159fc.txt
# 0 0.7859375 0.5441665 0.14937499999999992 0.088333
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/7bf9a7c321d93dc7.txt
# 0 0.16843750000000002 0.7870834999999999 0.084375 0.055832999999999945
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4a8742b982437dd4.txt
# 0 0.005625 0.58625 0.01125 0.03250000000000005
# 0 0.6575 0.620833 0.10250000000000004 0.040000000000000036
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/411fff784693d9ab.txt
# 0 0.335 0.9702549999999999 0.036250000000000004 0.029271999999999965
# 0 0.7159375 0.9546745 0.023125000000000062 0.01699699999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0ccb1f56a00a5280.txt
# 0 0.1959375 0.970544 0.074375 0.02718999999999993
# 0 0.8887499999999999 0.9520395 0.06874999999999998 0.02039300000000016
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/503cfa13d15441cc.txt
# 0 0.334375 0.7330059999999998 0.1375 0.070434
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a2ae330d9034473e.txt
# 0 0.823125 0.6779164999999999 0.03499999999999992 0.020832999999999952
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/22ad2e9217e242bb.txt
# 0 0.7946875 0.7405555 0.161875 0.14333299999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/8cd39c56a6024dc2.txt
# 0 0.946875 0.9270834999999998 0.06499999999999995 0.03416699999999991
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6a84cc60c6386e9a.txt
# 0 0.43999999999999995 0.54305 0.3725 0.303942
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/38602dd19b5c6dd5.txt
# 0 0.4459375 0.7733335 0.014375000000000027 0.006667000000000052
# 0 0.6728125 0.775833 0.020625000000000004 0.014999999999999977
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/df32b86162996bd6.txt
# 0 0.46249999999999997 0.9226080000000001 0.30874999999999997 0.11163199999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5fe7ddb14e726b80.txt
# 0 0.405667 0.752 0.010000000000000009 0.007999999999999915
# 0 0.502 0.745 0.016000000000000014 0.012000000000000038
# 0 0.6636664999999999 0.7740000000000001 0.020667000000000102 0.015999999999999997
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4d470b52bb9e758e.txt
# 0 0.0496875 0.81203 0.016875 0.022556000000000166
# 0 0.5434375 0.8016915000000001 0.023125000000000062 0.01691700000000021
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a38025f0aece35d8.txt
# 0 0.0496875 0.399906 0.038125000000000006 0.03853399999999989
# 0 0.760625 0.699248 0.04499999999999993 0.06390999999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b794a69779998ca7.txt
# 0 0.12187500000000001 0.755833 0.02625000000000001 0.010000000000000083
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/148cd22ab9ecfad8.txt
# 0 0.7 0.7410715000000001 0.039999999999999925 0.041666999999999954
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/030274af7c34a641.txt
# 0 0.535 0.5841664999999999 0.3575 0.16333300000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/980b3aae0cd02d19.txt
# 0 0.266875 0.7379165 0.03624999999999998 0.019167000000000083
# 0 0.886875 0.7437499999999999 0.0625 0.025833999999999985
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/124c06d8f5b23f3f.txt
# 0 0.5490625 0.5416664999999999 0.351875 0.22666700000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5e58ca2ab824af52.txt
# 0 0.0509375 0.481156 0.016874999999999994 0.017587999999999993
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a50b693b2c4cc734.txt
# 0 0.7909375000000001 0.4622225 0.08687499999999992 0.088889
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e982746cb469b34d.txt
# 0 0.5420834999999999 0.901875 0.054167 0.013749999999999929
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/23c91b5f4f2b3d44.txt
# 0 0.3503125 0.487917 0.009374999999999967 0.0074999999999999884
# 0 0.504375 0.5358335 0.02624999999999994 0.008333000000000071
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/697701a5324865dc.txt
# 0 0.0534375 0.48405250000000005 0.106875 0.058160999999999956
# 0 0.5715625 0.56848 0.13187499999999996 0.06378999999999994
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/7df36614bbed0d05.txt
# 0 0.38968749999999996 0.6854165 0.018125000000000002 0.010833000000000018
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1e1a307f68fbf801.txt
# 0 0.28875 0.8229050000000001 0.09750000000000003 0.1128499999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/5be37684542c087b.txt
# 0 0.6541665 0.5075 0.10166699999999995 0.09000000000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ade9c7f5ee446fe3.txt
# 0 0.11624999999999999 0.5758329999999999 0.028749999999999998 0.055000000000000014
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/72a50835c7daacaa.txt
# 0 0.15375 0.572411 0.025000000000000022 0.015371999999999993
# 0 0.2940625 0.79288 0.06687500000000002 0.025889999999999948
# 0 0.825625 0.78479 0.07124999999999992 0.027508000000000008
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/2697961fa491123d.txt
# 0 0.5740624999999999 0.7628260000000001 0.16812499999999997 0.067284
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/eaa621be0a24470e.txt
# 0 0.0425 0.8090989999999999 0.053750000000000006 0.04221400000000006
# 0 0.6875 0.7537525 0.04125000000000001 0.03283300000000008
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/38d6ca580d9a067f.txt
# 0 0.6140625 0.8445380000000001 0.10062500000000008 0.04948600000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4b90c71a0d969b9d.txt
# 0 0.228125 0.6829170000000001 0.12374999999999997 0.09749999999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b061f0cad44a99cc.txt
# 0 0.26125 0.8389989999999999 0.015000000000000013 0.03493799999999995
# 0 0.34781249999999997 0.7993389999999999 0.026875000000000038 0.019830000000000035
# 0 0.6496875 0.8050050000000001 0.03562500000000002 0.03304999999999989
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/bb09e924157e6321.txt
# 0 0.2003125 0.8644465000000001 0.079375 0.07786100000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4892d6e842f9d3f1.txt
# 0 0.968125 0.6999999999999998 0.06125000000000003 0.02333400000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b57017784b95ef9f.txt
# 0 0.31875 0.769231 0.38125000000000003 0.17448399999999992
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/fc45b15c72df2f89.txt
# 0 0.475 0.466725 0.21749999999999997 0.18914200000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9fe409d420aa8c3d.txt
# 0 0.18312499999999998 0.6430585 0.1 0.05722299999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a3459377124924f2.txt
# 0 0.24843749999999998 0.5754165 0.18687499999999999 0.06083299999999984
# 0 0.24843749999999998 0.670833 0.08812499999999998 0.09000000000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b5dc09cd8f986863.txt
# 0 0.3179165 0.9434374999999999 0.070833 0.024374999999999925
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c2dedf5efbed53da.txt
# 0 0.6468750000000001 0.5008335 0.026249999999999996 0.006667000000000052
# 0 0.76 0.46916650000000004 0.03249999999999997 0.013332999999999965
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/203ee75ba1deb0a3.txt
# 0 0.24375000000000002 0.5495835 0.02125000000000002 0.015832999999999913
# 0 0.3465625 0.6083335 0.02937500000000004 0.018333000000000006
# 0 0.49812500000000004 0.66125 0.07250000000000006 0.03416599999999992
# 0 0.7659374999999999 0.5429165 0.01937500000000003 0.009167000000000073
# 0 0.8896875 0.542083 0.013124999999999942 0.007500000000000062
# 0 0.9503125 0.5729164999999999 0.018124999999999947 0.014166999999999893
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ed2f9cca285fe026.txt
# 0 0.2003125 0.410882 0.041874999999999996 0.018761999999999963
# 0 0.5340625 0.7532835 0.09687500000000004 0.056285
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6334bb95468658ee.txt
# 0 0.423125 0.796314 0.20375000000000004 0.11814799999999992
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/3cfc9db999159182.txt
# 0 0.47000000000000003 0.8297375 0.21250000000000002 0.14165099999999992
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ea7a6b867fffef10.txt
# 0 0.1803125 0.782833 0.05562500000000001 0.02532799999999988
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/2fbee90a079c848c.txt
# 0 0.33281249999999996 0.781737 0.08687499999999998 0.08463200000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/550466a3366ad476.txt
# 0 0.151032 0.8393455000000001 0.229518 0.11828899999999999
# 0 0.79581 0.742869 0.10694199999999987 0.05117400000000011
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/f5753c6ab58b29a5.txt
# 0 0.2902525 0.802027 0.063533 0.05000000000000007
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/6d0ac2c8df58b6bc.txt
# 0 0.5321875 0.8748724999999999 0.015625 0.04596500000000004
# 0 0.9146875000000001 0.9601635000000001 0.06312499999999999 0.07763100000000012
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4356a4ecc267f372.txt
# 0 0.10318949999999999 0.3830644999999999 0.03877499999999999 0.019354999999999976
# 0 0.27360850000000003 0.791532 0.080675 0.03951600000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a334bdc0c3dcaa52.txt
# 0 0.874219 0.7161215 0.029687999999999937 0.02102899999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/681403c74dcef4e1.txt
# 0 0.18593749999999998 0.6247299999999999 0.08687500000000001 0.10259200000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/009d23e04f2fccd8.txt
# 0 0.72 0.9475000000000001 0.025000000000000022 0.018334000000000145
# 0 0.79625 0.978333 0.007500000000000062 0.010000000000000083
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/66864db013a243f0.txt
# 0 0.7093750000000001 0.7487499999999999 0.026249999999999996 0.01750000000000007
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/75c29ac4c6544a07.txt
# 0 0.6581250000000001 0.7445835000000001 0.19000000000000006 0.1408329999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a019c77bee87d10e.txt
# 0 0.021962 0.5437315 0.043924 0.024294999999999956
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/03fe4b804d6f46c6.txt
# 0 0.8340624999999999 0.4728875 0.114375 0.10088300000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/de4bc8a61189dfa9.txt
# 0 0.495625 0.8606945000000003 0.03750000000000003 0.03658500000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/352b12fe29a114a4.txt
# 0 0.43583299999999997 0.868125 0.20499999999999996 0.10625000000000007
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/d2b0e8dc325f78c2.txt
# 0 0.0824745 0.39899949999999995 0.07872499999999999 0.015008999999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0daaa3dfed3bd932.txt
# 0 0.9703124999999999 0.5645835 0.01937500000000003 0.019166999999999934
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b13fa16dad921b60.txt
# 0 0.3178125 0.6944665 0.16937500000000003 0.04822099999999993
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c22f28d8747ec380.txt
# 0 0.1624995 0.3891485 0.10312500000000001 0.04784099999999997
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c3bbf0c979f34c57.txt
# 0 0.295 0.4981165 0.0975 0.10169500000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/80d93986d4f950fb.txt
# 0 0.3953125 0.61875 0.08812500000000001 0.05749999999999996
# 0 0.9025 0.5870835 0.05125000000000002 0.04083300000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/4c2dc90c322d2304.txt
# 0 0.5525 0.45458350000000003 0.42999999999999994 0.28416700000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b5135dd7e1879f41.txt
# 0 0.2709375 0.7732454999999999 0.081875 0.03947300000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/54b3ce04864fa520.txt
# 0 0.3596875 0.9125 0.078125 0.07166600000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/95cbde2ecb27a642.txt
# 0 0.75625 0.7502949999999999 0.0625 0.029515999999999938
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1191454739a48d88.txt
# 0 0.632951 0.5353125 0.09176199999999997 0.016874999999999973
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ecbd2bb165e21884.txt
# 0 0.2965625 0.6540385000000001 0.260625 0.16236499999999998
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e6214a0878762e0b.txt
# 0 0.24432199999999998 0.9072769999999999 0.08809399999999998 0.025821999999999883
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/e746d1e2234707f3.txt
# 0 0.393791 0.39134 0.05555599999999994 0.02777799999999997
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/8da91fe0212afc7a.txt
# 0 0.195625 0.61625 0.03875000000000001 0.020834000000000092
# 0 0.518125 0.62125 0.021250000000000102 0.022499999999999964
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/8b3564168e4394d1.txt
# 0 0.8653124999999999 0.6941670000000001 0.020625000000000004 0.014999999999999977
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/d28174d48dfdb118.txt
# 0 0.3265625 0.7625000000000001 0.338125 0.20000000000000018
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/79206d271b86fd56.txt
# 0 0.45562499999999995 0.5125000000000001 0.14499999999999996 0.10833400000000008
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/09703e31dffe3ac8.txt
# 0 0.3149415 0.790365 0.02636700000000003 0.03125
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a31ba9429d547936.txt
# 0 0.5054685 0.47083350000000007 0.929687 0.6416670000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b1a73a1c8e7425c9.txt
# 0 0.1134375 0.5466669999999999 0.020625000000000004 0.014999999999999977
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/25c98cac9411dcba.txt
# 0 0.95375 0.602083 0.04125000000000001 0.01250000000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/85da4192d8154334.txt
# 0 0.4392655 0.9025000000000001 0.038606999999999954 0.01375000000000004
# 0 0.733051 0.9384375 0.044256000000000115 0.016874999999999973
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/82ce37b3d30e9eda.txt
# 0 0.6196875 0.8734715 0.09437499999999999 0.04045100000000005
# 0 0.9759375 0.7728124999999999 0.04437500000000005 0.014111000000000033
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/be87b4852cae3ebf.txt
# 0 0.9282225000000001 0.66373 0.061522999999999994 0.03230599999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/837738522ee3ef56.txt
# 0 0.515625 0.49671649999999995 0.605 0.4437149999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/fa97e44e47c01961.txt
# 0 0.7041664999999999 0.7022685 0.261111 0.13043499999999988
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/453524a8dd222698.txt
# 0 0.624512 0.43945300000000004 0.16699200000000003 0.05859399999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/ee5efc6ec568aca3.txt
# 0 0.0846875 0.7466215 0.020625000000000004 0.020271000000000042
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/98d81c695825384c.txt
# 0 0.3096875 0.592083 0.12937500000000002 0.11250000000000004
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9914bbea083f6da9.txt
# 0 0.48375 0.7077859999999999 0.09625 0.06660399999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/04302f9378fd72e5.txt
# 0 0.505625 0.5806605 0.12874999999999998 0.05754700000000007
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/a6e33e113c91c7e6.txt
# 0 0.0690625 0.678333 0.018125000000000002 0.014999999999999977
# 0 0.15999999999999998 0.6720835 0.0062500000000000056 0.009167
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/12e0b5faf9706557.txt
# 0 0.40185550000000003 0.4963345 0.526367 0.36803500000000006
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/aa11257736a45eb5.txt
# 0 0.447656 0.7489585 0.717188 0.497917
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/0f206a5a3a72a771.txt
# 0 0.5018750000000001 0.47833349999999997 0.9725 0.6483329999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/b97e022446de7744.txt
# 0 0.652344 0.4635415 0.13281200000000004 0.08541699999999992
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/25b1c2ad061c60f6.txt
# 0 0.04125 0.43002399999999996 0.0825 0.06100400000000003
# 0 0.2578125 0.32595650000000004 0.030625000000000013 0.03468900000000006
# 0 0.6240625 0.5508375 0.07187500000000002 0.058613000000000005
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/37be20e8bfb800a3.txt
# 0 0.359375 0.7994375 0.04249999999999998 0.04873499999999974
# 0 0.9381250000000001 0.738519 0.04749999999999999 0.01686999999999996
#
# ...
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/5fb888d79b551331.txt
# 0 0.5975375 0.539116 0.2759790000000001 0.14874600000000004
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/b01d46f9911d558b.txt
# 0 0.5038675 0.4267969999999999 0.220443 0.219608
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/a774a6f81fea258b.txt
# 0 0.8395239999999999 0.5205775 0.08345199999999997 0.07011499999999993
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/80e02a518ffe4cb2.txt
# 0 0.5136415000000001 0.6139294999999999 0.297103 0.09954100000000003
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/b1096bc91a89b0cf.txt
# 0 0.7400385 0.577619 0.10855900000000007 0.08590999999999997
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/0e50ea14c4fc1353.txt
# 0 0.6540725000000001 0.6487515 0.16906300000000007 0.0662510000000001
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/e52d4f347b2cf90f.txt
# 0 0.5361025 0.6035645 0.1163269999999999 0.085229
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/9286a99f243b359a.txt
# 0 0.8254315 0.5099175 0.10502100000000003 0.08142500000000004
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/25d5c2fbd8b99662.txt
# 0 0.880897 0.76254 0.044305999999999957 0.09592200000000008
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/185fd6653258d3ed.txt
# 0 0.7196119999999999 0.5912915 0.08369799999999994 0.05733499999999999
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/1a3e9d87d733ff7f.txt
# 0 0.851641 0.5334590000000001 0.08451800000000009 0.05770800000000014
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/593e594137f374ab.txt
# 0 0.6681140000000001 0.634102 0.3670460000000001 0.21456
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/88df55ff4e13b90d.txt
# 0 0.7733905 0.8357884999999999 0.2688090000000001 0.276797
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/5a3f94aa35766f31.txt
# 0 0.19626949999999999 0.34365900000000005 0.053341 0.035153999999999956
# 0 0.342068 0.257971 0.03200400000000003 0.030760000000000016
# 0 0.7172324999999999 0.408474 0.0924569999999999 0.05932200000000005
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/52bf6b555e578a34.txt
# 0 0.9735739999999999 0.8238495 0.05207799999999996 0.021449000000000034
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/2a3e44107826e876.txt
# 0 0.6448499999999999 0.461587 0.10737000000000008 0.0898479999999999
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/2e95d7a799e23e11.txt
# 0 0.791348 0.5291594999999999 0.123942 0.09152100000000009
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/d830c3573e57bfc0.txt
# 0 0.4630335 0.790521 0.12468900000000005 0.062439999999999905
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/d27e094e98374ff8.txt
# 0 0.6303749999999999 0.6748815 0.22713799999999995 0.08247699999999993
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/b3b61da98e22cd4a.txt
# 0 0.768008 0.5044559999999999 0.10282599999999997 0.115232
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/82b53fe7f9147c96.txt
# 0 0.234387 0.594772 0.05776799999999996 0.06150399999999994
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/a52079c6cc4050cd.txt
# 0 0.5006325 0.7509095 0.12709499999999996 0.08203300000000002
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/508f0a75156e5fd4.txt
# 0 0.9077189999999999 0.6972895 0.03749000000000002 0.04174299999999983
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/315aead7766727b8.txt
# 0 0.4632005 0.7300745000000001 0.22872500000000004 0.07003300000000001
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/057569768fd6303e.txt
# 0 0.044005999999999997 0.32908000000000004 0.035512 0.027721999999999986
# 0 0.892989 0.642601 0.132506 0.117286
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/12d3b6665f7e1cf6.txt
# 0 0.04899049999999999 0.37375499999999995 0.09797499999999999 0.050344
# 0 0.697117 0.243459 0.03809800000000004 0.014907999999999977
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/428a5131c8cff7da.txt
# 0 0.5090025 0.56729 0.20548100000000002 0.113842
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/693acf98575cbe27.txt
# 0 0.2086635 0.359319 0.07503100000000001 0.09397799999999996
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/5021041c726b6ee4.txt
# 0 0.566106 0.5414414999999999 0.12147200000000002 0.08068899999999994
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/bacc80fafc0566c3.txt
# 0 0.7766215000000001 0.512602 0.04767500000000002 0.046267999999999976
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/08481c03daf6f35d.txt
# 0 0.4989985 0.9390154999999999 0.37814299999999995 0.12196900000000013
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/b09813a8742277c7.txt
# 0 0.0169845 0.3931335 0.033969 0.022302999999999976
# 0 0.488106 0.4881635 0.308172 0.10482900000000005
# 0 0.8691015 0.345482 0.015055000000000152 0.015420000000000086
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/53925df03b471f5d.txt
# 0 0.525868 0.8042305000000001 0.028383999999999965 0.01626700000000003
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/665cac5fd1cc2186.txt
# 0 0.154103 0.639286 0.10921600000000001 0.10815800000000009
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/d565d93637d4e76d.txt
# 0 0.5796680000000001 0.757682 0.15287799999999996 0.07098400000000002
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/f1131b93a33cefb9.txt
# 0 0.46367899999999995 0.7782005000000001 0.1498239999999999 0.11754900000000013
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/fb4e60b5cee8b88e.txt
# 0 0.5786884999999999 0.696512 0.26005500000000004 0.08594999999999997
# 0 0.5111450000000001 0.255928 0.1037040000000001 0.02724199999999996
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/fb55b73f241bf50a.txt
# 0 0.5083475 0.646013 0.301195 0.11924799999999994
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/50631041f74001aa.txt
# 0 0.178411 0.548475 0.026431999999999983 0.04867999999999991
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/7539902687e8f3a4.txt
# 0 0.207855 0.43458949999999996 0.014346000000000025 0.010031000000000049
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/63d3df798bc8840f.txt
# 0 0.503294 0.694348 0.22564199999999995 0.13340800000000008
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/c650ff8d3e8e75b3.txt
# 0 0.143945 0.7726335 0.08441599999999999 0.09861700000000004
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/a56e82026bb71ad5.txt
# 0 0.5084974999999999 0.6721435 0.19235700000000006 0.151879
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/daac3a6c64a79bea.txt
# 0 0.1503895 0.3806405 0.18806700000000004 0.05386500000000005
# 0 0.487228 0.8848485 0.20182000000000008 0.052427
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/d59b7a0ff294e3be.txt
# 0 0.48945700000000003 0.6825705 0.125346 0.04678899999999993
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/e4d600a63db8bf3a.txt
# 0 0.9572015 0.5058955 0.08559699999999987 0.10504100000000005
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/b193070a9c45b5ab.txt
# 0 0.25046850000000004 0.6112515000000001 0.10793500000000003 0.06781699999999995
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/7a1f9520c7ecd5b1.txt
# 0 0.156644 0.3647485 0.131266 0.04718299999999999
# 0 0.84033 0.7067435000000001 0.12055599999999989 0.049216999999999934
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/16c15b29b30148c2.txt
# 0 0.3908815 0.7217895 0.288561 0.11006899999999994
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/b5e7183b6a5abe6c.txt
# 0 0.6084345 0.752505 0.1383970000000001 0.09677399999999997
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/09453a7c716a9ef3.txt
# 0 0.559419 0.856026 0.15275999999999995 0.06788999999999994
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/548a985825bb991f.txt
# 0 0.4096685 0.6621665 0.28924700000000003 0.28067700000000007
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/1ead26febde18ce9.txt
# 0 0.5352875 0.43483800000000006 0.262681 0.1726280000000001
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/d8f6c135ec5486ff.txt
# 0 0.8440650000000001 0.6757949999999999 0.13238800000000006 0.10824400000000012
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/90abd4265adf5a00.txt
# 0 0.086716 0.648443 0.03304199999999999 0.025659999999999995
# 0 0.36301700000000003 0.4859285 0.018230000000000024 0.018816999999999924
# 0 0.4359375 0.684368 0.027345000000000064 0.02566000000000008
# 0 0.5225305 0.48507300000000003 0.01595100000000005 0.010263999999999999
# 0 0.6507115 0.5098785 0.01936899999999997 0.018816999999999924
# 0 0.7298990000000001 0.42006750000000004 0.01823000000000008 0.013685000000000008
# 0 0.7851589999999999 0.8528695000000001 0.04443600000000003 0.037635000000000154
# 0 0.8199095 0.520142 0.02050899999999989 0.015395999999999998
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/44afab29f5fa0abf.txt
# 0 0.396684 0.7806879999999999 0.22257000000000005 0.11149999999999993
# 0 0.959083 0.6247585 0.08183399999999996 0.06356299999999988
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/7fc0fb6035bc06a6.txt
# 0 0.4702505 0.7936430000000001 0.15650499999999995 0.06072200000000007
# 0 0.7973205000000001 0.769283 0.0448670000000001 0.05625800000000007
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/8cca720c410ee7f8.txt
# 0 0.428099 0.8707625 0.357078 0.05517099999999986
# 0 0.48702599999999996 0.2621525 0.024361999999999995 0.01141700000000001
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/ccc1a2d44a290368.txt
# 0 0.5681345 0.6647109999999999 0.12987100000000007 0.10071400000000007
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/d7b71c9fd144d58d.txt
# 0 0.7067395000000001 0.5091749999999999 0.16881699999999988 0.07339799999999996
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/894cacdb385fdb6b.txt
# 0 0.5285569999999999 0.7171815 0.11390800000000001 0.07730899999999992
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/1e6e75488d7878aa.txt
# 0 0.071035 0.6135174999999999 0.026195999999999997 0.04116499999999997
# 0 0.654899 0.5213114999999999 0.012680000000000025 0.01780100000000003
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/f73b754cdb1ab677.txt
# 0 0.745428 0.785074 0.15606600000000015 0.06505600000000007
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/e40cafe0f0d3a550.txt
# 0 0.1038885 0.6088 0.08747300000000001 0.1682
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/99732f172ac80128.txt
# 0 0.0777205 0.40592350000000005 0.032443 0.01534500000000001
# 0 0.7535205 0.6090990000000001 0.06882900000000003 0.07712799999999993
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/da1352ab6054a2e4.txt
# 0 0.49032600000000004 0.657848 0.562784 0.3631660000000001
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/747b0f12f54703ee.txt
# 0 0.511789 0.7346015 0.30734 0.07486899999999992
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/0787b0fa95f545a5.txt
# 0 0.088875 0.207684 0.026620000000000005 0.010839999999999999
# 0 0.5207409999999999 0.6045335000000001 0.149752 0.09074500000000008
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/5cc19b450a51ee4c.txt
# 0 0.764756 0.8960149999999999 0.13901999999999992 0.1418880000000001
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/03b7b71e1ffcb7a8.txt
# 0 0.031397 0.5054409999999999 0.062794 0.084798
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/abca9401dcf8f7ba.txt
# 0 0.0925385 0.4538285 0.06732700000000001 0.045740999999999955
# 0 0.5132995 0.6403405 0.12160700000000002 0.08143900000000004
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/548a8e997a66a0c4.txt
# 0 0.46056600000000003 0.520269 0.09323200000000004 0.061562000000000006
# 0 0.7098445 0.47429950000000004 0.022968999999999906 0.013483000000000026
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/2f3887024d298547.txt
# 0 0.512203 0.5315934999999999 0.11133000000000004 0.037851
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/2e8a83cfb1afe7ba.txt
# 0 0.40804050000000003 0.659078 0.16477499999999995 0.05960000000000002
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/3e2306f2cf4b2c67.txt
# 0 0.6179555000000001 0.6774330000000001 0.12982499999999997 0.08628999999999992
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/0727983dd5f9e4e6.txt
# 0 0.584055 0.8380740000000001 0.219144 0.13056000000000015
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/aefe747315dd79fc.txt
# 0 0.2948885 0.7257325 0.17490499999999998 0.11839700000000002
# 0 0.7043874999999999 0.320617 0.051614999999999855 0.028038000000000007
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/1eb2ebab9cd7adf6.txt
# 0 0.45974499999999996 0.5304365 0.06319799999999992 0.019198999999999966
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/f700c5b69c973db6.txt
# 0 0.3723025 0.5163789999999999 0.10596299999999997 0.0469499999999999
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/f53243c2bb551b8a.txt
# 0 0.089627 0.567404 0.037996 0.092768
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/f6256bceaf66693f.txt
# 0 0.601542 0.792061 0.2359 0.13073200000000007
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/19eba8ac64eed194.txt
# 0 0.300205 0.43841749999999996 0.09653400000000001 0.09817099999999994
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/844adfe06e003c09.txt
# 0 0.6055159999999999 0.6952780000000001 0.04736399999999996 0.03578600000000002
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/1f0e643b125f00ec.txt
# 0 0.7569254999999999 0.7056275000000001 0.088279 0.07750099999999992
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/feaf383fc5de383f.txt
# 0 0.4936775 0.9432619999999999 0.19007100000000005 0.10345599999999984
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/aac1aaaf824b63dd.txt
# 0 0.0628375 0.3583475 0.038413 0.02717499999999995
# 0 0.5108565 0.599616 0.12029299999999987 0.07221399999999985
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/86c92b0402fec141.txt
# 0 0.42767599999999995 0.5591575 0.22142799999999996 0.09079100000000005
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/228bd52bbe043677.txt
# 0 0.526771 0.377785 0.07770800000000005 0.05199600000000001
# 0 0.9110199999999999 0.27640149999999997 0.030778000000000083 0.019827
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/43339d9cbca470e4.txt
# 0 0.6669565 0.39598300000000003 0.13682099999999997 0.10302800000000005

# %% [markdown]
# #  <font style="color:green">2. Training [25 Points]</font>
#
# - **Write your training code in this section.**
#
# - **You also have to share ([shared logs example](https://tensorboard.dev/experiment/JRtnsKbwTaq1ow6nPLPGeg)) the loss plot of your training using tensorboard.dev.**
#
# How to share TensorBoard logs using tensorboard.dev find [here](https://courses.opencv.org/courses/course-v1:OpenCV+OpenCV-106+2019_T1/courseware/b1c43ffe765246658e537109e188addb/d62572ec8bd344db9aeae81235ede618/4?activate_block_id=block-v1%3AOpenCV%2BOpenCV-106%2B2019_T1%2Btype%40vertical%2Bblock%40398b46ddcd5c465fa52cb4d572ba3229).

# %%
# !nvidia-smi
# Out:
# Thu Oct  3 07:00:21 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             25W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %%writefile data.yaml
# path: '/kaggle/working/datatset' # dataset root dir
# train: '/kaggle/working/datatset/train/Vehicle registration plate'
# val: '/kaggle/working/datatset/validation/Vehicle registration plate'
# nc: 1
# names: ['reg plate']
# Out:
# Writing data.yaml

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5889.8/8062.4 GB disk)

# %%
# !pip install yolov8
# Out:
# Requirement already satisfied: yolov8 in /opt/conda/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: yolov5 in /opt/conda/lib/python3.10/site-packages (from yolov8) (7.0.13)
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (4.9.0.80)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (10.3.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (5.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (1.14.1)
# Requirement already satisfied: thop>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.4.0)
# Requirement already satisfied: torchvision>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (4.66.4)
# Requirement already satisfied: ultralytics>=8.0.100 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (8.3.3)
# Requirement already satisfied: tensorboard>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.16.2)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (70.0.0)
# Requirement already satisfied: fire in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.7.0)
# Requirement already satisfied: boto3>=1.19.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (1.26.100)
# Requirement already satisfied: sahi>=0.11.10 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.11.18)
# Requirement already satisfied: huggingface-hub>=0.12.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.25.0)
# Requirement already satisfied: roboflow>=0.2.29 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (1.1.47)
# Requirement already satisfied: botocore<1.30.0,>=1.29.100 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.19.1->yolov5->yolov8) (1.29.165)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.19.1->yolov5->yolov8) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.19.1->yolov5->yolov8) (0.6.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>=3.1.30->yolov5->yolov8) (4.0.11)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->yolov5->yolov8) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->yolov5->yolov8) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (2024.8.30)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (4.10.0.84)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (1.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (1.16.0)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (0.10.1)
# Requirement already satisfied: filetype in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (1.2.0)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from sahi>=0.11.10->yolov5->yolov8) (1.8.5.post1)
# Requirement already satisfied: pybboxes==0.1.6 in /opt/conda/lib/python3.10/site-packages (from sahi>=0.11.10->yolov5->yolov8) (0.1.6)
# Requirement already satisfied: terminaltables in /opt/conda/lib/python3.10/site-packages (from sahi>=0.11.10->yolov5->yolov8) (3.1.10)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from sahi>=0.11.10->yolov5->yolov8) (8.1.7)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (3.0.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->yolov5->yolov8) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->yolov5->yolov8) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->yolov5->yolov8) (3.1.4)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.100->yolov5->yolov8) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.100->yolov5->yolov8) (2.0.8)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire->yolov5->yolov8) (2.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5->yolov8) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5->yolov8) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.7.0->yolov5->yolov8) (1.3.0)

# %%
# !yolo train model=yolo11n.pt data='data.yaml' epochs=30 imgsz=640
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 90.2MB/s]
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=data.yaml, epochs=3, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 19.0MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/datatset/train/Vehicle registration plate... 530
# train: New cache created: /kaggle/working/datatset/train/Vehicle registration plate.cache
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.17 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/datatset/validation/Vehicle registration plate...
# val: New cache created: /kaggle/working/datatset/validation/Vehicle registration plate.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3      2.64G      1.565       2.33      1.218         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.782      0.658      0.725      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3      2.64G      1.587      1.398      1.202         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.863      0.666      0.773      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3      2.64G      1.512      1.133      1.157         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.895      0.771      0.846      0.544
#
# 3 epochs completed in 0.069 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.4MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.4MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.897      0.771      0.846      0.544
# Speed: 0.2ms preprocess, 2.0ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo train model=yolo11n.pt data='data.yaml' epochs=30 imgsz=640
# Out:
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/datatset/train/Vehicle registration plate.cache.
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.17 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/datatset/validation/Vehicle registration plate.cac
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      2.62G      1.565       2.33      1.218         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.782      0.658      0.725      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      2.64G      1.644      1.445      1.243         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.832      0.705       0.78      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      2.64G      1.655      1.288      1.255         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512       0.65      0.688      0.668      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      2.63G      1.619      1.218      1.236         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.826       0.67      0.765      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      2.63G      1.585      1.137      1.206         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512       0.81      0.738      0.795       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      2.63G      1.554      1.081      1.191         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.895      0.769      0.849      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      2.63G      1.511      1.034      1.172         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.843      0.812      0.847      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      2.63G      1.509     0.9901      1.159         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512       0.91      0.762      0.843      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      2.63G        1.5      0.971      1.155         17        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.893      0.816      0.877      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      2.63G      1.485     0.9565      1.151         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.935      0.813      0.879      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      2.63G      1.467     0.9281      1.142         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512       0.87      0.799      0.861      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      2.65G      1.464     0.9152      1.146         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.902      0.826      0.882      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      2.65G       1.43     0.8872      1.125         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.907      0.816      0.878      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      2.63G      1.426     0.8692      1.125         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.902      0.834      0.883      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      2.65G      1.412     0.8666      1.117         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.893      0.829      0.877      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      2.63G        1.4     0.8407      1.112         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.911      0.822      0.886      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      2.63G      1.394      0.831      1.108         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.928      0.834      0.892      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      2.63G       1.38     0.8116      1.109         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.919      0.844      0.896      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      2.65G      1.379     0.8063      1.099         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512       0.91      0.848      0.897      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      2.63G      1.367     0.7985      1.097         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.926       0.86      0.902      0.641
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      2.63G      1.396     0.7708      1.106         14        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.906      0.847      0.899       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      2.63G      1.385     0.7553      1.098         15        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.959      0.814      0.906      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      2.63G      1.365     0.7448      1.089         15        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.949      0.836      0.905      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      2.63G      1.354     0.7212      1.089         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512       0.94       0.84      0.906      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      2.63G      1.343      0.713      1.086         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.936      0.852      0.908      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      2.63G      1.333     0.6991      1.079         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.926      0.854      0.904      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      2.63G      1.325     0.6883      1.077         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.939      0.848      0.914      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      2.63G       1.32     0.6811      1.067         13        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.945       0.84      0.912      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      2.63G      1.302     0.6611      1.062         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.938       0.85      0.915      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      2.63G      1.298     0.6625       1.06         19        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.939      0.869      0.917      0.678
#
# 30 epochs completed in 0.650 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.939      0.869      0.916      0.678
# Speed: 0.1ms preprocess, 1.9ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo task=detect mode=predict model=' /kaggle/working/runs/detect/train2/weights/best.pt' imgsz= 640 conf =0.5 source= '/kaggle/working/datatset/validation/Vehicle registration plate'
# Out:
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/386 /kaggle/working/datatset/validation/Vehicle registration plate/003a5aaf6d17c917.jpg: 448x640 1 reg plate, 45.5ms
# image 2/386 /kaggle/working/datatset/validation/Vehicle registration plate/00723dac8201a83e.jpg: 480x640 2 reg plates, 44.4ms
# image 3/386 /kaggle/working/datatset/validation/Vehicle registration plate/008637722500f239.jpg: 480x640 2 reg plates, 9.2ms
# image 4/386 /kaggle/working/datatset/validation/Vehicle registration plate/0170ea8e1a33375a.jpg: 448x640 2 reg plates, 9.6ms
# image 5/386 /kaggle/working/datatset/validation/Vehicle registration plate/017527da8bfeb97d.jpg: 448x640 1 reg plate, 9.1ms
# image 6/386 /kaggle/working/datatset/validation/Vehicle registration plate/02a6ef3d9bd68e91.jpg: 480x640 2 reg plates, 9.4ms
# image 7/386 /kaggle/working/datatset/validation/Vehicle registration plate/03b7b71e1ffcb7a8.jpg: 448x640 1 reg plate, 9.7ms
# image 8/386 /kaggle/working/datatset/validation/Vehicle registration plate/044417ca6134604f.jpg: 448x640 1 reg plate, 9.3ms
# image 9/386 /kaggle/working/datatset/validation/Vehicle registration plate/057569768fd6303e.jpg: 480x640 2 reg plates, 10.7ms
# image 10/386 /kaggle/working/datatset/validation/Vehicle registration plate/064a8def3049d040.jpg: 448x640 1 reg plate, 9.7ms
# image 11/386 /kaggle/working/datatset/validation/Vehicle registration plate/0673b967f8c68eec.jpg: 480x640 1 reg plate, 9.5ms
# image 12/386 /kaggle/working/datatset/validation/Vehicle registration plate/06b024413ad385a7.jpg: 512x640 1 reg plate, 45.5ms
# image 13/386 /kaggle/working/datatset/validation/Vehicle registration plate/0727983dd5f9e4e6.jpg: 480x640 1 reg plate, 10.1ms
# image 14/386 /kaggle/working/datatset/validation/Vehicle registration plate/0787b0fa95f545a5.jpg: 576x640 1 reg plate, 44.4ms
# image 15/386 /kaggle/working/datatset/validation/Vehicle registration plate/0801961485534636.jpg: 480x640 1 reg plate, 9.1ms
# image 16/386 /kaggle/working/datatset/validation/Vehicle registration plate/081f5a6bc61b9c48.jpg: 480x640 1 reg plate, 8.8ms
# image 17/386 /kaggle/working/datatset/validation/Vehicle registration plate/08481c03daf6f35d.jpg: 448x640 1 reg plate, 9.5ms
# image 18/386 /kaggle/working/datatset/validation/Vehicle registration plate/091c033b2a7df15b.jpg: 480x640 1 reg plate, 9.5ms
# image 19/386 /kaggle/working/datatset/validation/Vehicle registration plate/09453a7c716a9ef3.jpg: 480x640 2 reg plates, 9.0ms
# image 20/386 /kaggle/working/datatset/validation/Vehicle registration plate/0c756c9366a8cb10.jpg: 480x640 1 reg plate, 9.3ms
# image 21/386 /kaggle/working/datatset/validation/Vehicle registration plate/0cacb08195a3e2d7.jpg: 448x640 1 reg plate, 9.6ms
# image 22/386 /kaggle/working/datatset/validation/Vehicle registration plate/0d6ca8553971fefd.jpg: 448x640 1 reg plate, 9.1ms
# image 23/386 /kaggle/working/datatset/validation/Vehicle registration plate/0e50ea14c4fc1353.jpg: 448x640 1 reg plate, 9.5ms
# image 24/386 /kaggle/working/datatset/validation/Vehicle registration plate/0ee91c4938b6e7ee.jpg: 640x480 1 reg plate, 44.6ms
# image 25/386 /kaggle/working/datatset/validation/Vehicle registration plate/0f0596b1c511e071.jpg: 576x640 1 reg plate, 9.7ms
# image 26/386 /kaggle/working/datatset/validation/Vehicle registration plate/0f4bfc46402a9f52.jpg: 640x640 1 reg plate, 9.7ms
# image 27/386 /kaggle/working/datatset/validation/Vehicle registration plate/0fbd1b85fc01d2ae.jpg: 384x640 1 reg plate, 56.0ms
# image 28/386 /kaggle/working/datatset/validation/Vehicle registration plate/1071b237587a698b.jpg: 640x480 1 reg plate, 9.6ms
# image 29/386 /kaggle/working/datatset/validation/Vehicle registration plate/11b155ab5b3331cf.jpg: 384x640 1 reg plate, 10.2ms
# image 30/386 /kaggle/working/datatset/validation/Vehicle registration plate/11f80fda2c38011c.jpg: 448x640 1 reg plate, 9.6ms
# image 31/386 /kaggle/working/datatset/validation/Vehicle registration plate/125622a2508e3b1d.jpg: 416x640 1 reg plate, 44.3ms
# image 32/386 /kaggle/working/datatset/validation/Vehicle registration plate/128a59bca025bed6.jpg: 480x640 1 reg plate, 9.7ms
# image 33/386 /kaggle/working/datatset/validation/Vehicle registration plate/12b7ea40074d3b20.jpg: 480x640 1 reg plate, 9.0ms
# image 34/386 /kaggle/working/datatset/validation/Vehicle registration plate/12d3b6665f7e1cf6.jpg: 640x480 1 reg plate, 10.3ms
# image 35/386 /kaggle/working/datatset/validation/Vehicle registration plate/133921bd26fff729.jpg: 640x416 (no detections), 44.7ms
# image 36/386 /kaggle/working/datatset/validation/Vehicle registration plate/140e8d10ff02e7e7.jpg: 448x640 1 reg plate, 9.4ms
# image 37/386 /kaggle/working/datatset/validation/Vehicle registration plate/1545c73bdecb3e2f.jpg: 352x640 1 reg plate, 44.7ms
# image 38/386 /kaggle/working/datatset/validation/Vehicle registration plate/15a51e29f5ceffd8.jpg: 448x640 1 reg plate, 9.9ms
# image 39/386 /kaggle/working/datatset/validation/Vehicle registration plate/16789af24af158d8.jpg: 640x640 1 reg plate, 9.8ms
# image 40/386 /kaggle/working/datatset/validation/Vehicle registration plate/16c15b29b30148c2.jpg: 576x640 1 reg plate, 9.9ms
# image 41/386 /kaggle/working/datatset/validation/Vehicle registration plate/17585ef2efb5ef9b.jpg: 640x480 1 reg plate, 9.7ms
# image 42/386 /kaggle/working/datatset/validation/Vehicle registration plate/18098dc9ee6aad80.jpg: 448x640 1 reg plate, 9.6ms
# image 43/386 /kaggle/working/datatset/validation/Vehicle registration plate/182268e1f8c6525f.jpg: 448x640 1 reg plate, 9.6ms
# image 44/386 /kaggle/working/datatset/validation/Vehicle registration plate/185d5dfa193c4ced.jpg: 448x640 1 reg plate, 9.0ms
# image 45/386 /kaggle/working/datatset/validation/Vehicle registration plate/185fd6653258d3ed.jpg: 480x640 1 reg plate, 9.8ms
# image 46/386 /kaggle/working/datatset/validation/Vehicle registration plate/19eba8ac64eed194.jpg: 480x640 1 reg plate, 9.0ms
# image 47/386 /kaggle/working/datatset/validation/Vehicle registration plate/19ff847d0cd1c5ec.jpg: 448x640 1 reg plate, 9.7ms
# image 48/386 /kaggle/working/datatset/validation/Vehicle registration plate/1a3e9d87d733ff7f.jpg: 448x640 1 reg plate, 9.0ms
# image 49/386 /kaggle/working/datatset/validation/Vehicle registration plate/1ca1155083156d72.jpg: 448x640 1 reg plate, 9.5ms
# image 50/386 /kaggle/working/datatset/validation/Vehicle registration plate/1db3793d7c84faa1.jpg: 480x640 1 reg plate, 9.5ms
# image 51/386 /kaggle/working/datatset/validation/Vehicle registration plate/1e6e75488d7878aa.jpg: 480x640 1 reg plate, 8.9ms
# image 52/386 /kaggle/working/datatset/validation/Vehicle registration plate/1ead26febde18ce9.jpg: 480x640 1 reg plate, 9.0ms
# image 53/386 /kaggle/working/datatset/validation/Vehicle registration plate/1eb2ebab9cd7adf6.jpg: 480x640 1 reg plate, 9.4ms
# image 54/386 /kaggle/working/datatset/validation/Vehicle registration plate/1edfbe8c28a86caf.jpg: 384x640 1 reg plate, 10.0ms
# image 55/386 /kaggle/working/datatset/validation/Vehicle registration plate/1f0e643b125f00ec.jpg: 448x640 1 reg plate, 10.3ms
# image 56/386 /kaggle/working/datatset/validation/Vehicle registration plate/1f1d5bc31e444cc1.jpg: 448x640 1 reg plate, 9.0ms
# image 57/386 /kaggle/working/datatset/validation/Vehicle registration plate/1f34454c4c073e1b.jpg: 608x640 1 reg plate, 45.4ms
# image 58/386 /kaggle/working/datatset/validation/Vehicle registration plate/228bd52bbe043677.jpg: 480x640 2 reg plates, 9.5ms
# image 59/386 /kaggle/working/datatset/validation/Vehicle registration plate/23c2c79a9febbf3e.jpg: 384x640 1 reg plate, 9.8ms
# image 60/386 /kaggle/working/datatset/validation/Vehicle registration plate/246a0e4264a39433.jpg: 480x640 1 reg plate, 9.6ms
# image 61/386 /kaggle/working/datatset/validation/Vehicle registration plate/25d5c2fbd8b99662.jpg: 384x640 (no detections), 10.1ms
# image 62/386 /kaggle/working/datatset/validation/Vehicle registration plate/26183d88c4f8012f.jpg: 480x640 1 reg plate, 10.6ms
# image 63/386 /kaggle/working/datatset/validation/Vehicle registration plate/26192da5ce2afa62.jpg: 448x640 1 reg plate, 9.9ms
# image 64/386 /kaggle/working/datatset/validation/Vehicle registration plate/2619ec27a314e69c.jpg: 480x640 1 reg plate, 9.9ms
# image 65/386 /kaggle/working/datatset/validation/Vehicle registration plate/2753536137929411.jpg: 512x640 1 reg plate, 9.9ms
# image 66/386 /kaggle/working/datatset/validation/Vehicle registration plate/27798906120ea394.jpg: 480x640 3 reg plates, 9.9ms
# image 67/386 /kaggle/working/datatset/validation/Vehicle registration plate/288a95c01e43cd14.jpg: 480x640 1 reg plate, 9.2ms
# image 68/386 /kaggle/working/datatset/validation/Vehicle registration plate/28bd6c6b1050e055.jpg: 448x640 1 reg plate, 9.8ms
# image 69/386 /kaggle/working/datatset/validation/Vehicle registration plate/28d1fb27a6e42ee7.jpg: 480x640 (no detections), 9.7ms
# image 70/386 /kaggle/working/datatset/validation/Vehicle registration plate/28e26a4eb646c67a.jpg: 384x640 1 reg plate, 11.3ms
# image 71/386 /kaggle/working/datatset/validation/Vehicle registration plate/2956bcbedfc167b6.jpg: 480x640 1 reg plate, 9.6ms
# image 72/386 /kaggle/working/datatset/validation/Vehicle registration plate/299f0363ae21d1c3.jpg: 448x640 1 reg plate, 9.7ms
# image 73/386 /kaggle/working/datatset/validation/Vehicle registration plate/29f7991e696e6e3f.jpg: 448x640 1 reg plate, 9.2ms
# image 74/386 /kaggle/working/datatset/validation/Vehicle registration plate/2a3e44107826e876.jpg: 384x640 1 reg plate, 9.9ms
# image 75/386 /kaggle/working/datatset/validation/Vehicle registration plate/2adddd0b09bb0f17.jpg: 480x640 1 reg plate, 9.6ms
# image 76/386 /kaggle/working/datatset/validation/Vehicle registration plate/2b97f5bf137ee8d1.jpg: 448x640 3 reg plates, 9.4ms
# image 77/386 /kaggle/working/datatset/validation/Vehicle registration plate/2bd26c63ebf598b7.jpg: 448x640 1 reg plate, 9.0ms
# image 78/386 /kaggle/working/datatset/validation/Vehicle registration plate/2c09fab0221652c5.jpg: 480x640 1 reg plate, 9.4ms
# image 79/386 /kaggle/working/datatset/validation/Vehicle registration plate/2d40d6e377c82ec9.jpg: 640x480 1 reg plate, 9.5ms
# image 80/386 /kaggle/working/datatset/validation/Vehicle registration plate/2d6640fb230770fd.jpg: 448x640 2 reg plates, 10.3ms
# image 81/386 /kaggle/working/datatset/validation/Vehicle registration plate/2e8a83cfb1afe7ba.jpg: 480x640 1 reg plate, 9.6ms
# image 82/386 /kaggle/working/datatset/validation/Vehicle registration plate/2e95d7a799e23e11.jpg: 352x640 1 reg plate, 9.9ms
# image 83/386 /kaggle/working/datatset/validation/Vehicle registration plate/2f3887024d298547.jpg: 480x640 1 reg plate, 9.6ms
# image 84/386 /kaggle/working/datatset/validation/Vehicle registration plate/2f90aaa72744452d.jpg: 480x640 2 reg plates, 9.0ms
# image 85/386 /kaggle/working/datatset/validation/Vehicle registration plate/2fe1f00b77a110a0.jpg: 448x640 1 reg plate, 9.7ms
# image 86/386 /kaggle/working/datatset/validation/Vehicle registration plate/302d636c896c263f.jpg: 448x640 1 reg plate, 9.3ms
# image 87/386 /kaggle/working/datatset/validation/Vehicle registration plate/30b6cfb60bf44533.jpg: 640x640 1 reg plate, 9.8ms
# image 88/386 /kaggle/working/datatset/validation/Vehicle registration plate/315aead7766727b8.jpg: 608x640 1 reg plate, 10.4ms
# image 89/386 /kaggle/working/datatset/validation/Vehicle registration plate/321ffb38656f7311.jpg: 480x640 1 reg plate, 9.8ms
# image 90/386 /kaggle/working/datatset/validation/Vehicle registration plate/3241f09a8964ddfb.jpg: 480x640 2 reg plates, 9.2ms
# image 91/386 /kaggle/working/datatset/validation/Vehicle registration plate/326c3286bcb5b2b0.jpg: 448x640 1 reg plate, 9.7ms
# image 92/386 /kaggle/working/datatset/validation/Vehicle registration plate/334f31e809ec9a77.jpg: 480x640 1 reg plate, 9.5ms
# image 93/386 /kaggle/working/datatset/validation/Vehicle registration plate/33e0333ff031c4fb.jpg: 640x640 1 reg plate, 10.2ms
# image 94/386 /kaggle/working/datatset/validation/Vehicle registration plate/343326e127297379.jpg: 448x640 2 reg plates, 10.6ms
# image 95/386 /kaggle/working/datatset/validation/Vehicle registration plate/35875c388efcddf0.jpg: 480x640 2 reg plates, 9.6ms
# image 96/386 /kaggle/working/datatset/validation/Vehicle registration plate/36d7b8b3cca3b0f5.jpg: 448x640 1 reg plate, 9.7ms
# image 97/386 /kaggle/working/datatset/validation/Vehicle registration plate/37ff77d13a54aac2.jpg: 448x640 1 reg plate, 9.2ms
# image 98/386 /kaggle/working/datatset/validation/Vehicle registration plate/39c193bcc0c00f9e.jpg: 448x640 1 reg plate, 8.9ms
# image 99/386 /kaggle/working/datatset/validation/Vehicle registration plate/3d98e3713783e82d.jpg: 448x640 1 reg plate, 9.2ms
# image 100/386 /kaggle/working/datatset/validation/Vehicle registration plate/3e156de979eb0828.jpg: 480x640 1 reg plate, 9.8ms
# image 101/386 /kaggle/working/datatset/validation/Vehicle registration plate/3e2306f2cf4b2c67.jpg: 544x640 1 reg plate, 44.9ms
# image 102/386 /kaggle/working/datatset/validation/Vehicle registration plate/3ecd5af7c4f11963.jpg: 480x640 1 reg plate, 9.8ms
# image 103/386 /kaggle/working/datatset/validation/Vehicle registration plate/3ed000628c6a0587.jpg: 448x640 1 reg plate, 9.6ms
# image 104/386 /kaggle/working/datatset/validation/Vehicle registration plate/3feecc5809a29627.jpg: 640x640 1 reg plate, 9.7ms
# image 105/386 /kaggle/working/datatset/validation/Vehicle registration plate/4148b2126f0986a4.jpg: 640x640 1 reg plate, 9.1ms
# image 106/386 /kaggle/working/datatset/validation/Vehicle registration plate/415d64bf8cfe82f2.jpg: 448x640 1 reg plate, 9.7ms
# image 107/386 /kaggle/working/datatset/validation/Vehicle registration plate/428a5131c8cff7da.jpg: 640x640 1 reg plate, 10.3ms
# image 108/386 /kaggle/working/datatset/validation/Vehicle registration plate/43339d9cbca470e4.jpg: 480x640 1 reg plate, 9.7ms
# image 109/386 /kaggle/working/datatset/validation/Vehicle registration plate/43b1b0028dd2db8d.jpg: 480x640 1 reg plate, 9.2ms
# image 110/386 /kaggle/working/datatset/validation/Vehicle registration plate/44afab29f5fa0abf.jpg: 480x640 2 reg plates, 9.0ms
# image 111/386 /kaggle/working/datatset/validation/Vehicle registration plate/453a77009b27e253.jpg: 448x640 1 reg plate, 9.8ms
# image 112/386 /kaggle/working/datatset/validation/Vehicle registration plate/4572990fd64bb6be.jpg: 512x640 2 reg plates, 9.5ms
# image 113/386 /kaggle/working/datatset/validation/Vehicle registration plate/460753acbd6e6dad.jpg: 480x640 2 reg plates, 9.5ms
# image 114/386 /kaggle/working/datatset/validation/Vehicle registration plate/46a7991da6461831.jpg: 448x640 (no detections), 10.2ms
# image 115/386 /kaggle/working/datatset/validation/Vehicle registration plate/4793138df3c05610.jpg: 352x640 1 reg plate, 11.2ms
# image 116/386 /kaggle/working/datatset/validation/Vehicle registration plate/485e5f37dd13ffab.jpg: 384x640 2 reg plates, 9.8ms
# image 117/386 /kaggle/working/datatset/validation/Vehicle registration plate/488722909dd9c0ac.jpg: 480x640 1 reg plate, 9.7ms
# image 118/386 /kaggle/working/datatset/validation/Vehicle registration plate/49595029959689b7.jpg: 480x640 1 reg plate, 9.0ms
# image 119/386 /kaggle/working/datatset/validation/Vehicle registration plate/4ac941b9393d00f9.jpg: 480x640 1 reg plate, 8.9ms
# image 120/386 /kaggle/working/datatset/validation/Vehicle registration plate/4b3aba5dfb7a0492.jpg: 480x640 1 reg plate, 10.0ms
# image 121/386 /kaggle/working/datatset/validation/Vehicle registration plate/4c04b488ddc48225.jpg: 384x640 1 reg plate, 10.5ms
# image 122/386 /kaggle/working/datatset/validation/Vehicle registration plate/4cb48c8bf41b70a4.jpg: 480x640 1 reg plate, 9.4ms
# image 123/386 /kaggle/working/datatset/validation/Vehicle registration plate/4df1448703257ff0.jpg: 480x640 1 reg plate, 8.9ms
# image 124/386 /kaggle/working/datatset/validation/Vehicle registration plate/4e2cb95b9c509b10.jpg: 384x640 1 reg plate, 10.7ms
# image 125/386 /kaggle/working/datatset/validation/Vehicle registration plate/4e593c88022ff6b1.jpg: 480x640 2 reg plates, 9.4ms
# image 126/386 /kaggle/working/datatset/validation/Vehicle registration plate/4ee3f0e9a2fb20a9.jpg: 448x640 1 reg plate, 9.5ms
# image 127/386 /kaggle/working/datatset/validation/Vehicle registration plate/4fa24c1abe969cb7.jpg: 448x640 1 reg plate, 9.1ms
# image 128/386 /kaggle/working/datatset/validation/Vehicle registration plate/4ff8bebd6d6a0361.jpg: 480x640 1 reg plate, 9.5ms
# image 129/386 /kaggle/working/datatset/validation/Vehicle registration plate/5021041c726b6ee4.jpg: 480x640 1 reg plate, 9.6ms
# image 130/386 /kaggle/working/datatset/validation/Vehicle registration plate/50631041f74001aa.jpg: 448x640 (no detections), 10.5ms
# image 131/386 /kaggle/working/datatset/validation/Vehicle registration plate/508f0a75156e5fd4.jpg: 448x640 1 reg plate, 9.4ms
# image 132/386 /kaggle/working/datatset/validation/Vehicle registration plate/50c37aeaf19acd5b.jpg: 448x640 1 reg plate, 9.1ms
# image 133/386 /kaggle/working/datatset/validation/Vehicle registration plate/5290f4027491d09b.jpg: 480x640 1 reg plate, 9.6ms
# image 134/386 /kaggle/working/datatset/validation/Vehicle registration plate/52bf6b555e578a34.jpg: 448x640 1 reg plate, 9.5ms
# image 135/386 /kaggle/working/datatset/validation/Vehicle registration plate/52ceb1fc30b413e5.jpg: 480x640 2 reg plates, 9.6ms
# image 136/386 /kaggle/working/datatset/validation/Vehicle registration plate/53386dae3cf13cc3.jpg: 480x640 1 reg plate, 9.0ms
# image 137/386 /kaggle/working/datatset/validation/Vehicle registration plate/5373ec295ea62c47.jpg: 448x640 2 reg plates, 9.6ms
# image 138/386 /kaggle/working/datatset/validation/Vehicle registration plate/53925df03b471f5d.jpg: 480x640 (no detections), 9.6ms
# image 139/386 /kaggle/working/datatset/validation/Vehicle registration plate/53ad98b12752ad16.jpg: 480x640 4 reg plates, 8.9ms
# image 140/386 /kaggle/working/datatset/validation/Vehicle registration plate/548a8e997a66a0c4.jpg: 576x640 1 reg plate, 9.5ms
# image 141/386 /kaggle/working/datatset/validation/Vehicle registration plate/548a985825bb991f.jpg: 480x640 (no detections), 9.5ms
# image 142/386 /kaggle/working/datatset/validation/Vehicle registration plate/54bd93e5a4de808a.jpg: 480x640 1 reg plate, 9.0ms
# image 143/386 /kaggle/working/datatset/validation/Vehicle registration plate/54ebca2064066a49.jpg: 448x640 1 reg plate, 9.7ms
# image 144/386 /kaggle/working/datatset/validation/Vehicle registration plate/5581a1b7d2f0f2b4.jpg: 640x640 1 reg plate, 10.3ms
# image 145/386 /kaggle/working/datatset/validation/Vehicle registration plate/5641e6ad7d2600f2.jpg: 480x640 1 reg plate, 11.6ms
# image 146/386 /kaggle/working/datatset/validation/Vehicle registration plate/575d96d014e4fbab.jpg: 480x640 1 reg plate, 12.9ms
# image 147/386 /kaggle/working/datatset/validation/Vehicle registration plate/593e594137f374ab.jpg: 448x640 1 reg plate, 10.0ms
# image 148/386 /kaggle/working/datatset/validation/Vehicle registration plate/59b83c5f8f1dcfa4.jpg: 640x480 1 reg plate, 10.3ms
# image 149/386 /kaggle/working/datatset/validation/Vehicle registration plate/5a122adbb1a776b7.jpg: 480x640 1 reg plate, 14.1ms
# image 150/386 /kaggle/working/datatset/validation/Vehicle registration plate/5a3f94aa35766f31.jpg: 544x640 3 reg plates, 10.0ms
# image 151/386 /kaggle/working/datatset/validation/Vehicle registration plate/5a96f5e1f9be8d42.jpg: 480x640 1 reg plate, 11.8ms
# image 152/386 /kaggle/working/datatset/validation/Vehicle registration plate/5cc19b450a51ee4c.jpg: 480x640 (no detections), 9.6ms
# image 153/386 /kaggle/working/datatset/validation/Vehicle registration plate/5daafbcf76fa6602.jpg: 480x640 1 reg plate, 9.7ms
# image 154/386 /kaggle/working/datatset/validation/Vehicle registration plate/5df8816356fc2b29.jpg: 320x640 1 reg plate, 46.2ms
# image 155/386 /kaggle/working/datatset/validation/Vehicle registration plate/5fb888d79b551331.jpg: 640x640 1 reg plate, 9.7ms
# image 156/386 /kaggle/working/datatset/validation/Vehicle registration plate/5ff91ccfc6f15d04.jpg: 448x640 1 reg plate, 9.8ms
# image 157/386 /kaggle/working/datatset/validation/Vehicle registration plate/61a69ad713142e45.jpg: 480x640 1 reg plate, 9.5ms
# image 158/386 /kaggle/working/datatset/validation/Vehicle registration plate/620bd952592bc0e9.jpg: 480x640 1 reg plate, 9.1ms
# image 159/386 /kaggle/working/datatset/validation/Vehicle registration plate/621837d55c229864.jpg: 480x640 1 reg plate, 9.8ms
# image 160/386 /kaggle/working/datatset/validation/Vehicle registration plate/628a23a43f19c4db.jpg: 384x640 1 reg plate, 10.6ms
# image 161/386 /kaggle/working/datatset/validation/Vehicle registration plate/62bb93bbd270dd9a.jpg: 448x640 1 reg plate, 9.8ms
# image 162/386 /kaggle/working/datatset/validation/Vehicle registration plate/6306fc7f3573eb70.jpg: 448x640 2 reg plates, 9.6ms
# image 163/386 /kaggle/working/datatset/validation/Vehicle registration plate/63d3df798bc8840f.jpg: 640x640 1 reg plate, 9.8ms
# image 164/386 /kaggle/working/datatset/validation/Vehicle registration plate/643c3cc1a4e85db2.jpg: 480x640 1 reg plate, 9.7ms
# image 165/386 /kaggle/working/datatset/validation/Vehicle registration plate/647ff22cf6950211.jpg: 544x640 1 reg plate, 11.1ms
# image 166/386 /kaggle/working/datatset/validation/Vehicle registration plate/64de505bd2bac82b.jpg: 480x640 1 reg plate, 9.9ms
# image 167/386 /kaggle/working/datatset/validation/Vehicle registration plate/6504632e0dc25997.jpg: 480x640 1 reg plate, 9.2ms
# image 168/386 /kaggle/working/datatset/validation/Vehicle registration plate/659dbf4f8c0fd29d.jpg: 480x640 1 reg plate, 9.8ms
# image 169/386 /kaggle/working/datatset/validation/Vehicle registration plate/65e080f9ac466664.jpg: 384x640 3 reg plates, 9.9ms
# image 170/386 /kaggle/working/datatset/validation/Vehicle registration plate/665cac5fd1cc2186.jpg: 448x640 1 reg plate, 9.5ms
# image 171/386 /kaggle/working/datatset/validation/Vehicle registration plate/66771a4870c324f9.jpg: 384x640 1 reg plate, 12.5ms
# image 172/386 /kaggle/working/datatset/validation/Vehicle registration plate/66be6b583048fa94.jpg: 448x640 1 reg plate, 9.9ms
# image 173/386 /kaggle/working/datatset/validation/Vehicle registration plate/67945cf7a6beccdf.jpg: 384x640 1 reg plate, 15.0ms
# image 174/386 /kaggle/working/datatset/validation/Vehicle registration plate/67c834b73882a9f9.jpg: 448x640 2 reg plates, 9.8ms
# image 175/386 /kaggle/working/datatset/validation/Vehicle registration plate/6846c275ded01f85.jpg: 640x640 1 reg plate, 9.5ms
# image 176/386 /kaggle/working/datatset/validation/Vehicle registration plate/693acf98575cbe27.jpg: 480x640 1 reg plate, 9.7ms
# image 177/386 /kaggle/working/datatset/validation/Vehicle registration plate/69450fa183d57a7b.jpg: 384x640 2 reg plates, 10.3ms
# image 178/386 /kaggle/working/datatset/validation/Vehicle registration plate/6a0ef049e5ec4b16.jpg: 448x640 1 reg plate, 10.0ms
# image 179/386 /kaggle/working/datatset/validation/Vehicle registration plate/6aff04e9c32aec0f.jpg: 640x480 1 reg plate, 10.2ms
# image 180/386 /kaggle/working/datatset/validation/Vehicle registration plate/6b113b3edbadfe5d.jpg: 480x640 1 reg plate, 9.8ms
# image 181/386 /kaggle/working/datatset/validation/Vehicle registration plate/6c144e47161867c2.jpg: 384x640 1 reg plate, 10.0ms
# image 182/386 /kaggle/working/datatset/validation/Vehicle registration plate/6e819dc674a74078.jpg: 480x640 2 reg plates, 9.5ms
# image 183/386 /kaggle/working/datatset/validation/Vehicle registration plate/6eb18d1ad17cd174.jpg: 448x640 1 reg plate, 9.6ms
# image 184/386 /kaggle/working/datatset/validation/Vehicle registration plate/70e7b5173fe1e289.jpg: 480x640 1 reg plate, 9.6ms
# image 185/386 /kaggle/working/datatset/validation/Vehicle registration plate/71881a9c0f7f0a86.jpg: 448x640 2 reg plates, 9.4ms
# image 186/386 /kaggle/working/datatset/validation/Vehicle registration plate/71dbb47ebe504abe.jpg: 352x640 1 reg plate, 10.4ms
# image 187/386 /kaggle/working/datatset/validation/Vehicle registration plate/724307be418b2ed2.jpg: 480x640 1 reg plate, 10.0ms
# image 188/386 /kaggle/working/datatset/validation/Vehicle registration plate/7275e72e1996267f.jpg: 512x640 1 reg plate, 9.5ms
# image 189/386 /kaggle/working/datatset/validation/Vehicle registration plate/73467682c5995b65.jpg: 512x640 1 reg plate, 8.8ms
# image 190/386 /kaggle/working/datatset/validation/Vehicle registration plate/747b0f12f54703ee.jpg: 480x640 1 reg plate, 9.5ms
# image 191/386 /kaggle/working/datatset/validation/Vehicle registration plate/749b4451492fc250.jpg: 448x640 1 reg plate, 10.7ms
# image 192/386 /kaggle/working/datatset/validation/Vehicle registration plate/74ee6d1b58ae2e70.jpg: 448x640 1 reg plate, 9.3ms
# image 193/386 /kaggle/working/datatset/validation/Vehicle registration plate/7539902687e8f3a4.jpg: 480x640 (no detections), 10.6ms
# image 194/386 /kaggle/working/datatset/validation/Vehicle registration plate/76e14d05ee8acb6d.jpg: 448x640 1 reg plate, 9.8ms
# image 195/386 /kaggle/working/datatset/validation/Vehicle registration plate/77e716224c85410f.jpg: 480x640 (no detections), 10.3ms
# image 196/386 /kaggle/working/datatset/validation/Vehicle registration plate/791d63b1c3499e4f.jpg: 512x640 1 reg plate, 9.8ms
# image 197/386 /kaggle/working/datatset/validation/Vehicle registration plate/7a1f9520c7ecd5b1.jpg: 544x640 2 reg plates, 9.5ms
# image 198/386 /kaggle/working/datatset/validation/Vehicle registration plate/7b4e86e1c94d65de.jpg: 480x640 (no detections), 9.5ms
# image 199/386 /kaggle/working/datatset/validation/Vehicle registration plate/7bcf6b4ec09f1ea7.jpg: 480x640 1 reg plate, 9.4ms
# image 200/386 /kaggle/working/datatset/validation/Vehicle registration plate/7cbc7ee444622a66.jpg: 640x640 1 reg plate, 10.7ms
# image 201/386 /kaggle/working/datatset/validation/Vehicle registration plate/7f56adf4b9306ac9.jpg: 448x640 1 reg plate, 10.5ms
# image 202/386 /kaggle/working/datatset/validation/Vehicle registration plate/7f9740e95a74f2b9.jpg: 480x640 1 reg plate, 9.5ms
# image 203/386 /kaggle/working/datatset/validation/Vehicle registration plate/7fc0fb6035bc06a6.jpg: 448x640 1 reg plate, 9.7ms
# image 204/386 /kaggle/working/datatset/validation/Vehicle registration plate/80d21c58a71a0751.jpg: 384x640 1 reg plate, 10.0ms
# image 205/386 /kaggle/working/datatset/validation/Vehicle registration plate/80e02a518ffe4cb2.jpg: 480x640 1 reg plate, 10.3ms
# image 206/386 /kaggle/working/datatset/validation/Vehicle registration plate/8256e277c7f47797.jpg: 480x640 1 reg plate, 8.9ms
# image 207/386 /kaggle/working/datatset/validation/Vehicle registration plate/82b53fe7f9147c96.jpg: 448x640 1 reg plate, 9.8ms
# image 208/386 /kaggle/working/datatset/validation/Vehicle registration plate/844adfe06e003c09.jpg: 480x640 1 reg plate, 9.7ms
# image 209/386 /kaggle/working/datatset/validation/Vehicle registration plate/85b1dafd26aa98df.jpg: 448x640 1 reg plate, 9.6ms
# image 210/386 /kaggle/working/datatset/validation/Vehicle registration plate/85ddb7e0f60156a3.jpg: 448x640 (no detections), 9.9ms
# image 211/386 /kaggle/working/datatset/validation/Vehicle registration plate/85f0b4db3eb512ce.jpg: 448x640 1 reg plate, 9.0ms
# image 212/386 /kaggle/working/datatset/validation/Vehicle registration plate/86c92b0402fec141.jpg: 448x640 1 reg plate, 9.1ms
# image 213/386 /kaggle/working/datatset/validation/Vehicle registration plate/87793700161a7a6b.jpg: 448x640 1 reg plate, 9.1ms
# image 214/386 /kaggle/working/datatset/validation/Vehicle registration plate/87b4f1202cd06440.jpg: 480x640 2 reg plates, 9.8ms
# image 215/386 /kaggle/working/datatset/validation/Vehicle registration plate/88df55ff4e13b90d.jpg: 480x640 (no detections), 9.5ms
# image 216/386 /kaggle/working/datatset/validation/Vehicle registration plate/88fc866f92860d70.jpg: 640x640 (no detections), 9.5ms
# image 217/386 /kaggle/working/datatset/validation/Vehicle registration plate/894cacdb385fdb6b.jpg: 480x640 1 reg plate, 9.5ms
# image 218/386 /kaggle/working/datatset/validation/Vehicle registration plate/895d440e05b2a8d8.jpg: 480x640 1 reg plate, 8.9ms
# image 219/386 /kaggle/working/datatset/validation/Vehicle registration plate/8c63cf76166c3bd7.jpg: 512x640 1 reg plate, 9.6ms
# image 220/386 /kaggle/working/datatset/validation/Vehicle registration plate/8cb5553e75d3d311.jpg: 480x640 3 reg plates, 9.7ms
# image 221/386 /kaggle/working/datatset/validation/Vehicle registration plate/8cca720c410ee7f8.jpg: 640x480 1 reg plate, 9.6ms
# image 222/386 /kaggle/working/datatset/validation/Vehicle registration plate/8cdcb833ef1ef049.jpg: 480x640 1 reg plate, 9.6ms
# image 223/386 /kaggle/working/datatset/validation/Vehicle registration plate/8ceed1ec9bc3ac45.jpg: 640x480 1 reg plate, 10.1ms
# image 224/386 /kaggle/working/datatset/validation/Vehicle registration plate/9034927e7438bdd6.jpg: 640x480 2 reg plates, 9.0ms
# image 225/386 /kaggle/working/datatset/validation/Vehicle registration plate/90596bf3313e72e3.jpg: 352x640 2 reg plates, 9.9ms
# image 226/386 /kaggle/working/datatset/validation/Vehicle registration plate/908a3ac555a1a509.jpg: 448x640 1 reg plate, 9.5ms
# image 227/386 /kaggle/working/datatset/validation/Vehicle registration plate/90abd4265adf5a00.jpg: 448x640 3 reg plates, 9.4ms
# image 228/386 /kaggle/working/datatset/validation/Vehicle registration plate/911e694dcc0814bf.jpg: 480x640 2 reg plates, 9.5ms
# image 229/386 /kaggle/working/datatset/validation/Vehicle registration plate/9238f5062ff1dc8d.jpg: 480x640 1 reg plate, 10.0ms
# image 230/386 /kaggle/working/datatset/validation/Vehicle registration plate/9286a99f243b359a.jpg: 512x640 1 reg plate, 9.5ms
# image 231/386 /kaggle/working/datatset/validation/Vehicle registration plate/932eef14e5ee78b2.jpg: 448x640 1 reg plate, 10.2ms
# image 232/386 /kaggle/working/datatset/validation/Vehicle registration plate/934645379fe657e1.jpg: 480x640 1 reg plate, 10.1ms
# image 233/386 /kaggle/working/datatset/validation/Vehicle registration plate/944281d0485869f0.jpg: 448x640 1 reg plate, 9.6ms
# image 234/386 /kaggle/working/datatset/validation/Vehicle registration plate/9498d0aff8f9ff8c.jpg: 384x640 1 reg plate, 9.8ms
# image 235/386 /kaggle/working/datatset/validation/Vehicle registration plate/955a8e4c8ba8116e.jpg: 480x640 1 reg plate, 9.6ms
# image 236/386 /kaggle/working/datatset/validation/Vehicle registration plate/98bcfbc4d3c8abbc.jpg: 480x640 2 reg plates, 9.0ms
# image 237/386 /kaggle/working/datatset/validation/Vehicle registration plate/99732f172ac80128.jpg: 384x640 2 reg plates, 9.8ms
# image 238/386 /kaggle/working/datatset/validation/Vehicle registration plate/9995dfc6e0eae5a1.jpg: 448x640 1 reg plate, 9.8ms
# image 239/386 /kaggle/working/datatset/validation/Vehicle registration plate/99c9c657582f958f.jpg: 448x640 2 reg plates, 9.0ms
# image 240/386 /kaggle/working/datatset/validation/Vehicle registration plate/9a4fe6361597f264.jpg: 448x640 1 reg plate, 9.1ms
# image 241/386 /kaggle/working/datatset/validation/Vehicle registration plate/9a795bbf4e94d630.jpg: 448x640 1 reg plate, 9.6ms
# image 242/386 /kaggle/working/datatset/validation/Vehicle registration plate/9c92cadb0f6237c0.jpg: 448x640 1 reg plate, 9.3ms
# image 243/386 /kaggle/working/datatset/validation/Vehicle registration plate/9ebbaf4d1f8d6e7b.jpg: 352x640 1 reg plate, 9.9ms
# image 244/386 /kaggle/working/datatset/validation/Vehicle registration plate/a21aa7c1d7b93d12.jpg: 480x640 1 reg plate, 9.7ms
# image 245/386 /kaggle/working/datatset/validation/Vehicle registration plate/a3ad91fabd188be3.jpg: 448x640 2 reg plates, 9.6ms
# image 246/386 /kaggle/working/datatset/validation/Vehicle registration plate/a52079c6cc4050cd.jpg: 480x640 1 reg plate, 9.6ms
# image 247/386 /kaggle/working/datatset/validation/Vehicle registration plate/a54e7bb80448f3b0.jpg: 480x640 2 reg plates, 9.0ms
# image 248/386 /kaggle/working/datatset/validation/Vehicle registration plate/a56e82026bb71ad5.jpg: 448x640 1 reg plate, 10.0ms
# image 249/386 /kaggle/working/datatset/validation/Vehicle registration plate/a5d6f8d36672fa64.jpg: 448x640 1 reg plate, 9.1ms
# image 250/386 /kaggle/working/datatset/validation/Vehicle registration plate/a67bc3f5f8650c73.jpg: 640x640 1 reg plate, 9.9ms
# image 251/386 /kaggle/working/datatset/validation/Vehicle registration plate/a6e3b0b73220cd32.jpg: 448x640 1 reg plate, 9.5ms
# image 252/386 /kaggle/working/datatset/validation/Vehicle registration plate/a72a8cda1bb31e34.jpg: 480x640 1 reg plate, 9.5ms
# image 253/386 /kaggle/working/datatset/validation/Vehicle registration plate/a774a6f81fea258b.jpg: 480x640 1 reg plate, 8.9ms
# image 254/386 /kaggle/working/datatset/validation/Vehicle registration plate/a79296fb4a48245e.jpg: 448x640 2 reg plates, 10.2ms
# image 255/386 /kaggle/working/datatset/validation/Vehicle registration plate/a823532e163f5722.jpg: 480x640 1 reg plate, 9.3ms
# image 256/386 /kaggle/working/datatset/validation/Vehicle registration plate/a929dc75c20da7d8.jpg: 640x640 1 reg plate, 9.5ms
# image 257/386 /kaggle/working/datatset/validation/Vehicle registration plate/a9b2a2018f845393.jpg: 480x640 1 reg plate, 9.7ms
# image 258/386 /kaggle/working/datatset/validation/Vehicle registration plate/aac1aaaf824b63dd.jpg: 480x640 2 reg plates, 8.9ms
# image 259/386 /kaggle/working/datatset/validation/Vehicle registration plate/abca9401dcf8f7ba.jpg: 480x640 2 reg plates, 9.3ms
# image 260/386 /kaggle/working/datatset/validation/Vehicle registration plate/aca8821ff0368720.jpg: 480x640 2 reg plates, 9.5ms
# image 261/386 /kaggle/working/datatset/validation/Vehicle registration plate/ad10c7d29f111692.jpg: 480x640 1 reg plate, 8.8ms
# image 262/386 /kaggle/working/datatset/validation/Vehicle registration plate/ae6724423f0d111a.jpg: 512x640 1 reg plate, 9.3ms
# image 263/386 /kaggle/working/datatset/validation/Vehicle registration plate/aefe747315dd79fc.jpg: 480x640 1 reg plate, 9.5ms
# image 264/386 /kaggle/working/datatset/validation/Vehicle registration plate/affd16c51644a893.jpg: 480x640 1 reg plate, 9.0ms
# image 265/386 /kaggle/working/datatset/validation/Vehicle registration plate/b01d46f9911d558b.jpg: 288x640 1 reg plate, 43.9ms
# image 266/386 /kaggle/working/datatset/validation/Vehicle registration plate/b076ad266891d7aa.jpg: 448x640 2 reg plates, 9.4ms
# image 267/386 /kaggle/working/datatset/validation/Vehicle registration plate/b09813a8742277c7.jpg: 512x640 1 reg plate, 9.4ms
# image 268/386 /kaggle/working/datatset/validation/Vehicle registration plate/b101900b26128253.jpg: 480x640 (no detections), 10.8ms
# image 269/386 /kaggle/working/datatset/validation/Vehicle registration plate/b1096bc91a89b0cf.jpg: 448x640 1 reg plate, 9.7ms
# image 270/386 /kaggle/working/datatset/validation/Vehicle registration plate/b15d6c0bdf90226d.jpg: 480x640 1 reg plate, 11.1ms
# image 271/386 /kaggle/working/datatset/validation/Vehicle registration plate/b193070a9c45b5ab.jpg: 480x640 1 reg plate, 9.0ms
# image 272/386 /kaggle/working/datatset/validation/Vehicle registration plate/b1a50a3824887ee2.jpg: 448x640 1 reg plate, 9.4ms
# image 273/386 /kaggle/working/datatset/validation/Vehicle registration plate/b25d7d2cb7abf86b.jpg: 448x640 1 reg plate, 8.9ms
# image 274/386 /kaggle/working/datatset/validation/Vehicle registration plate/b32671b7cc279583.jpg: 640x640 1 reg plate, 9.6ms
# image 275/386 /kaggle/working/datatset/validation/Vehicle registration plate/b3b61da98e22cd4a.jpg: 480x640 1 reg plate, 10.2ms
# image 276/386 /kaggle/working/datatset/validation/Vehicle registration plate/b57fe3aa2ff9577e.jpg: 384x640 1 reg plate, 10.1ms
# image 277/386 /kaggle/working/datatset/validation/Vehicle registration plate/b5e7183b6a5abe6c.jpg: 480x640 1 reg plate, 9.5ms
# image 278/386 /kaggle/working/datatset/validation/Vehicle registration plate/b6580dec5ada277d.jpg: 448x640 1 reg plate, 9.8ms
# image 279/386 /kaggle/working/datatset/validation/Vehicle registration plate/b6e55f97085c3732.jpg: 480x640 1 reg plate, 9.5ms
# image 280/386 /kaggle/working/datatset/validation/Vehicle registration plate/b6ecda23586a6ba5.jpg: 480x640 1 reg plate, 9.6ms
# image 281/386 /kaggle/working/datatset/validation/Vehicle registration plate/b7cdb5c0c99002b7.jpg: 448x640 1 reg plate, 9.5ms
# image 282/386 /kaggle/working/datatset/validation/Vehicle registration plate/b8a3f2ea385e45b3.jpg: 384x640 2 reg plates, 9.9ms
# image 283/386 /kaggle/working/datatset/validation/Vehicle registration plate/b91c3aaba25bf914.jpg: 448x640 1 reg plate, 9.7ms
# image 284/386 /kaggle/working/datatset/validation/Vehicle registration plate/b94993a2d67b455e.jpg: 448x640 1 reg plate, 8.9ms
# image 285/386 /kaggle/working/datatset/validation/Vehicle registration plate/b9f5b9acf1777acf.jpg: 480x640 1 reg plate, 10.2ms
# image 286/386 /kaggle/working/datatset/validation/Vehicle registration plate/bacc80fafc0566c3.jpg: 480x640 1 reg plate, 8.9ms
# image 287/386 /kaggle/working/datatset/validation/Vehicle registration plate/bbcac63e32bd8137.jpg: 448x640 1 reg plate, 9.5ms
# image 288/386 /kaggle/working/datatset/validation/Vehicle registration plate/bd12ea92bcab1afd.jpg: 480x640 1 reg plate, 9.6ms
# image 289/386 /kaggle/working/datatset/validation/Vehicle registration plate/be654a7eabe0e891.jpg: 480x640 1 reg plate, 9.0ms
# image 290/386 /kaggle/working/datatset/validation/Vehicle registration plate/be9fd0014b5a4f2a.jpg: 448x640 1 reg plate, 10.2ms
# image 291/386 /kaggle/working/datatset/validation/Vehicle registration plate/bf0aac0878b0a3d2.jpg: 512x640 (no detections), 9.4ms
# image 292/386 /kaggle/working/datatset/validation/Vehicle registration plate/bf2f25f3ed9ff4d5.jpg: 448x640 1 reg plate, 9.5ms
# image 293/386 /kaggle/working/datatset/validation/Vehicle registration plate/c1d8b110186e095a.jpg: 480x640 1 reg plate, 9.5ms
# image 294/386 /kaggle/working/datatset/validation/Vehicle registration plate/c274e026ac907eb9.jpg: 480x640 1 reg plate, 9.3ms
# image 295/386 /kaggle/working/datatset/validation/Vehicle registration plate/c50d184afad1a9dc.jpg: 480x640 (no detections), 9.5ms
# image 296/386 /kaggle/working/datatset/validation/Vehicle registration plate/c650ff8d3e8e75b3.jpg: 416x640 1 reg plate, 9.3ms
# image 297/386 /kaggle/working/datatset/validation/Vehicle registration plate/c7b1e6f7c38fa1a0.jpg: 480x640 1 reg plate, 9.7ms
# image 298/386 /kaggle/working/datatset/validation/Vehicle registration plate/c7df5232291486a3.jpg: 640x640 1 reg plate, 9.5ms
# image 299/386 /kaggle/working/datatset/validation/Vehicle registration plate/c91ee912164d8ecb.jpg: 480x640 1 reg plate, 9.4ms
# image 300/386 /kaggle/working/datatset/validation/Vehicle registration plate/cb4b754537798d23.jpg: 448x640 1 reg plate, 9.7ms
# image 301/386 /kaggle/working/datatset/validation/Vehicle registration plate/cb8c75fc1c7ccf73.jpg: 640x640 1 reg plate, 9.9ms
# image 302/386 /kaggle/working/datatset/validation/Vehicle registration plate/ccc1a2d44a290368.jpg: 448x640 1 reg plate, 9.4ms
# image 303/386 /kaggle/working/datatset/validation/Vehicle registration plate/cdb1e8621d1c624e.jpg: 448x640 1 reg plate, 9.3ms
# image 304/386 /kaggle/working/datatset/validation/Vehicle registration plate/ce97f7bc90e97109.jpg: 448x640 2 reg plates, 9.2ms
# image 305/386 /kaggle/working/datatset/validation/Vehicle registration plate/d027c6e32db60e3c.jpg: 480x640 1 reg plate, 9.6ms
# image 306/386 /kaggle/working/datatset/validation/Vehicle registration plate/d27e094e98374ff8.jpg: 448x640 1 reg plate, 9.6ms
# image 307/386 /kaggle/working/datatset/validation/Vehicle registration plate/d28d71c2690c16ed.jpg: 480x640 2 reg plates, 9.6ms
# image 308/386 /kaggle/working/datatset/validation/Vehicle registration plate/d2fe2b47668e9d8e.jpg: 480x640 1 reg plate, 9.0ms
# image 309/386 /kaggle/working/datatset/validation/Vehicle registration plate/d3729058c6a4186e.jpg: 480x640 1 reg plate, 8.9ms
# image 310/386 /kaggle/working/datatset/validation/Vehicle registration plate/d44c0b2252bf8a92.jpg: 480x640 1 reg plate, 9.6ms
# image 311/386 /kaggle/working/datatset/validation/Vehicle registration plate/d5058059dc0ce0ad.jpg: 480x640 1 reg plate, 9.1ms
# image 312/386 /kaggle/working/datatset/validation/Vehicle registration plate/d53a3bc813477685.jpg: 384x640 1 reg plate, 9.8ms
# image 313/386 /kaggle/working/datatset/validation/Vehicle registration plate/d565d93637d4e76d.jpg: 448x640 1 reg plate, 9.5ms
# image 314/386 /kaggle/working/datatset/validation/Vehicle registration plate/d59b7a0ff294e3be.jpg: 576x640 1 reg plate, 9.6ms
# image 315/386 /kaggle/working/datatset/validation/Vehicle registration plate/d5f4069e6734ac06.jpg: 480x640 1 reg plate, 9.6ms
# image 316/386 /kaggle/working/datatset/validation/Vehicle registration plate/d648b2ae1abc09f3.jpg: 544x640 2 reg plates, 9.7ms
# image 317/386 /kaggle/working/datatset/validation/Vehicle registration plate/d6c5271e96ec1a61.jpg: 640x480 1 reg plate, 9.7ms
# image 318/386 /kaggle/working/datatset/validation/Vehicle registration plate/d7b71c9fd144d58d.jpg: 640x640 1 reg plate, 10.1ms
# image 319/386 /kaggle/working/datatset/validation/Vehicle registration plate/d7d49b1a3706f3eb.jpg: 448x640 1 reg plate, 9.5ms
# image 320/386 /kaggle/working/datatset/validation/Vehicle registration plate/d830c3573e57bfc0.jpg: 480x640 1 reg plate, 10.0ms
# image 321/386 /kaggle/working/datatset/validation/Vehicle registration plate/d8cc6d566d01054b.jpg: 640x640 1 reg plate, 9.4ms
# image 322/386 /kaggle/working/datatset/validation/Vehicle registration plate/d8daed582e6cce2d.jpg: 480x640 1 reg plate, 9.6ms
# image 323/386 /kaggle/working/datatset/validation/Vehicle registration plate/d8f6c135ec5486ff.jpg: 448x640 1 reg plate, 9.4ms
# image 324/386 /kaggle/working/datatset/validation/Vehicle registration plate/d9fa2abf3719a4bd.jpg: 480x640 1 reg plate, 10.1ms
# image 325/386 /kaggle/working/datatset/validation/Vehicle registration plate/da1352ab6054a2e4.jpg: 480x640 1 reg plate, 9.0ms
# image 326/386 /kaggle/working/datatset/validation/Vehicle registration plate/da8186b39f042cdf.jpg: 480x640 1 reg plate, 9.4ms
# image 327/386 /kaggle/working/datatset/validation/Vehicle registration plate/daac3a6c64a79bea.jpg: 640x512 1 reg plate, 44.3ms
# image 328/386 /kaggle/working/datatset/validation/Vehicle registration plate/de2b5afb7eda96cf.jpg: 448x640 1 reg plate, 11.2ms
# image 329/386 /kaggle/working/datatset/validation/Vehicle registration plate/dec4608715b2d28d.jpg: 384x640 1 reg plate, 9.8ms
# image 330/386 /kaggle/working/datatset/validation/Vehicle registration plate/defd8f4b30b3e1e1.jpg: 480x640 1 reg plate, 10.3ms
# image 331/386 /kaggle/working/datatset/validation/Vehicle registration plate/e08424f3cd5f6dac.jpg: 480x640 1 reg plate, 9.0ms
# image 332/386 /kaggle/working/datatset/validation/Vehicle registration plate/e1120bfe48f85c1b.jpg: 576x640 1 reg plate, 9.6ms
# image 333/386 /kaggle/working/datatset/validation/Vehicle registration plate/e1925cd0ae28fbd9.jpg: 416x640 1 reg plate, 9.7ms
# image 334/386 /kaggle/working/datatset/validation/Vehicle registration plate/e2427db217e5c3db.jpg: 448x640 1 reg plate, 10.2ms
# image 335/386 /kaggle/working/datatset/validation/Vehicle registration plate/e40cafe0f0d3a550.jpg: 480x640 1 reg plate, 9.5ms
# image 336/386 /kaggle/working/datatset/validation/Vehicle registration plate/e4d600a63db8bf3a.jpg: 640x640 1 reg plate, 9.7ms
# image 337/386 /kaggle/working/datatset/validation/Vehicle registration plate/e52d4f347b2cf90f.jpg: 480x640 1 reg plate, 9.5ms
# image 338/386 /kaggle/working/datatset/validation/Vehicle registration plate/e57d38ae6a921518.jpg: 480x640 1 reg plate, 9.2ms
# image 339/386 /kaggle/working/datatset/validation/Vehicle registration plate/e5edf93b7c9f5edb.jpg: 480x640 1 reg plate, 9.3ms
# image 340/386 /kaggle/working/datatset/validation/Vehicle registration plate/e6299b9e04680adb.jpg: 480x640 2 reg plates, 9.6ms
# image 341/386 /kaggle/working/datatset/validation/Vehicle registration plate/e742e284c7c9da96.jpg: 480x640 1 reg plate, 9.0ms
# image 342/386 /kaggle/working/datatset/validation/Vehicle registration plate/e79f6777f2fc08b2.jpg: 448x640 1 reg plate, 9.5ms
# image 343/386 /kaggle/working/datatset/validation/Vehicle registration plate/e82f13b4a2fe69f3.jpg: 480x640 1 reg plate, 9.5ms
# image 344/386 /kaggle/working/datatset/validation/Vehicle registration plate/e8b36c888a75d742.jpg: 480x640 (no detections), 9.0ms
# image 345/386 /kaggle/working/datatset/validation/Vehicle registration plate/e9561d7c16db565f.jpg: 448x640 1 reg plate, 10.5ms
# image 346/386 /kaggle/working/datatset/validation/Vehicle registration plate/e9cd346a4a84d594.jpg: 512x640 1 reg plate, 10.4ms
# image 347/386 /kaggle/working/datatset/validation/Vehicle registration plate/e9fdd0a41cb61da6.jpg: 480x640 1 reg plate, 9.5ms
# image 348/386 /kaggle/working/datatset/validation/Vehicle registration plate/ea02d99ba51372ee.jpg: 480x640 2 reg plates, 9.0ms
# image 349/386 /kaggle/working/datatset/validation/Vehicle registration plate/ebaefbcb87bfa8a1.jpg: 448x640 1 reg plate, 9.7ms
# image 350/386 /kaggle/working/datatset/validation/Vehicle registration plate/ec8a36f7874c0c34.jpg: 480x640 1 reg plate, 9.7ms
# image 351/386 /kaggle/working/datatset/validation/Vehicle registration plate/ed7d99098d4af8e6.jpg: 480x640 1 reg plate, 9.0ms
# image 352/386 /kaggle/working/datatset/validation/Vehicle registration plate/edecf3a6d569b7c9.jpg: 640x448 1 reg plate, 45.2ms
# image 353/386 /kaggle/working/datatset/validation/Vehicle registration plate/ee047c8ca2cca8a2.jpg: 480x640 1 reg plate, 9.4ms
# image 354/386 /kaggle/working/datatset/validation/Vehicle registration plate/ef1bd7b718a3f6e8.jpg: 480x640 1 reg plate, 8.9ms
# image 355/386 /kaggle/working/datatset/validation/Vehicle registration plate/efde2a25c1c9c924.jpg: 448x640 1 reg plate, 9.8ms
# image 356/386 /kaggle/working/datatset/validation/Vehicle registration plate/f0c7057612710f21.jpg: 384x640 1 reg plate, 10.0ms
# image 357/386 /kaggle/working/datatset/validation/Vehicle registration plate/f1131b93a33cefb9.jpg: 448x640 1 reg plate, 9.5ms
# image 358/386 /kaggle/working/datatset/validation/Vehicle registration plate/f194eaf4f3d1d835.jpg: 480x640 1 reg plate, 9.5ms
# image 359/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3814f4a6121838d.jpg: 320x640 1 reg plate, 9.9ms
# image 360/386 /kaggle/working/datatset/validation/Vehicle registration plate/f38265abb22a00e4.jpg: 448x640 2 reg plates, 9.8ms
# image 361/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3bd3adea149193b.jpg: 448x640 1 reg plate, 10.6ms
# image 362/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3c9af100984744f.jpg: 480x640 2 reg plates, 9.5ms
# image 363/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3d472955c13cae0.jpg: 512x640 (no detections), 9.6ms
# image 364/386 /kaggle/working/datatset/validation/Vehicle registration plate/f5128e7a123b4fa8.jpg: 448x640 1 reg plate, 9.6ms
# image 365/386 /kaggle/working/datatset/validation/Vehicle registration plate/f53243c2bb551b8a.jpg: 448x640 (no detections), 9.5ms
# image 366/386 /kaggle/working/datatset/validation/Vehicle registration plate/f5c2a80a21ddb78c.jpg: 448x640 1 reg plate, 9.4ms
# image 367/386 /kaggle/working/datatset/validation/Vehicle registration plate/f5d1729aa333b284.jpg: 480x640 2 reg plates, 9.5ms
# image 368/386 /kaggle/working/datatset/validation/Vehicle registration plate/f6256bceaf66693f.jpg: 480x640 1 reg plate, 9.2ms
# image 369/386 /kaggle/working/datatset/validation/Vehicle registration plate/f700c5b69c973db6.jpg: 448x640 1 reg plate, 9.6ms
# image 370/386 /kaggle/working/datatset/validation/Vehicle registration plate/f73b754cdb1ab677.jpg: 448x640 1 reg plate, 9.0ms
# image 371/386 /kaggle/working/datatset/validation/Vehicle registration plate/f83d18919353c483.jpg: 448x640 1 reg plate, 8.7ms
# image 372/386 /kaggle/working/datatset/validation/Vehicle registration plate/f9170e8c13a99991.jpg: 544x640 1 reg plate, 9.2ms
# image 373/386 /kaggle/working/datatset/validation/Vehicle registration plate/f9f539977bfea25e.jpg: 448x640 1 reg plate, 10.1ms
# image 374/386 /kaggle/working/datatset/validation/Vehicle registration plate/fa897478280a2758.jpg: 480x640 1 reg plate, 9.4ms
# image 375/386 /kaggle/working/datatset/validation/Vehicle registration plate/fa9147596edc058f.jpg: 448x640 1 reg plate, 9.5ms
# image 376/386 /kaggle/working/datatset/validation/Vehicle registration plate/fb4e60b5cee8b88e.jpg: 640x416 2 reg plates, 9.5ms
# image 377/386 /kaggle/working/datatset/validation/Vehicle registration plate/fb55b73f241bf50a.jpg: 448x640 1 reg plate, 10.7ms
# image 378/386 /kaggle/working/datatset/validation/Vehicle registration plate/fc0a607ba5f38505.jpg: 448x640 1 reg plate, 9.0ms
# image 379/386 /kaggle/working/datatset/validation/Vehicle registration plate/fc0f46431cb1dbe9.jpg: 416x640 1 reg plate, 9.5ms
# image 380/386 /kaggle/working/datatset/validation/Vehicle registration plate/fd07d2db70cf53d5.jpg: 480x640 1 reg plate, 9.5ms
# image 381/386 /kaggle/working/datatset/validation/Vehicle registration plate/fdd963edc28bf163.jpg: 480x640 1 reg plate, 9.0ms
# image 382/386 /kaggle/working/datatset/validation/Vehicle registration plate/fe6139d150a3e2a8.jpg: 640x640 2 reg plates, 9.5ms
# image 383/386 /kaggle/working/datatset/validation/Vehicle registration plate/feaf383fc5de383f.jpg: 480x640 1 reg plate, 10.7ms
# image 384/386 /kaggle/working/datatset/validation/Vehicle registration plate/fed5c0275ff3a440.jpg: 448x640 2 reg plates, 9.4ms
# image 385/386 /kaggle/working/datatset/validation/Vehicle registration plate/ff69d090c735eccb.jpg: 480x640 1 reg plate, 11.2ms
# image 386/386 /kaggle/working/datatset/validation/Vehicle registration plate/ff85b09876d61631.jpg: 640x544 1 reg plate, 44.5ms
# Speed: 2.2ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode= val model='/kaggle/working/runs/detect/train2/weights/best.pt' source= '/kaggle/working/datatset/validation/Vehicle registration plate' data='data.yaml' save_json=True
# Out:
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /kaggle/working/datatset/validation/Vehicle registration plate.cac
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.936      0.864      0.917      0.679
# Speed: 0.6ms preprocess, 3.5ms inference, 0.0ms loss, 1.2ms postprocess per image
# Saving runs/detect/val8/predictions.json...
# Results saved to runs/detect/val8
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# #  <font style="color:green">3. Inference [15 Points]</font>
#
# **You have to make predictions from your trained model on three images from the validation dataset.**
#
# The plotted images should be similar to the following:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-p1.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-p2.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-p3.png'>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Assuming your predicted images are in the following directory
image_dir = "/kaggle/working/runs/detect/predict" 

# List of image file names (replace with your actual image names)
image_files = ["003a5aaf6d17c917.jpg", "fa9147596edc058f.jpg", "ff85b09876d61631.jpg"]

# Create a figure and axes
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Iterate through the images and display them
for i, file in enumerate(image_files):
    image_path = os.path.join(image_dir, file)
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].axis('off')  # Hide axes
    axes[i].set_title(f"Image {i+1}")

# Show the plot
plt.show()

# %% [markdown]
# #  <font style="color:green">4. COCO Detection Evaluation [25 Points]</font>
#
# **You have to evaluate your detection model on COCO detection evaluation metric.**
#
# For your reference here is the coco evaluation metric chart:
#
#
# ---
#
# <img src="https://www.learnopencv.com/wp-content/uploads/2020/03/c3-w9-coco_metric.png">
#
# ---
#
# #### <font style="color:red">The expected `AP` (primary challenge metric) is more than `0.5`.</font>
#
# **The expected output should look similar to the following:**
#
# ```
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.886
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.629
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.256
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.627
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.722
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
# ```

# %%
# !pip install pycocotools
# Out:
# Collecting pycocotools
#   Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 8.2 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.8

# %%
from pycocotools.cocoeval import COCOeval
from pycocotools.coco import COCO

# %%
import os
import json
from PIL import Image

createCocoLabelFile = True   # Do it only once
if createCocoLabelFile:
    # Paths to the images and labels folders
    images_path = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate'
    labels_path = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate/Label'  # Labels in special format

    # Initialize the COCO dataset structure
    coco_format = {
        "info": {
            "description": "Vehicle Registration Plates Dataset",
            "version": "1.0",
            "year": 2024,
            "contributor": "",
            "date_created": "2024-08-24"
        },
        "licenses": [],
        "images": [],
        "annotations": [],
        "categories": [
            {
                "id": 1,
                "name": "Vehicle registration plate",
                "supercategory": "object"
            }
        ]
    }

    # Function to create the COCO annotations from bounding box information
    def create_coco_annotation(ann_id, image_id, bbox, category_id=1):
        x_min, y_min, x_max, y_max = bbox
        width = x_max - x_min
        height = y_max - y_min
        area = width * height

        return {
            "id": ann_id,
            "image_id": image_id,
            "category_id": category_id,
            "bbox": [x_min, y_min, width, height],
            "area": area,
            "segmentation": [],
            "iscrowd": 0
        }

    # Process each image and its corresponding label
    image_id = 0
    ann_id = 0
    for image_filename in os.listdir(images_path):
        if image_filename.endswith(('.jpg', '.jpeg', '.png')):
            print(image_filename)
            image_id += 1

            # Read image to get dimensions
            image_path = os.path.join(images_path, image_filename)
            img = Image.open(image_path)
            width, height = img.size

            # Append image info to the COCO structure
            coco_format["images"].append({
                "id": image_id,
                "file_name": image_filename,
                "width": width,
                "height": height
            })

            # Get corresponding label file
            label_filename = os.path.splitext(image_filename)[0] + '.txt'
            label_path = os.path.join(labels_path, label_filename)

            # Check if the label file exists
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    for line in f:
                        parts = line.strip().split()
                        if len(parts) == 7 and parts[0] == 'Vehicle':
                            # Convert bounding box coordinates to float
                            bbox = list(map(float, parts[3:]))
                            annotation = create_coco_annotation(ann_id, image_id, bbox)
                            coco_format["annotations"].append(annotation)
                            ann_id += 1

    # Save the COCO-format JSON to a file
    with open('/kaggle/working/coco_ground_truth.json', 'w') as json_file:
        json.dump(coco_format, json_file, indent=4)

        print("COCO ground truth JSON file created successfully.")
# Out:
# 6504632e0dc25997.jpg
# 485e5f37dd13ffab.jpg
# a67bc3f5f8650c73.jpg
# 64de505bd2bac82b.jpg
# e57d38ae6a921518.jpg
# ea02d99ba51372ee.jpg
# 246a0e4264a39433.jpg
# a6e3b0b73220cd32.jpg
# fa9147596edc058f.jpg
# 0170ea8e1a33375a.jpg
# bbcac63e32bd8137.jpg
# cb8c75fc1c7ccf73.jpg
# 53ad98b12752ad16.jpg
# ef1bd7b718a3f6e8.jpg
# f73b754cdb1ab677.jpg
# 71dbb47ebe504abe.jpg
# 80e02a518ffe4cb2.jpg
# 86c92b0402fec141.jpg
# e9cd346a4a84d594.jpg
# b6e55f97085c3732.jpg
# 0f0596b1c511e071.jpg
# 302d636c896c263f.jpg
# 453a77009b27e253.jpg
# 7539902687e8f3a4.jpg
# 4ac941b9393d00f9.jpg
# 65e080f9ac466664.jpg
# aca8821ff0368720.jpg
# 0801961485534636.jpg
# 63d3df798bc8840f.jpg
# 61a69ad713142e45.jpg
# 16789af24af158d8.jpg
# a21aa7c1d7b93d12.jpg
# 182268e1f8c6525f.jpg
# b15d6c0bdf90226d.jpg
# 11f80fda2c38011c.jpg
# 5cc19b450a51ee4c.jpg
# e9fdd0a41cb61da6.jpg
# 288a95c01e43cd14.jpg
# 1545c73bdecb3e2f.jpg
# 1ca1155083156d72.jpg
# 091c033b2a7df15b.jpg
# e2427db217e5c3db.jpg
# bf2f25f3ed9ff4d5.jpg
# 59b83c5f8f1dcfa4.jpg
# e6299b9e04680adb.jpg
# 1ead26febde18ce9.jpg
# 8256e277c7f47797.jpg
# a3ad91fabd188be3.jpg
# aefe747315dd79fc.jpg
# 7bcf6b4ec09f1ea7.jpg
# 2956bcbedfc167b6.jpg
# c7b1e6f7c38fa1a0.jpg
# 76e14d05ee8acb6d.jpg
# efde2a25c1c9c924.jpg
# 4e593c88022ff6b1.jpg
# 1f34454c4c073e1b.jpg
# 7b4e86e1c94d65de.jpg
# 66771a4870c324f9.jpg
# 6306fc7f3573eb70.jpg
# 33e0333ff031c4fb.jpg
# d2fe2b47668e9d8e.jpg
# d53a3bc813477685.jpg
# d7d49b1a3706f3eb.jpg
# 125622a2508e3b1d.jpg
# 6c144e47161867c2.jpg
# 3d98e3713783e82d.jpg
# 2f90aaa72744452d.jpg
# 9995dfc6e0eae5a1.jpg
# 934645379fe657e1.jpg
# 1edfbe8c28a86caf.jpg
# 6e819dc674a74078.jpg
# fa897478280a2758.jpg
# 8cb5553e75d3d311.jpg
# 85b1dafd26aa98df.jpg
# 844adfe06e003c09.jpg
# da1352ab6054a2e4.jpg
# affd16c51644a893.jpg
# defd8f4b30b3e1e1.jpg
# 0673b967f8c68eec.jpg
# a929dc75c20da7d8.jpg
# d027c6e32db60e3c.jpg
# 52bf6b555e578a34.jpg
# 647ff22cf6950211.jpg
# 0e50ea14c4fc1353.jpg
# f3c9af100984744f.jpg
# 15a51e29f5ceffd8.jpg
# c50d184afad1a9dc.jpg
# abca9401dcf8f7ba.jpg
# 643c3cc1a4e85db2.jpg
# 908a3ac555a1a509.jpg
# 488722909dd9c0ac.jpg
# 0727983dd5f9e4e6.jpg
# 99732f172ac80128.jpg
# b01d46f9911d558b.jpg
# 49595029959689b7.jpg
# 4e2cb95b9c509b10.jpg
# 9034927e7438bdd6.jpg
# f5c2a80a21ddb78c.jpg
# 3feecc5809a29627.jpg
# 693acf98575cbe27.jpg
# 548a8e997a66a0c4.jpg
# 3e156de979eb0828.jpg
# 02a6ef3d9bd68e91.jpg
# de2b5afb7eda96cf.jpg
# ce97f7bc90e97109.jpg
# e1925cd0ae28fbd9.jpg
# 5290f4027491d09b.jpg
# 99c9c657582f958f.jpg
# 26192da5ce2afa62.jpg
# a72a8cda1bb31e34.jpg
# fc0f46431cb1dbe9.jpg
# 7f9740e95a74f2b9.jpg
# b6580dec5ada277d.jpg
# 3ecd5af7c4f11963.jpg
# be654a7eabe0e891.jpg
# 88fc866f92860d70.jpg
# fdd963edc28bf163.jpg
# b32671b7cc279583.jpg
# fb4e60b5cee8b88e.jpg
# fd07d2db70cf53d5.jpg
# 3e2306f2cf4b2c67.jpg
# b25d7d2cb7abf86b.jpg
# da8186b39f042cdf.jpg
# 11b155ab5b3331cf.jpg
# 50c37aeaf19acd5b.jpg
# b94993a2d67b455e.jpg
# b5e7183b6a5abe6c.jpg
# 8ceed1ec9bc3ac45.jpg
# 8c63cf76166c3bd7.jpg
# d9fa2abf3719a4bd.jpg
# 0cacb08195a3e2d7.jpg
# 2f3887024d298547.jpg
# 39c193bcc0c00f9e.jpg
# 53386dae3cf13cc3.jpg
# 4148b2126f0986a4.jpg
# 460753acbd6e6dad.jpg
# 3ed000628c6a0587.jpg
# c7df5232291486a3.jpg
# 4ff8bebd6d6a0361.jpg
# 9498d0aff8f9ff8c.jpg
# dec4608715b2d28d.jpg
# a54e7bb80448f3b0.jpg
# 43339d9cbca470e4.jpg
# f5d1729aa333b284.jpg
# 7f56adf4b9306ac9.jpg
# 057569768fd6303e.jpg
# 128a59bca025bed6.jpg
# 747b0f12f54703ee.jpg
# e08424f3cd5f6dac.jpg
# ff69d090c735eccb.jpg
# 54ebca2064066a49.jpg
# 081f5a6bc61b9c48.jpg
# b09813a8742277c7.jpg
# 2e95d7a799e23e11.jpg
# 326c3286bcb5b2b0.jpg
# b193070a9c45b5ab.jpg
# 35875c388efcddf0.jpg
# d6c5271e96ec1a61.jpg
# 43b1b0028dd2db8d.jpg
# 2619ec27a314e69c.jpg
# ee047c8ca2cca8a2.jpg
# cdb1e8621d1c624e.jpg
# 428a5131c8cff7da.jpg
# 2bd26c63ebf598b7.jpg
# f3814f4a6121838d.jpg
# 9286a99f243b359a.jpg
# 185fd6653258d3ed.jpg
# ec8a36f7874c0c34.jpg
# 70e7b5173fe1e289.jpg
# 29f7991e696e6e3f.jpg
# b101900b26128253.jpg
# c274e026ac907eb9.jpg
# c91ee912164d8ecb.jpg
# f700c5b69c973db6.jpg
# d830c3573e57bfc0.jpg
# 4b3aba5dfb7a0492.jpg
# 9ebbaf4d1f8d6e7b.jpg
# 1e6e75488d7878aa.jpg
# 3241f09a8964ddfb.jpg
# 69450fa183d57a7b.jpg
# 1f1d5bc31e444cc1.jpg
# f83d18919353c483.jpg
# 064a8def3049d040.jpg
# f0c7057612710f21.jpg
# e52d4f347b2cf90f.jpg
# d7b71c9fd144d58d.jpg
# 6eb18d1ad17cd174.jpg
# 4572990fd64bb6be.jpg
# fed5c0275ff3a440.jpg
# 1db3793d7c84faa1.jpg
# d3729058c6a4186e.jpg
# 228bd52bbe043677.jpg
# 4793138df3c05610.jpg
# 017527da8bfeb97d.jpg
# 8cca720c410ee7f8.jpg
# 621837d55c229864.jpg
# 08481c03daf6f35d.jpg
# 895d440e05b2a8d8.jpg
# e8b36c888a75d742.jpg
# d27e094e98374ff8.jpg
# b076ad266891d7aa.jpg
# 791d63b1c3499e4f.jpg
# f9170e8c13a99991.jpg
# 85ddb7e0f60156a3.jpg
# 23c2c79a9febbf3e.jpg
# 1a3e9d87d733ff7f.jpg
# 16c15b29b30148c2.jpg
# b6ecda23586a6ba5.jpg
# 548a985825bb991f.jpg
# daac3a6c64a79bea.jpg
# 5021041c726b6ee4.jpg
# d28d71c2690c16ed.jpg
# d5f4069e6734ac06.jpg
# 85f0b4db3eb512ce.jpg
# 749b4451492fc250.jpg
# 044417ca6134604f.jpg
# fb55b73f241bf50a.jpg
# 36d7b8b3cca3b0f5.jpg
# d44c0b2252bf8a92.jpg
# 5a3f94aa35766f31.jpg
# 09453a7c716a9ef3.jpg
# f194eaf4f3d1d835.jpg
# 98bcfbc4d3c8abbc.jpg
# b1a50a3824887ee2.jpg
# 80d21c58a71a0751.jpg
# 2d40d6e377c82ec9.jpg
# 2d6640fb230770fd.jpg
# d5058059dc0ce0ad.jpg
# 343326e127297379.jpg
# e1120bfe48f85c1b.jpg
# 894cacdb385fdb6b.jpg
# 37ff77d13a54aac2.jpg
# a52079c6cc4050cd.jpg
# 5df8816356fc2b29.jpg
# 724307be418b2ed2.jpg
# f38265abb22a00e4.jpg
# e82f13b4a2fe69f3.jpg
# ebaefbcb87bfa8a1.jpg
# 008637722500f239.jpg
# d59b7a0ff294e3be.jpg
# 06b024413ad385a7.jpg
# 003a5aaf6d17c917.jpg
# f3bd3adea149193b.jpg
# feaf383fc5de383f.jpg
# 1eb2ebab9cd7adf6.jpg
# 2fe1f00b77a110a0.jpg
# 4df1448703257ff0.jpg
# a56e82026bb71ad5.jpg
# f1131b93a33cefb9.jpg
# 315aead7766727b8.jpg
# 74ee6d1b58ae2e70.jpg
# 2e8a83cfb1afe7ba.jpg
# 90abd4265adf5a00.jpg
# 575d96d014e4fbab.jpg
# 28bd6c6b1050e055.jpg
# 6846c275ded01f85.jpg
# d8daed582e6cce2d.jpg
# 73467682c5995b65.jpg
# 88df55ff4e13b90d.jpg
# 44afab29f5fa0abf.jpg
# 9238f5062ff1dc8d.jpg
# e40cafe0f0d3a550.jpg
# 955a8e4c8ba8116e.jpg
# f53243c2bb551b8a.jpg
# b9f5b9acf1777acf.jpg
# ed7d99098d4af8e6.jpg
# 7fc0fb6035bc06a6.jpg
# 185d5dfa193c4ced.jpg
# 67c834b73882a9f9.jpg
# b7cdb5c0c99002b7.jpg
# 30b6cfb60bf44533.jpg
# f9f539977bfea25e.jpg
# 4c04b488ddc48225.jpg
# 5daafbcf76fa6602.jpg
# 0f4bfc46402a9f52.jpg
# b1096bc91a89b0cf.jpg
# 659dbf4f8c0fd29d.jpg
# 7cbc7ee444622a66.jpg
# bacc80fafc0566c3.jpg
# fe6139d150a3e2a8.jpg
# b8a3f2ea385e45b3.jpg
# b91c3aaba25bf914.jpg
# 1f0e643b125f00ec.jpg
# 62bb93bbd270dd9a.jpg
# 0787b0fa95f545a5.jpg
# 0fbd1b85fc01d2ae.jpg
# a774a6f81fea258b.jpg
# 12b7ea40074d3b20.jpg
# 6aff04e9c32aec0f.jpg
# 508f0a75156e5fd4.jpg
# a79296fb4a48245e.jpg
# 7a1f9520c7ecd5b1.jpg
# 5fb888d79b551331.jpg
# 133921bd26fff729.jpg
# d8cc6d566d01054b.jpg
# 90596bf3313e72e3.jpg
# 5373ec295ea62c47.jpg
# 25d5c2fbd8b99662.jpg
# 67945cf7a6beccdf.jpg
# 6b113b3edbadfe5d.jpg
# e9561d7c16db565f.jpg
# 2b97f5bf137ee8d1.jpg
# 2c09fab0221652c5.jpg
# 28e26a4eb646c67a.jpg
# 5641e6ad7d2600f2.jpg
# a5d6f8d36672fa64.jpg
# b3b61da98e22cd4a.jpg
# e5edf93b7c9f5edb.jpg
# e79f6777f2fc08b2.jpg
# 0ee91c4938b6e7ee.jpg
# 0d6ca8553971fefd.jpg
# 71881a9c0f7f0a86.jpg
# ff85b09876d61631.jpg
# 7275e72e1996267f.jpg
# c650ff8d3e8e75b3.jpg
# 77e716224c85410f.jpg
# ad10c7d29f111692.jpg
# f5128e7a123b4fa8.jpg
# 415d64bf8cfe82f2.jpg
# fc0a607ba5f38505.jpg
# 52ceb1fc30b413e5.jpg
# 140e8d10ff02e7e7.jpg
# 299f0363ae21d1c3.jpg
# 03b7b71e1ffcb7a8.jpg
# 9a4fe6361597f264.jpg
# 4cb48c8bf41b70a4.jpg
# 4ee3f0e9a2fb20a9.jpg
# 5581a1b7d2f0f2b4.jpg
# ccc1a2d44a290368.jpg
# 620bd952592bc0e9.jpg
# 53925df03b471f5d.jpg
# 911e694dcc0814bf.jpg
# be9fd0014b5a4f2a.jpg
# 19eba8ac64eed194.jpg
# d565d93637d4e76d.jpg
# edecf3a6d569b7c9.jpg
# a823532e163f5722.jpg
# b57fe3aa2ff9577e.jpg
# 28d1fb27a6e42ee7.jpg
# 50631041f74001aa.jpg
# 00723dac8201a83e.jpg
# 5ff91ccfc6f15d04.jpg
# 321ffb38656f7311.jpg
# 665cac5fd1cc2186.jpg
# 628a23a43f19c4db.jpg
# 593e594137f374ab.jpg
# aac1aaaf824b63dd.jpg
# d648b2ae1abc09f3.jpg
# 5a96f5e1f9be8d42.jpg
# bf0aac0878b0a3d2.jpg
# e742e284c7c9da96.jpg
# 46a7991da6461831.jpg
# 17585ef2efb5ef9b.jpg
# 1071b237587a698b.jpg
# c1d8b110186e095a.jpg
# f3d472955c13cae0.jpg
# 2a3e44107826e876.jpg
# d8f6c135ec5486ff.jpg
# 82b53fe7f9147c96.jpg
# 2753536137929411.jpg
# 334f31e809ec9a77.jpg
# 944281d0485869f0.jpg
# 87793700161a7a6b.jpg
# bd12ea92bcab1afd.jpg
# e4d600a63db8bf3a.jpg
# cb4b754537798d23.jpg
# 87b4f1202cd06440.jpg
# 27798906120ea394.jpg
# 4fa24c1abe969cb7.jpg
# 12d3b6665f7e1cf6.jpg
# 19ff847d0cd1c5ec.jpg
# 932eef14e5ee78b2.jpg
# 9c92cadb0f6237c0.jpg
# f6256bceaf66693f.jpg
# 54bd93e5a4de808a.jpg
# 5a122adbb1a776b7.jpg
# 18098dc9ee6aad80.jpg
# 2adddd0b09bb0f17.jpg
# 66be6b583048fa94.jpg
# ae6724423f0d111a.jpg
# 9a795bbf4e94d630.jpg
# 8cdcb833ef1ef049.jpg
# 6a0ef049e5ec4b16.jpg
# a9b2a2018f845393.jpg
# 26183d88c4f8012f.jpg
# 0c756c9366a8cb10.jpg
# COCO ground truth JSON file created successfully.

# %%
def load_coco_image_mapping(gt_annotations_path):
    # Load the COCO ground truth annotations and create a mapping from filenames to image IDs.
    coco_gt = COCO(gt_annotations_path)
    img_filename_to_id = {img['file_name']: img['id'] for img in coco_gt.loadImgs(coco_gt.getImgIds())}
    return img_filename_to_id

def convert_yolo_to_coco(yolo_json_path, img_filename_to_id_map):
    # Convert YOLO predictions to COCO format and replace the image filename with the corresponding image ID.
    with open(yolo_json_path, 'r') as f:
        yolo_predictions = json.load(f)

    coco_predictions = []
    for pred in yolo_predictions:
        img_filename  = str(pred['image_id']) + '.jpg' # directly using image_id as the filename
        if img_filename in img_filename_to_id_map:
            
            img_id = img_filename_to_id_map[img_filename]
            category_id = pred['category_id']+1
            x_min, y_min, width, height = pred['bbox']
        

            coco_pred = {
                "image_id": img_id,
                "category_id": category_id,  # COCO category IDs start at 1, not 0
                "bbox": [x_min, y_min, width, height],
                "score": pred['score']
            }
            coco_predictions.append(coco_pred)

    return coco_predictions

def compute_coco_metrics(gt_annotations_path, pred_annotations):
    # Compute COCO metrics based on ground truth and prediction annotations.
    
    # Load ground truth in COCO format
    coco_gt = COCO(gt_annotations_path)
    
    # Convert predictions to COCO format
    coco_dt = coco_gt.loadRes(pred_annotations)
    
    # Initialize COCO evaluation
    coco_eval = COCOeval(coco_gt, coco_dt, 'bbox')
    
    # Run evaluation
    coco_eval.evaluate()
    coco_eval.accumulate()
    coco_eval.summarize()

    # Extract metrics
    metrics = [
        coco_eval.stats[0],  # AP
        coco_eval.stats[1],  # AP50
        coco_eval.stats[2],  # AP75
        coco_eval.stats[3],  # APs
        coco_eval.stats[4],  # APm
        coco_eval.stats[5],  # APl
        coco_eval.stats[6],  # AR1
        coco_eval.stats[7],  # AR10
        coco_eval.stats[8],  # AR100
        coco_eval.stats[9],  # ARs
        coco_eval.stats[10], # ARm
        coco_eval.stats[11]  # ARl
    ]
    
    return metrics

# Paths to the COCO ground truth annotations and YOLO predictions JSON files
gt_annotations_path = '/kaggle/working/coco_ground_truth.json'  # Created in CreateCocoGtFile.py
yolo_json_path = '/kaggle/working/runs/detect/val8/predictions.json'

# Load mapping from image filenames to COCO Image IDs
img_filename_to_id_map = load_coco_image_mapping(gt_annotations_path)

# Convert YOLO predictions to COCO format
coco_predictions = convert_yolo_to_coco(yolo_json_path, img_filename_to_id_map)

# Save the converted predictions to a new JSON file
pred_annotations_path = 'converted_yolo_predictions.json'
with open(pred_annotations_path, 'w') as f:
    json.dump(coco_predictions, f)

# Check if the JSON file is empty or improperly formatted
if not coco_predictions:
    print("No predictions available for evaluation.")
else:
    print("YOLO predictions are ready for evaluation.")
    # Compute COCO metrics
    metrics = compute_coco_metrics(gt_annotations_path, pred_annotations_path)
    print("COCO Metrics:", metrics)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# YOLO predictions are ready for evaluation.
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.45s).
# Accumulating evaluation results...
# DONE (t=0.11s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.904
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.793
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.734
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.741
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.747
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.848
# COCO Metrics: [0.6714529358463261, 0.9039071339229384, 0.7928849654258314, 0.34662307202634135, 0.7336753581368468, 0.7997679952383898, 0.60390625, 0.7412109375, 0.747265625, 0.49593495934959353, 0.807843137254902, 0.8475675675675676]

# %% [markdown]
# # <font style="color:green">5. Run Inference on a Video [15 Points]</font>
#
# #### [Download the Input Video](https://www.dropbox.com/s/g88o4dx18zpgn8k/projet3-input-video.mp4?dl=1)
#
# **You have to run inference on a video.**
#
# You can download the video from [here](https://www.dropbox.com/s/g88o4dx18zpgn8k/projet3-input-video.mp4?dl=1).
#
# #### <font style="color:red">Upload the output video on youtube and share the link. Do not upload the video in the lab.</font>

# %%
https://youtu.be/8MEb1RHeghA

# %%
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("18HWHCevFdU", width=640, height=360)
display(video)

# %% [markdown]
# **Your output video should have a bounding box around the vehicle registration plate.**

# %%
video = YouTubeVideo("5SgCuee7AMs", width=640, height=360)
display(video)

# %% [markdown]
# **You can use the following sample code to read and write a video.**

# %%
from ultralytics import YOLO


model = YOLO("/kaggle/working/runs/detect/train2/weights/best.pt")  # load a custom model

# Predict with the model
results = model.predict("/kaggle/input/input-video/projet3-input-video.mp4", conf=0.5, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.4ms
# video 1/1 (frame 2/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 3/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.0ms
# video 1/1 (frame 4/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 5/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 6/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 7/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 8/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 9/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 10/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 11/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 12/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 13/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 14/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 15/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 16/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 17/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 18/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 19/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 20/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 21/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.6ms
# video 1/1 (frame 22/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# video 1/1 (frame 23/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.5ms
# video 1/1 (frame 24/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 25/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 26/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# video 1/1 (frame 27/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.4ms
# video 1/1 (frame 28/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 29/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.6ms
# video 1/1 (frame 30/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# video 1/1 (frame 31/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 32/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.6ms
# video 1/1 (frame 33/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.4ms
# video 1/1 (frame 34/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 35/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.7ms
# video 1/1 (frame 36/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 37/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.6ms
# video 1/1 (frame 38/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 39/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.5ms
# video 1/1 (frame 40/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 41/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 42/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 43/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.9ms
# video 1/1 (frame 44/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 45/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 11.0ms
# video 1/1 (frame 46/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 47/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 13.0ms
# video 1/1 (frame 48/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 49/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# video 1/1 (frame 50/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 11.9ms
# video 1/1 (frame 51/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.9ms
# video 1/1 (frame 52/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 53/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.8ms
# video 1/1 (frame 54/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 55/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 56/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 57/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.0ms
# video 1/1 (frame 58/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.6ms
# video 1/1 (frame 59/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.9ms
# video 1/1 (frame 60/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.0ms
# video 1/1 (frame 61/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.0ms
# video 1/1 (frame 62/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 63/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 64/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# video 1/1 (frame 65/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.0ms
# video 1/1 (frame 66/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.1ms
# video 1/1 (frame 67/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.6ms
# video 1/1 (frame 68/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.2ms
# video 1/1 (frame 69/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 70/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.5ms
# video 1/1 (frame 71/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.3ms
# video 1/1 (frame 72/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# video 1/1 (frame 73/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 74/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 75/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 76/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.9ms
# video 1/1 (frame 77/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 11.9ms
# video 1/1 (frame 78/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 79/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 80/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 11.0ms
# video 1/1 (frame 81/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 82/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 83/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 84/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 85/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.0ms
# video 1/1 (frame 86/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 87/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.4ms
# video 1/1 (frame 88/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.0ms
# video 1/1 (frame 89/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.0ms
# video 1/1 (frame 90/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 11.1ms
# video 1/1 (frame 91/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 92/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (frame 93/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 94/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 95/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 96/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.2ms
# video 1/1 (frame 97/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 98/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 99/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 100/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.1ms
# video 1/1 (frame 101/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 102/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.1ms
# video 1/1 (frame 103/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.1ms
# video 1/1 (frame 104/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.4ms
# video 1/1 (frame 105/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 106/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.0ms
# video 1/1 (frame 107/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.8ms
# video 1/1 (frame 108/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 109/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 110/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 11.9ms
# video 1/1 (frame 111/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.1ms
# video 1/1 (frame 112/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 113/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.1ms
# video 1/1 (frame 114/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.1ms
# video 1/1 (frame 115/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.1ms
# video 1/1 (frame 116/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.1ms
# video 1/1 (frame 117/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 14.2ms
# video 1/1 (frame 118/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 14.4ms
# video 1/1 (frame 119/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.7ms
# video 1/1 (frame 120/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# video 1/1 (frame 121/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.1ms
# video 1/1 (frame 122/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 123/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.0ms
# video 1/1 (frame 124/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.8ms
# video 1/1 (frame 125/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 126/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 127/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 11.0ms
# video 1/1 (frame 128/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.0ms
# video 1/1 (frame 129/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 2 reg plates, 9.9ms
# video 1/1 (frame 130/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 2 reg plates, 9.9ms
# video 1/1 (frame 131/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.9ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
def video_read_write(video_path):
    """
    Read video frames one-by-one, flip it, and write in the other video.
    video_path (str): path/to/video
    """
    video = cv2.VideoCapture(video_path)
    
    # Check if camera opened successfully
    if not video.isOpened(): 
        print("Error opening video file")
        return
    
    # create video writer
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frames_per_second = video.get(cv2.CAP_PROP_FPS)
    num_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    
    output_fname = '{}_out.mp4'.format(os.path.splitext(video_path)[0])
    
    output_file = cv2.VideoWriter(
        filename=output_fname,
        # some installation of opencv may not support x264 (due to its license),
        # you can try other format (e.g. MPEG)
        fourcc = cv2.VideoWriter_fourcc(*'mpeg'),
        
        fps=float(frames_per_second),
        frameSize=(width, height),
        isColor=True,
    )
    
        
    i = 0
    while video.isOpened():
        ret, frame = video.read()
        if ret:
            
            output_file.write(frame[:, ::1, :])
#             cv2.imwrite('anpd_out/frame_{}.png'.format(str(i).zfill(3)), frame[:, ::-1, :])
            i += 1
        else:
            break
        
    video.release()
    output_file.release()
    
    return

# %%
video_read_write('/kaggle/working/runs/detect/predict2/projet3-input-video.avi')
# Out:
# OpenCV: FFMPEG: tag 0x6765706d/'mpeg' is not supported with codec id 2 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
