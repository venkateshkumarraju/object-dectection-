# %% [markdown]
# ### <font style="color:purple">Download the Dataset</font>
#
# **[Download the Vehicle registration plate](https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1)**
#
#
# Download the Vehicle Registration Plate dataset from [here](https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1) and unzip it.
#
# We will have the following directory structure:
#
# ```
# Dataset
# ├── train
# │   └── Vehicle registration plate
# │       └── Label
# └── validation
#     └── Vehicle registration plate
#         └── Label
# ```
#
# Unzipping the file will give you a directory `Dataset`. This directory has two folder `train` and `validation`. Each train and validation folder has `Vehicle registration plate`  folder with `.jpg` images and a folder `Labels`.  `Labels` folder has bounding box data for the images.
#
#
# For example,
# For image: `Dataset/train/Vehicle registration plate/bf4689922cdfd532.jpg`
# Label file is  `Dataset/train/Vehicle registration plate/Label/bf4689922cdfd532.txt`
#
# There are one or more lines in each `.txt` file. Each line represents one bounding box.
# For example,
# ```
# Vehicle registration plate 385.28 445.15 618.24 514.225
# Vehicle registration plate 839.68 266.066462 874.24 289.091462
# ```
#
# We have a single class detection (`Vehicle registration plate detection`) problem. So bounding box details start from the fourth column in each row.
#
# Representation is in `xmin`, `ymin`, `xmax`, and `ymax` format.
#
# **It has `5308` training and `386` validation dataset.**
#
# Data is downloaded from [Open Images Dataset](https://storage.googleapis.com/openimages/web/index.html)

# %% [markdown]
# # <font style="color:blue">Project 3: Object Detection</font>
#
#
# #### Maximum Points: 100
#
# <div>
#     <table>
#         <tr><td><h3>Sr. no.</h3></td> <td><h3>Section</h3></td> <td><h3>Points</h3></td> </tr>
#         <tr><td><h3>1</h3></td> <td><h3>Plot Ground Truth Bounding Boxes</h3></td> <td><h3>20</h3></td> </tr>
#         <tr><td><h3>2</h3></td> <td><h3>Training</h3></td> <td><h3>25</h3></td> </tr>
#         <tr><td><h3>3</h3></td> <td><h3>Inference</h3></td> <td><h3>15</h3></td> </tr>
#         <tr><td><h3>4</h3></td> <td><h3>COCO Detection Evaluation</h3></td> <td><h3>25</h3></td> </tr>
#         <tr><td><h3>5</h3></td> <td><h3>Run Inference on a Video</h3></td> <td><h3>15</h3></td> </tr>
#     </table>
# </div>

# %% [markdown]
# #  <font style="color:green">1. Plot Ground Truth Bounding Boxes [20 Points]</font>
#
# **You have to show three images from validation data with the bounding boxes.**
#
# The plotted images should be similar to the following:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-g1.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-g2.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-g3.png'>

# %%
import os
import glob
import cv2
import matplotlib.pyplot as plt

# Function to read and process each label file
def read_label_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        boxes = []
        for line in lines:
            parts = line.strip().split()
            x_min = float(parts[3])
            y_min = float(parts[4])
            x_max = float(parts[5])
            y_max = float(parts[6])
            boxes.append((x_min, y_min, x_max, y_max))
    return boxes

# Function to draw bounding boxes on an image
def draw_bounding_boxes(image_path, boxes):
    image = cv2.imread(image_path)
    label='reg_plate'
    for (x_min, y_min, x_max, y_max) in boxes:
        cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)
        cv2.putText(image, label, (int(x_min), int(y_min) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return image

# Paths to the validation directories
validation_dir = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate'
label_dir = os.path.join(validation_dir, 'Label')

# Get a list of all image files and their corresponding label files
image_files = glob.glob(os.path.join(validation_dir, '*.jpg'))
label_files = [os.path.join(label_dir, os.path.basename(f).replace('.jpg', '.txt')) for f in image_files]

# Display three images with bounding boxes
plt.figure(figsize=(15, 10))
for i in range(3):
    image_path = image_files[i]
    label_path = label_files[i]
    boxes = read_label_file(label_path)
    image_with_boxes = draw_bounding_boxes(image_path, boxes)
    
    plt.subplot(1, 3, i+1)
    plt.imshow(cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB))
    plt.title(f'Image {i+1}')
    plt.axis('off')

plt.show()

# %%
import os
import shutil

def copy_files(src_dir, dst_dir):
    # Create the destination directory if it doesn't exist
    if not os.path.exists(dst_dir):
        os.makedirs(dst_dir)

    # Walk through the source directory
    for root, dirs, files in os.walk(src_dir):
        for dir_name in dirs:
            src_subdir = os.path.join(root, dir_name)
            dst_subdir = os.path.join(dst_dir, dir_name)
            shutil.copytree(src_subdir, dst_subdir)

# Specify your source and destination directories
src_dataset_dir = '/kaggle/input/object-dectection-num-plate/Dataset'  # Replace with your actual dataset path
dst_copy_dir = '/kaggle/working/datatset'  # Replace with your desired copy destination

# Copy the dataset without label folders
copy_files(os.path.join(src_dataset_dir, 'train'), os.path.join(dst_copy_dir, 'train'))
copy_files(os.path.join(src_dataset_dir, 'validation'), os.path.join(dst_copy_dir, 'validation'))

print("Dataset copied")
# Out:
# Dataset copied

# %%
import os
import glob
import cv2

# Function to read and process each label file
def read_label_file(file_path, image_width, image_height):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        boxes = []
        for line in lines:
            parts = line.strip().split()
            x_min = float(parts[3])
            y_min = float(parts[4])
            x_max = float(parts[5])
            y_max = float(parts[6])

            x_center = ((x_min + x_max) / 2) / image_width
            y_center = ((y_min + y_max) / 2) / image_height
            width = (x_max - x_min) / image_width
            height = (y_max - y_min) / image_height

            boxes.append(f"0 {x_center} {y_center} {width} {height}")
    return boxes

# Paths to the directories
train_images_dir = '/kaggle/working/datatset/train/Vehicle registration plate'
train_labels_dir = '/kaggle/input/object-dectection-num-plate/Dataset/train/Vehicle registration plate/Label'

# Get a list of all image files and their corresponding label files
image_files = glob.glob(os.path.join(train_images_dir, '*.jpg'))
label_files = [os.path.join(train_labels_dir, os.path.basename(f).replace('.jpg', '.txt')) for f in image_files]

for i in range(len(image_files)):
    image_path = image_files[i]
    label_path = label_files[i]
    
    # Get image dimensions
    image = cv2.imread(image_path)
    image_height, image_width, _ = image.shape

    # Create the output directory if it doesn't exist
    output_dir = "/kaggle/working/datatset/train/Vehicle registration plate"
    os.makedirs(output_dir, exist_ok=True)

    # Create the output label file path
    output_label_path = os.path.join(output_dir, os.path.basename(label_path))
    
    boxes = read_label_file(label_path, image_width, image_height)
    
    with open(output_label_path, 'w') as f:
        for box in boxes:
            f.write(box + '\n')

# %%
# Paths to the directories
val_images_dir = '/kaggle/working/datatset/validation/Vehicle registration plate'
val_labels_dir = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate/Label'

# Get a list of all image files and their corresponding label files
image_files = glob.glob(os.path.join(val_images_dir, '*.jpg'))
label_files = [os.path.join(val_labels_dir, os.path.basename(f).replace('.jpg', '.txt')) for f in image_files]

for i in range(len(image_files)):
    image_path = image_files[i]
    label_path = label_files[i]
    
    # Get image dimensions
    image = cv2.imread(image_path)
    image_height, image_width, _ = image.shape

    # Create the output directory if it doesn't exist
    output_dir = "/kaggle/working/datatset/validation/Vehicle registration plate"
    os.makedirs(output_dir, exist_ok=True)

    # Create the output label file path
    output_label_path = os.path.join(output_dir, os.path.basename(label_path))
    
    boxes = read_label_file(label_path, image_width, image_height)
    
    with open(output_label_path, 'w') as f:
        for box in boxes:
            
            f.write(box + '\n')

# %%
import os
import glob

def read_and_print_labels(folder_path):
  """
  Reads and prints the contents of all label files in the specified folder.

  Args:
    folder_path: The path to the folder containing the label files.
  """
  for filename in glob.glob(os.path.join(folder_path, '*.txt')):
    with open(filename, 'r') as f:
        print(f'Filename: {filename}')
        print(f.read())

# Example usage:
folder_path = '/kaggle/working/datatset/train/Vehicle registration plate'
read_and_print_labels(folder_path)
folder_path = '/kaggle/working/datatset/validation/Vehicle registration plate'
read_and_print_labels(folder_path)
# Out:
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/51d1c20df69e533c.txt
# 0 0.10573250000000001 0.4890625 0.043313000000000004 0.020625000000000004
# 0 0.73758 0.6853125 0.08662400000000005 0.05312500000000009
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/19df9430a10e9a26.txt
# 0 0.7090625 0.2861165 0.005624999999999991 0.009381000000000023
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c87d08012c7064ab.txt
# 0 0.318125 0.40291649999999996 0.03375 0.025832999999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/47b976afcdaff6fa.txt
# 0 0.208125 0.5182925000000002 0.095 0.10412700000000008
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/f1635340b2be2e7d.txt
# 0 0.5054685 0.9632814999999999 0.264063 0.07031299999999996
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/74573609760be750.txt
# 0 0.13208299999999998 0.7778125 0.1625 0.07437499999999997
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/f0c9c06039ef51c6.txt
# 0 0.0640625 0.42167 0.128125 0.35365800000000003
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/36b8b9b9ac119187.txt
# 0 0.723125 0.5219834999999999 0.23750000000000004 0.16276900000000002
# 0 0.9928125 0.16697849999999997 0.013125000000000053 0.03648300000000001
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/379b34acaa12842a.txt
# 0 0.35 0.9183864999999999 0.10874999999999996 0.08442699999999997
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/1de496db40f54940.txt
# 0 0.5015625 0.6210935 0.02500100000000005 0.017186999999999952
# 0 0.611719 0.8109375 0.03906199999999993 0.034375000000000044
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/dc882ca05aa68263.txt
# 0 0.354375 0.547083 0.37000000000000005 0.32249999999999995
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/9c264204a8201c67.txt
# 0 0.9284375 0.9129169999999999 0.05437499999999995 0.017499999999999922
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/c8d01e3f271276b9.txt
# 0 0.27375 0.6777675 0.12 0.07786099999999997
# 0 0.99125 0.2368665 0.01375000000000004 0.034709000000000025
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate/d28ccf7a2b43a3a9.txt
# 0 0.8887499999999999 0.4199625 0.04999999999999993 0.01694899999999995
# 0 0.9734375 0.46563099999999996 0.051875000000000004 0.03295599999999999
#
# Filename: /kaggle/working/datatset/train/Vehicle registration plate
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/e1925cd0ae28fbd9.txt
# 0 0.5097005 0.631837 0.11587499999999995 0.076502
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/cb4b754537798d23.txt
# 0 0.021204 0.533175 0.042408 0.028624000000000063
# 0 0.5581855 0.7261545 0.13135500000000006 0.04261699999999999
# 0 0.928987 0.7075955 0.11402199999999996 0.04399100000000001
#
# Filename: /kaggle/working/datatset/validation/Vehicle registration plate/defd8f4b30b3e1e1.txt
# 0 0.22555199999999997 0.559558 0.13558599999999998 0.1750719999999998

# %% [markdown]
# #  <font style="color:green">2. Training [25 Points]</font>
#
# - **Write your training code in this section.**
#
# - **You also have to share ([shared logs example](https://tensorboard.dev/experiment/JRtnsKbwTaq1ow6nPLPGeg)) the loss plot of your training using tensorboard.dev.**
#
# How to share TensorBoard logs using tensorboard.dev find [here](https://courses.opencv.org/courses/course-v1:OpenCV+OpenCV-106+2019_T1/courseware/b1c43ffe765246658e537109e188addb/d62572ec8bd344db9aeae81235ede618/4?activate_block_id=block-v1%3AOpenCV%2BOpenCV-106%2B2019_T1%2Btype%40vertical%2Bblock%40398b46ddcd5c465fa52cb4d572ba3229).

# %%
# !nvidia-smi
# Out:
# Sat Oct  5 09:04:25 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %%writefile data.yaml
# path: '/kaggle/working/datatset' # dataset root dir
# train: '/kaggle/working/datatset/train/Vehicle registration plate'
# val: '/kaggle/working/datatset/validation/Vehicle registration plate'
# nc: 1
# names: ['reg plate']
# Out:
# Writing data.yaml

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.5 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
# !pip install yolov8
# Out:
# Collecting yolov8
#   Downloading yolov8-0.0.2-py37.py38.py39-none-any.whl.metadata (2.0 kB)
# Collecting yolov5 (from yolov8)
#   Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl.metadata (10 kB)
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (10.3.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (5.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (1.14.1)
# Collecting thop>=0.1.1 (from yolov5->yolov8)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.4.0)
# Requirement already satisfied: torchvision>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (4.66.4)
# Requirement already satisfied: ultralytics>=8.0.100 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (8.3.5)
# Requirement already satisfied: tensorboard>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.16.2)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (70.0.0)
# Collecting fire (from yolov5->yolov8)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: boto3>=1.19.1 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (1.26.100)
# Collecting sahi>=0.11.10 (from yolov5->yolov8)
#   Downloading sahi-0.11.18-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.12.0 in /opt/conda/lib/python3.10/site-packages (from yolov5->yolov8) (0.25.1)
# Collecting roboflow>=0.2.29 (from yolov5->yolov8)
#   Downloading roboflow-1.1.47-py3-none-any.whl.metadata (9.7 kB)
# Collecting botocore<1.30.0,>=1.29.100 (from boto3>=1.19.1->yolov5->yolov8)
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.19.1->yolov5->yolov8) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3>=1.19.1->yolov5->yolov8) (0.6.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython>=3.1.30->yolov5->yolov8) (4.0.11)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.12.0->yolov5->yolov8) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3->yolov5->yolov8) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->yolov5->yolov8) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->yolov5->yolov8) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->yolov5->yolov8) (2024.8.30)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (4.10.0.84)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (1.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (1.16.0)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow>=0.2.29->yolov5->yolov8) (0.10.1)
# Collecting filetype (from roboflow>=0.2.29->yolov5->yolov8)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting opencv-python>=4.1.1 (from yolov5->yolov8)
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from sahi>=0.11.10->yolov5->yolov8) (1.8.5.post1)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5->yolov8)
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting terminaltables (from sahi>=0.11.10->yolov5->yolov8)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from sahi>=0.11.10->yolov5->yolov8) (8.1.7)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.4.1->yolov5->yolov8) (3.0.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->yolov5->yolov8) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->yolov5->yolov8) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.7.0->yolov5->yolov8) (3.1.4)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.100->yolov5->yolov8) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics>=8.0.100->yolov5->yolov8) (2.0.8)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire->yolov5->yolov8) (2.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5->yolov8) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5->yolov8) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.7.0->yolov5->yolov8) (1.3.0)
# Downloading yolov8-0.0.2-py37.py38.py39-none-any.whl (1.9 kB)
# Downloading yolov5-7.0.13-py37.py38.py39.py310-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 18.6 MB/s eta 0:00:00a 0:00:01
# Downloading roboflow-1.1.47-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 6.9 MB/s eta 0:00:00
# Downloading sahi-0.11.18-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 10.4 MB/s eta 0:00:00
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 27.1 MB/s eta 0:00:00:00:0100:01
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 93.0 MB/s eta 0:00:00:00:010:01
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114248 sha256=bf86ecd7ef9bd4fea0d770cba3fe51f5e4e9677c0ad1f630f5ccecbd4625b4cb
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# Installing collected packages: filetype, terminaltables, pybboxes, opencv-python, fire, sahi, botocore, thop, roboflow, yolov5, yolov8
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.35.23
#     Uninstalling botocore-1.35.23:
#       Successfully uninstalled botocore-1.35.23
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.15.1 requires botocore<1.35.24,>=1.35.16, but you have botocore 1.29.165 which is incompatible.
# Successfully installed botocore-1.29.165 filetype-1.2.0 fire-0.7.0 opencv-python-4.9.0.80 pybboxes-0.1.6 roboflow-1.1.47 sahi-0.11.18 terminaltables-3.1.10 thop-0.1.1.post2209072238 yolov5-7.0.13 yolov8-0.0.2

# %%
# !yolo train model=yolo11n.pt data='data.yaml' epochs=50 imgsz=640
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 63.8MB/s]
# Ultralytics 8.3.5 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 14.6MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/datatset/train/Vehicle registration plate... 530
# train: New cache created: /kaggle/working/datatset/train/Vehicle registration plate.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/datatset/validation/Vehicle registration plate...
# val: New cache created: /kaggle/working/datatset/validation/Vehicle registration plate.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.39G      1.558      2.297      1.208         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.706      0.652      0.688      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.37G      1.666      1.459      1.232         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.817      0.621      0.726      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.43G      1.672      1.317      1.257         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.746      0.693       0.72      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.42G      1.642      1.238      1.243         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.766      0.721      0.757      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.41G      1.606      1.174      1.215         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.842      0.744      0.811      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.36G      1.569      1.101      1.206         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.863      0.741      0.823      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.45G      1.547      1.054        1.2         43        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.895      0.764      0.851      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.38G      1.553      1.035      1.191         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.879       0.77      0.815      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.38G      1.522      1.013      1.182         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.882      0.791      0.855       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.41G      1.506      1.003      1.169         17        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.898      0.754      0.849      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.44G       1.49     0.9769      1.163         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.933      0.791      0.865      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.41G      1.484      0.959      1.164         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.871      0.801      0.856      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.49G      1.457     0.9219      1.144         16        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.908      0.825      0.871      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.44G      1.448     0.9219      1.139         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.923       0.82      0.883      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.42G      1.443     0.9052      1.143         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.929      0.817      0.887      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.36G      1.431     0.8934      1.133         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.909      0.815      0.892       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2
# image 6/386 /kaggle/working/datatset/validation/Vehicle registration plate/02a6ef3d9bd68e91.jpg: 480x640 2 reg plates, 9.2ms
# image 7/386 /kaggle/working/datatset/validation/Vehicle registration plate/03b7b71e1ffcb7a8.jpg: 448x640 1 reg plate, 11.6ms
# image 8/386 /kaggle/working/datatset/validation/Vehicle registration plate/044417ca6134604f.jpg: 448x640 1 reg plate, 10.4ms
# image 9/386 /kaggle/working/datatset/validation/Vehicle registration plate/057569768fd6303e.jpg: 480x640 2 reg plates, 9.4ms
# image 10/386 /kaggle/working/datatset/validation/Vehicle registration plate/064a8def3049d040.jpg: 448x640 1 reg plate, 9.8ms
# image 11/386 /kaggle/working/datatset/validation/Vehicle registration plate/0673b967f8c68eec.jpg: 480x640 1 reg plate, 9.6ms
# image 12/386 /kaggle/working/datatset/validation/Vehicle registration plate/06b024413ad385a7.jpg: 512x640 1 reg plate, 47.9ms
# image 13/386 /kaggle/working/datatset/validation/Vehicle registration plate/0727983dd5f9e4e6.jpg: 480x640 1 reg plate, 10.6ms
# image 14/386 /kaggle/working/datatset/validation/Vehicle registration plate/0787b0fa95f545a5.jpg: 576x640 1 reg plate, 47.2ms
# image 15/386 /kaggle/working/datatset/validation/Vehicle registration plate/0801961485534636.jpg: 480x640 1 reg plate, 9.3ms
# image 16/386 /kaggle/working/datatset/validation/Vehicle registration plate/081f5a6bc61b9c48.jpg: 480x640 1 reg plate, 8.6ms
# image 17/386 /kaggle/working/datatset/validation/Vehicle registration plate/08481c03daf6f35d.jpg: 448x640 1 reg plate, 10.3ms
# image 18/386 /kaggle/working/datatset/validation/Vehicle registration plate/091c033b2a7df15b.jpg: 480x640 2 reg plates, 9.1ms
# image 19/386 /kaggle/working/datatset/validation/Vehicle registration plate/09453a7c716a9ef3.jpg: 480x640 1 reg plate, 8.6ms
# image 20/386 /kaggle/working/datatset/validation/Vehicle registration plate/0c756c9366a8cb10.jpg: 480x640 1 reg plate, 8.6ms
# image 21/386 /kaggle/working/datatset/validation/Vehicle registration plate/0cacb08195a3e2d7.jpg: 448x640 1 reg plate, 9.3ms
# image 22/386 /kaggle/working/datatset/validation/Vehicle registration plate/0d6ca8553971fefd.jpg: 448x640 1 reg plate, 9.3ms
# image 23/386 /kaggle/working/datatset/validation/Vehicle registration plate/0e50ea14c4fc1353.jpg: 448x640 1 reg plate, 9.8ms
# image 24/386 /kaggle/working/datatset/validation/Vehicle registration plate/0ee91c4938b6e7ee.jpg: 640x480 1 reg plate, 48.3ms
# image 25/386 /kaggle/working/datatset/validation/Vehicle registration plate/0f0596b1c511e071.jpg: 576x640 1 reg plate, 9.6ms
# image 26/386 /kaggle/working/datatset/validation/Vehicle registration plate/0f4bfc46402a9f52.jpg: 640x640 1 reg plate, 9.8ms
# image 27/386 /kaggle/working/datatset/validation/Vehicle registration plate/0fbd1b85fc01d2ae.jpg: 384x640 1 reg plate, 50.6ms
# image 28/386 /kaggle/working/datatset/validation/Vehicle registration plate/1071b237587a698b.jpg: 640x480 1 reg plate, 9.6ms
# image 29/386 /kaggle/working/datatset/validation/Vehicle registration plate/11b155ab5b3331cf.jpg: 384x640 1 reg plate, 9.9ms
# image 30/386 /kaggle/working/datatset/validation/Vehicle registration plate/11f80fda2c38011c.jpg: 448x640 1 reg plate, 10.0ms
# image 31/386 /kaggle/working/datatset/validation/Vehicle registration plate/125622a2508e3b1d.jpg: 416x640 1 reg plate, 47.4ms
# image 32/386 /kaggle/working/datatset/validation/Vehicle registration plate/128a59bca025bed6.jpg: 480x640 1 reg plate, 9.7ms
# image 33/386 /kaggle/working/datatset/validation/Vehicle registration plate/12b7ea40074d3b20.jpg: 480x640 1 reg plate, 9.3ms
# image 34/386 /kaggle/working/datatset/validation/Vehicle registration plate/12d3b6665f7e1cf6.jpg: 640x480 2 reg plates, 9.3ms
# image 35/386 /kaggle/working/datatset/validation/Vehicle registration plate/133921bd26fff729.jpg: 640x416 (no detections), 48.1ms
# image 36/386 /kaggle/working/datatset/validation/Vehicle registration plate/140e8d10ff02e7e7.jpg: 448x640 1 reg plate, 9.4ms
# image 37/386 /kaggle/working/datatset/validation/Vehicle registration plate/1545c73bdecb3e2f.jpg: 352x640 1 reg plate, 48.4ms
# image 38/386 /kaggle/working/datatset/validation/Vehicle registration plate/15a51e29f5ceffd8.jpg: 448x640 1 reg plate, 9.6ms
# image 39/386 /kaggle/working/datatset/validation/Vehicle registration plate/16789af24af158d8.jpg: 640x640 1 reg plate, 9.6ms
# image 40/386 /kaggle/working/datatset/validation/Vehicle registration plate/16c15b29b30148c2.jpg: 576x640 1 reg plate, 9.7ms
# image 41/386 /kaggle/working/datatset/validation/Vehicle registration plate/17585ef2efb5ef9b.jpg: 640x480 1 reg plate, 10.1ms
# image 42/386 /kaggle/working/datatset/validation/Vehicle registration plate/18098dc9ee6aad80.jpg: 448x640 1 reg plate, 9.5ms
# image 43/386 /kaggle/working/datatset/validation/Vehicle registration plate/182268e1f8c6525f.jpg: 448x640 1 reg plate, 10.2ms
# image 44/386 /kaggle/working/datatset/validation/Vehicle registration plate/185d5dfa193c4ced.jpg: 448x640 1 reg plate, 9.1ms
# image 45/386 /kaggle/working/datatset/validation/Vehicle registration plate/185fd6653258d3ed.jpg: 480x640 1 reg plate, 9.5ms
# image 46/386 /kaggle/working/datatset/validation/Vehicle registration plate/19eba8ac64eed194.jpg: 480x640 1 reg plate, 9.2ms
# image 47/386 /kaggle/working/datatset/validation/Vehicle registration plate/19ff847d0cd1c5ec.jpg: 448x640 1 reg plate, 11.1ms
# image 48/386 /kaggle/working/datatset/validation/Vehicle registration plate/1a3e9d87d733ff7f.jpg: 448x640 1 reg plate, 9.0ms
# image 49/386 /kaggle/working/datatset/validation/Vehicle registration plate/1ca1155083156d72.jpg: 448x640 1 reg plate, 9.2ms
# image 50/386 /kaggle/working/datatset/validation/Vehicle registration plate/1db3793d7c84faa1.jpg: 480x640 1 reg plate, 10.0ms
# image 51/386 /kaggle/working/datatset/validation/Vehicle registration plate/1e6e75488d7878aa.jpg: 480x640 1 reg plate, 9.1ms
# image 52/386 /kaggle/working/datatset/validation/Vehicle registration plate/1ead26febde18ce9.jpg: 480x640 1 reg plate, 8.9ms
# image 53/386 /kaggle/working/datatset/validation/Vehicle registration plate/1eb2ebab9cd7adf6.jpg: 480x640 1 reg plate, 8.9ms
# image 54/386 /kaggle/working/datatset/validation/Vehicle registration plate/1edfbe8c28a86caf.jpg: 384x640 1 reg plate, 9.5ms
# image 55/386 /kaggle/working/datatset/validation/Vehicle registration plate/1f0e643b125f00ec.jpg: 448x640 1 reg plate, 9.6ms
# image 56/386 /kaggle/working/datatset/validation/Vehicle registration plate/1f1d5bc31e444cc1.jpg: 448x640 1 reg plate, 9.0ms
# image 57/386 /kaggle/working/datatset/validation/Vehicle registration plate/1f34454c4c073e1b.jpg: 608x640 1 reg plate, 47.1ms
# image 58/386 /kaggle/working/datatset/validation/Vehicle registration plate/228bd52bbe043677.jpg: 480x640 2 reg plates, 9.9ms
# image 59/386 /kaggle/working/datatset/validation/Vehicle registration plate/23c2c79a9febbf3e.jpg: 384x640 1 reg plate, 9.9ms
# image 60/386 /kaggle/working/datatset/validation/Vehicle registration plate/246a0e4264a39433.jpg: 480x640 1 reg plate, 9.4ms
# image 61/386 /kaggle/working/datatset/validation/Vehicle registration plate/25d5c2fbd8b99662.jpg: 384x640 (no detections), 9.7ms
# image 62/386 /kaggle/working/datatset/validation/Vehicle registration plate/26183d88c4f8012f.jpg: 480x640 1 reg plate, 9.4ms
# image 63/386 /kaggle/working/datatset/validation/Vehicle registration plate/26192da5ce2afa62.jpg: 448x640 1 reg plate, 11.2ms
# image 64/386 /kaggle/working/datatset/validation/Vehicle registration plate/2619ec27a314e69c.jpg: 480x640 1 reg plate, 9.2ms
# image 65/386 /kaggle/working/datatset/validation/Vehicle registration plate/2753536137929411.jpg: 512x640 1 reg plate, 9.9ms
# image 66/386 /kaggle/working/datatset/validation/Vehicle registration plate/27798906120ea394.jpg: 480x640 3 reg plates, 10.6ms
# image 67/386 /kaggle/working/datatset/validation/Vehicle registration plate/288a95c01e43cd14.jpg: 480x640 1 reg plate, 9.9ms
# image 68/386 /kaggle/working/datatset/validation/Vehicle registration plate/28bd6c6b1050e055.jpg: 448x640 1 reg plate, 9.6ms
# image 69/386 /kaggle/working/datatset/validation/Vehicle registration plate/28d1fb27a6e42ee7.jpg: 480x640 (no detections), 10.5ms
# image 70/386 /kaggle/working/datatset/validation/Vehicle registration plate/28e26a4eb646c67a.jpg: 384x640 1 reg plate, 10.7ms
# image 71/386 /kaggle/working/datatset/validation/Vehicle registration plate/2956bcbedfc167b6.jpg: 480x640 1 reg plate, 11.6ms
# image 72/386 /kaggle/working/datatset/validation/Vehicle registration plate/299f0363ae21d1c3.jpg: 448x640 1 reg plate, 9.7ms
# image 73/386 /kaggle/working/datatset/validation/Vehicle registration plate/29f7991e696e6e3f.jpg: 448x640 1 reg plate, 9.7ms
# image 74/386 /kaggle/working/datatset/validation/Vehicle registration plate/2a3e44107826e876.jpg: 384x640 1 reg plate, 9.6ms
# image 75/386 /kaggle/working/datatset/validation/Vehicle registration plate/2adddd0b09bb0f17.jpg: 480x640 1 reg plate, 9.4ms
# image 76/386 /kaggle/working/datatset/validation/Vehicle registration plate/2b97f5bf137ee8d1.jpg: 448x640 3 reg plates, 9.3ms
# image 77/386 /kaggle/working/datatset/validation/Vehicle registration plate/2bd26c63ebf598b7.jpg: 448x640 1 reg plate, 8.9ms
# image 78/386 /kaggle/working/datatset/validation/Vehicle registration plate/2c09fab0221652c5.jpg: 480x640 1 reg plate, 10.3ms
# image 79/386 /kaggle/working/datatset/validation/Vehicle registration plate/2d40d6e377c82ec9.jpg: 640x480 1 reg plate, 10.1ms
# image 80/386 /kaggle/working/datatset/validation/Vehicle registration plate/2d6640fb230770fd.jpg: 448x640 2 reg plates, 9.3ms
# image 81/386 /kaggle/working/datatset/validation/Vehicle registration plate/2e8a83cfb1afe7ba.jpg: 480x640 1 reg plate, 9.7ms
# image 82/386 /kaggle/working/datatset/validation/Vehicle registration plate/2e95d7a799e23e11.jpg: 352x640 1 reg plate, 9.6ms
# image 83/386 /kaggle/working/datatset/validation/Vehicle registration plate/2f3887024d298547.jpg: 480x640 1 reg plate, 9.4ms
# image 84/386 /kaggle/working/datatset/validation/Vehicle registration plate/2f90aaa72744452d.jpg: 480x640 2 reg plates, 9.1ms
# image 85/386 /kaggle/working/datatset/validation/Vehicle registration plate/2fe1f00b77a110a0.jpg: 448x640 1 reg plate, 9.9ms
# image 86/386 /kaggle/working/datatset/validation/Vehicle registration plate/302d636c896c263f.jpg: 448x640 1 reg plate, 9.7ms
# image 87/386 /kaggle/working/datatset/validation/Vehicle registration plate/30b6cfb60bf44533.jpg: 640x640 (no detections), 10.1ms
# image 88/386 /kaggle/working/datatset/validation/Vehicle registration plate/315aead7766727b8.jpg: 608x640 1 reg plate, 10.1ms
# image 89/386 /kaggle/working/datatset/validation/Vehicle registration plate/321ffb38656f7311.jpg: 480x640 2 reg plates, 10.3ms
# image 90/386 /kaggle/working/datatset/validation/Vehicle registration plate/3241f09a8964ddfb.jpg: 480x640 2 reg plates, 9.1ms
# image 91/386 /kaggle/working/datatset/validation/Vehicle registration plate/326c3286bcb5b2b0.jpg: 448x640 1 reg plate, 9.5ms
# image 92/386 /kaggle/working/datatset/validation/Vehicle registration plate/334f31e809ec9a77.jpg: 480x640 1 reg plate, 9.4ms
# image 93/386 /kaggle/working/datatset/validation/Vehicle registration plate/33e0333ff031c4fb.jpg: 640x640 1 reg plate, 10.3ms
# image 94/386 /kaggle/working/datatset/validation/Vehicle registration plate/343326e127297379.jpg: 448x640 2 reg plates, 9.6ms
# image 95/386 /kaggle/working/datatset/validation/Vehicle registration plate/35875c388efcddf0.jpg: 480x640 2 reg plates, 9.4ms
# image 96/386 /kaggle/working/datatset/validation/Vehicle registration plate/36d7b8b3cca3b0f5.jpg: 448x640 1 reg plate, 9.1ms
# image 97/386 /kaggle/working/datatset/validation/Vehicle registration plate/37ff77d13a54aac2.jpg: 448x640 1 reg plate, 9.0ms
# image 98/386 /kaggle/working/datatset/validation/Vehicle registration plate/39c193bcc0c00f9e.jpg: 448x640 1 reg plate, 8.9ms
# image 99/386 /kaggle/working/datatset/validation/Vehicle registration plate/3d98e3713783e82d.jpg: 448x640 1 reg plate, 9.9ms
# image 100/386 /kaggle/working/datatset/validation/Vehicle registration plate/3e156de979eb0828.jpg: 480x640 1 reg plate, 10.5ms
# image 101/386 /kaggle/working/datatset/validation/Vehicle registration plate/3e2306f2cf4b2c67.jpg: 544x640 1 reg plate, 46.9ms
# image 102/386 /kaggle/working/datatset/validation/Vehicle registration plate/3ecd5af7c4f11963.jpg: 480x640 1 reg plate, 9.6ms
# image 103/386 /kaggle/working/datatset/validation/Vehicle registration plate/3ed000628c6a0587.jpg: 448x640 1 reg plate, 9.5ms
# image 104/386 /kaggle/working/datatset/validation/Vehicle registration plate/3feecc5809a29627.jpg: 640x640 1 reg plate, 9.9ms
# image 105/386 /kaggle/working/datatset/validation/Vehicle registration plate/4148b2126f0986a4.jpg: 640x640 1 reg plate, 8.9ms
# image 106/386 /kaggle/working/datatset/validation/Vehicle registration plate/415d64bf8cfe82f2.jpg: 448x640 1 reg plate, 10.9ms
# image 107/386 /kaggle/working/datatset/validation/Vehicle registration plate/428a5131c8cff7da.jpg: 640x640 1 reg plate, 9.4ms
# image 108/386 /kaggle/working/datatset/validation/Vehicle registration plate/43339d9cbca470e4.jpg: 480x640 1 reg plate, 9.9ms
# image 109/386 /kaggle/working/datatset/validation/Vehicle registration plate/43b1b0028dd2db8d.jpg: 480x640 1 reg plate, 10.1ms
# image 110/386 /kaggle/working/datatset/validation/Vehicle registration plate/44afab29f5fa0abf.jpg: 480x640 2 reg plates, 9.4ms
# image 111/386 /kaggle/working/datatset/validation/Vehicle registration plate/453a77009b27e253.jpg: 448x640 (no detections), 9.8ms
# image 112/386 /kaggle/working/datatset/validation/Vehicle registration plate/4572990fd64bb6be.jpg: 512x640 2 reg plates, 9.6ms
# image 113/386 /kaggle/working/datatset/validation/Vehicle registration plate/460753acbd6e6dad.jpg: 480x640 2 reg plates, 9.9ms
# image 114/386 /kaggle/working/datatset/validation/Vehicle registration plate/46a7991da6461831.jpg: 448x640 1 reg plate, 9.8ms
# image 115/386 /kaggle/working/datatset/validation/Vehicle registration plate/4793138df3c05610.jpg: 352x640 1 reg plate, 10.9ms
# image 116/386 /kaggle/working/datatset/validation/Vehicle registration plate/485e5f37dd13ffab.jpg: 384x640 2 reg plates, 9.5ms
# image 117/386 /kaggle/working/datatset/validation/Vehicle registration plate/488722909dd9c0ac.jpg: 480x640 1 reg plate, 9.7ms
# image 118/386 /kaggle/working/datatset/validation/Vehicle registration plate/49595029959689b7.jpg: 480x640 1 reg plate, 9.2ms
# image 119/386 /kaggle/working/datatset/validation/Vehicle registration plate/4ac941b9393d00f9.jpg: 480x640 1 reg plate, 8.9ms
# image 120/386 /kaggle/working/datatset/validation/Vehicle registration plate/4b3aba5dfb7a0492.jpg: 480x640 1 reg plate, 9.0ms
# image 121/386 /kaggle/working/datatset/validation/Vehicle registration plate/4c04b488ddc48225.jpg: 384x640 1 reg plate, 10.3ms
# image 122/386 /kaggle/working/datatset/validation/Vehicle registration plate/4cb48c8bf41b70a4.jpg: 480x640 1 reg plate, 9.3ms
# image 123/386 /kaggle/working/datatset/validation/Vehicle registration plate/4df1448703257ff0.jpg: 480x640 1 reg plate, 8.9ms
# image 124/386 /kaggle/working/datatset/validation/Vehicle registration plate/4e2cb95b9c509b10.jpg: 384x640 1 reg plate, 11.3ms
# image 125/386 /kaggle/working/datatset/validation/Vehicle registration plate/4e593c88022ff6b1.jpg: 480x640 2 reg plates, 9.6ms
# image 126/386 /kaggle/working/datatset/validation/Vehicle registration plate/4ee3f0e9a2fb20a9.jpg: 448x640 1 reg plate, 9.6ms
# image 127/386 /kaggle/working/datatset/validation/Vehicle registration plate/4fa24c1abe969cb7.jpg: 448x640 1 reg plate, 8.8ms
# image 128/386 /kaggle/working/datatset/validation/Vehicle registration plate/4ff8bebd6d6a0361.jpg: 480x640 1 reg plate, 9.7ms
# image 129/386 /kaggle/working/datatset/validation/Vehicle registration plate/5021041c726b6ee4.jpg: 480x640 1 reg plate, 9.6ms
# image 130/386 /kaggle/working/datatset/validation/Vehicle registration plate/50631041f74001aa.jpg: 448x640 1 reg plate, 10.5ms
# image 131/386 /kaggle/working/datatset/validation/Vehicle registration plate/508f0a75156e5fd4.jpg: 448x640 1 reg plate, 9.0ms
# image 132/386 /kaggle/working/datatset/validation/Vehicle registration plate/50c37aeaf19acd5b.jpg: 448x640 1 reg plate, 9.2ms
# image 133/386 /kaggle/working/datatset/validation/Vehicle registration plate/5290f4027491d09b.jpg: 480x640 1 reg plate, 9.8ms
# image 134/386 /kaggle/working/datatset/validation/Vehicle registration plate/52bf6b555e578a34.jpg: 448x640 1 reg plate, 9.4ms
# image 135/386 /kaggle/working/datatset/validation/Vehicle registration plate/52ceb1fc30b413e5.jpg: 480x640 1 reg plate, 9.4ms
# image 136/386 /kaggle/working/datatset/validation/Vehicle registration plate/53386dae3cf13cc3.jpg: 480x640 1 reg plate, 9.0ms
# image 137/386 /kaggle/working/datatset/validation/Vehicle registration plate/5373ec295ea62c47.jpg: 448x640 2 reg plates, 9.3ms
# image 138/386 /kaggle/working/datatset/validation/Vehicle registration plate/53925df03b471f5d.jpg: 480x640 (no detections), 9.3ms
# image 139/386 /kaggle/working/datatset/validation/Vehicle registration plate/53ad98b12752ad16.jpg: 480x640 3 reg plates, 8.9ms
# image 140/386 /kaggle/working/datatset/validation/Vehicle registration plate/548a8e997a66a0c4.jpg: 576x640 1 reg plate, 9.2ms
# image 141/386 /kaggle/working/datatset/validation/Vehicle registration plate/548a985825bb991f.jpg: 480x640 (no detections), 9.2ms
# image 142/386 /kaggle/working/datatset/validation/Vehicle registration plate/54bd93e5a4de808a.jpg: 480x640 1 reg plate, 8.8ms
# image 143/386 /kaggle/working/datatset/validation/Vehicle registration plate/54ebca2064066a49.jpg: 448x640 1 reg plate, 10.1ms
# image 144/386 /kaggle/working/datatset/validation/Vehicle registration plate/5581a1b7d2f0f2b4.jpg: 640x640 1 reg plate, 9.7ms
# image 145/386 /kaggle/working/datatset/validation/Vehicle registration plate/5641e6ad7d2600f2.jpg: 480x640 1 reg plate, 9.8ms
# image 146/386 /kaggle/working/datatset/validation/Vehicle registration plate/575d96d014e4fbab.jpg: 480x640 1 reg plate, 9.0ms
# image 147/386 /kaggle/working/datatset/validation/Vehicle registration plate/593e594137f374ab.jpg: 448x640 1 reg plate, 9.4ms
# image 148/386 /kaggle/working/datatset/validation/Vehicle registration plate/59b83c5f8f1dcfa4.jpg: 640x480 1 reg plate, 9.3ms
# image 149/386 /kaggle/working/datatset/validation/Vehicle registration plate/5a122adbb1a776b7.jpg: 480x640 1 reg plate, 9.7ms
# image 150/386 /kaggle/working/datatset/validation/Vehicle registration plate/5a3f94aa35766f31.jpg: 544x640 3 reg plates, 10.2ms
# image 151/386 /kaggle/working/datatset/validation/Vehicle registration plate/5a96f5e1f9be8d42.jpg: 480x640 1 reg plate, 9.3ms
# image 152/386 /kaggle/working/datatset/validation/Vehicle registration plate/5cc19b450a51ee4c.jpg: 480x640 (no detections), 9.0ms
# image 153/386 /kaggle/working/datatset/validation/Vehicle registration plate/5daafbcf76fa6602.jpg: 480x640 1 reg plate, 8.8ms
# image 154/386 /kaggle/working/datatset/validation/Vehicle registration plate/5df8816356fc2b29.jpg: 320x640 1 reg plate, 47.3ms
# image 155/386 /kaggle/working/datatset/validation/Vehicle registration plate/5fb888d79b551331.jpg: 640x640 1 reg plate, 9.2ms
# image 156/386 /kaggle/working/datatset/validation/Vehicle registration plate/5ff91ccfc6f15d04.jpg: 448x640 1 reg plate, 9.3ms
# image 157/386 /kaggle/working/datatset/validation/Vehicle registration plate/61a69ad713142e45.jpg: 480x640 1 reg plate, 9.3ms
# image 158/386 /kaggle/working/datatset/validation/Vehicle registration plate/620bd952592bc0e9.jpg: 480x640 1 reg plate, 9.3ms
# image 159/386 /kaggle/working/datatset/validation/Vehicle registration plate/621837d55c229864.jpg: 480x640 1 reg plate, 9.4ms
# image 160/386 /kaggle/working/datatset/validation/Vehicle registration plate/628a23a43f19c4db.jpg: 384x640 1 reg plate, 9.3ms
# image 161/386 /kaggle/working/datatset/validation/Vehicle registration plate/62bb93bbd270dd9a.jpg: 448x640 1 reg plate, 9.1ms
# image 162/386 /kaggle/working/datatset/validation/Vehicle registration plate/6306fc7f3573eb70.jpg: 448x640 2 reg plates, 8.9ms
# image 163/386 /kaggle/working/datatset/validation/Vehicle registration plate/63d3df798bc8840f.jpg: 640x640 1 reg plate, 9.4ms
# image 164/386 /kaggle/working/datatset/validation/Vehicle registration plate/643c3cc1a4e85db2.jpg: 480x640 1 reg plate, 9.9ms
# image 165/386 /kaggle/working/datatset/validation/Vehicle registration plate/647ff22cf6950211.jpg: 544x640 1 reg plate, 9.3ms
# image 166/386 /kaggle/working/datatset/validation/Vehicle registration plate/64de505bd2bac82b.jpg: 480x640 1 reg plate, 9.3ms
# image 167/386 /kaggle/working/datatset/validation/Vehicle registration plate/6504632e0dc25997.jpg: 480x640 1 reg plate, 8.7ms
# image 168/386 /kaggle/working/datatset/validation/Vehicle registration plate/659dbf4f8c0fd29d.jpg: 480x640 1 reg plate, 9.0ms
# image 169/386 /kaggle/working/datatset/validation/Vehicle registration plate/65e080f9ac466664.jpg: 384x640 3 reg plates, 10.0ms
# image 170/386 /kaggle/working/datatset/validation/Vehicle registration plate/665cac5fd1cc2186.jpg: 448x640 1 reg plate, 11.0ms
# image 171/386 /kaggle/working/datatset/validation/Vehicle registration plate/66771a4870c324f9.jpg: 384x640 2 reg plates, 9.3ms
# image 172/386 /kaggle/working/datatset/validation/Vehicle registration plate/66be6b583048fa94.jpg: 448x640 1 reg plate, 9.2ms
# image 173/386 /kaggle/working/datatset/validation/Vehicle registration plate/67945cf7a6beccdf.jpg: 384x640 1 reg plate, 9.7ms
# image 174/386 /kaggle/working/datatset/validation/Vehicle registration plate/67c834b73882a9f9.jpg: 448x640 2 reg plates, 9.9ms
# image 175/386 /kaggle/working/datatset/validation/Vehicle registration plate/6846c275ded01f85.jpg: 640x640 1 reg plate, 9.3ms
# image 176/386 /kaggle/working/datatset/validation/Vehicle registration plate/693acf98575cbe27.jpg: 480x640 1 reg plate, 9.8ms
# image 177/386 /kaggle/working/datatset/validation/Vehicle registration plate/69450fa183d57a7b.jpg: 384x640 1 reg plate, 9.3ms
# image 178/386 /kaggle/working/datatset/validation/Vehicle registration plate/6a0ef049e5ec4b16.jpg: 448x640 1 reg plate, 9.9ms
# image 179/386 /kaggle/working/datatset/validation/Vehicle registration plate/6aff04e9c32aec0f.jpg: 640x480 1 reg plate, 9.3ms
# image 180/386 /kaggle/working/datatset/validation/Vehicle registration plate/6b113b3edbadfe5d.jpg: 480x640 1 reg plate, 10.0ms
# image 181/386 /kaggle/working/datatset/validation/Vehicle registration plate/6c144e47161867c2.jpg: 384x640 1 reg plate, 9.5ms
# image 182/386 /kaggle/working/datatset/validation/Vehicle registration plate/6e819dc674a74078.jpg: 480x640 1 reg plate, 9.3ms
# image 183/386 /kaggle/working/datatset/validation/Vehicle registration plate/6eb18d1ad17cd174.jpg: 448x640 1 reg plate, 9.5ms
# image 184/386 /kaggle/working/datatset/validation/Vehicle registration plate/70e7b5173fe1e289.jpg: 480x640 1 reg plate, 10.5ms
# image 185/386 /kaggle/working/datatset/validation/Vehicle registration plate/71881a9c0f7f0a86.jpg: 448x640 2 reg plates, 9.4ms
# image 186/386 /kaggle/working/datatset/validation/Vehicle registration plate/71dbb47ebe504abe.jpg: 352x640 1 reg plate, 9.6ms
# image 187/386 /kaggle/working/datatset/validation/Vehicle registration plate/724307be418b2ed2.jpg: 480x640 1 reg plate, 9.4ms
# image 188/386 /kaggle/working/datatset/validation/Vehicle registration plate/7275e72e1996267f.jpg: 512x640 1 reg plate, 9.4ms
# image 189/386 /kaggle/working/datatset/validation/Vehicle registration plate/73467682c5995b65.jpg: 512x640 1 reg plate, 9.1ms
# image 190/386 /kaggle/working/datatset/validation/Vehicle registration plate/747b0f12f54703ee.jpg: 480x640 1 reg plate, 9.4ms
# image 191/386 /kaggle/working/datatset/validation/Vehicle registration plate/749b4451492fc250.jpg: 448x640 1 reg plate, 9.4ms
# image 192/386 /kaggle/working/datatset/validation/Vehicle registration plate/74ee6d1b58ae2e70.jpg: 448x640 1 reg plate, 8.8ms
# image 193/386 /kaggle/working/datatset/validation/Vehicle registration plate/7539902687e8f3a4.jpg: 480x640 (no detections), 9.9ms
# image 194/386 /kaggle/working/datatset/validation/Vehicle registration plate/76e14d05ee8acb6d.jpg: 448x640 1 reg plate, 9.2ms
# image 195/386 /kaggle/working/datatset/validation/Vehicle registration plate/77e716224c85410f.jpg: 480x640 (no detections), 9.2ms
# image 196/386 /kaggle/working/datatset/validation/Vehicle registration plate/791d63b1c3499e4f.jpg: 512x640 1 reg plate, 9.6ms
# image 197/386 /kaggle/working/datatset/validation/Vehicle registration plate/7a1f9520c7ecd5b1.jpg: 544x640 2 reg plates, 9.7ms
# image 198/386 /kaggle/working/datatset/validation/Vehicle registration plate/7b4e86e1c94d65de.jpg: 480x640 (no detections), 9.6ms
# image 199/386 /kaggle/working/datatset/validation/Vehicle registration plate/7bcf6b4ec09f1ea7.jpg: 480x640 1 reg plate, 9.5ms
# image 200/386 /kaggle/working/datatset/validation/Vehicle registration plate/7cbc7ee444622a66.jpg: 640x640 1 reg plate, 9.5ms
# image 201/386 /kaggle/working/datatset/validation/Vehicle registration plate/7f56adf4b9306ac9.jpg: 448x640 1 reg plate, 9.4ms
# image 202/386 /kaggle/working/datatset/validation/Vehicle registration plate/7f9740e95a74f2b9.jpg: 480x640 1 reg plate, 9.2ms
# image 203/386 /kaggle/working/datatset/validation/Vehicle registration plate/7fc0fb6035bc06a6.jpg: 448x640 1 reg plate, 9.2ms
# image 204/386 /kaggle/working/datatset/validation/Vehicle registration plate/80d21c58a71a0751.jpg: 384x640 1 reg plate, 9.4ms
# image 205/386 /kaggle/working/datatset/validation/Vehicle registration plate/80e02a518ffe4cb2.jpg: 480x640 1 reg plate, 9.1ms
# image 206/386 /kaggle/working/datatset/validation/Vehicle registration plate/8256e277c7f47797.jpg: 480x640 (no detections), 8.5ms
# image 207/386 /kaggle/working/datatset/validation/Vehicle registration plate/82b53fe7f9147c96.jpg: 448x640 1 reg plate, 9.5ms
# image 208/386 /kaggle/working/datatset/validation/Vehicle registration plate/844adfe06e003c09.jpg: 480x640 1 reg plate, 11.4ms
# image 209/386 /kaggle/working/datatset/validation/Vehicle registration plate/85b1dafd26aa98df.jpg: 448x640 1 reg plate, 9.9ms
# image 210/386 /kaggle/working/datatset/validation/Vehicle registration plate/85ddb7e0f60156a3.jpg: 448x640 (no detections), 10.9ms
# image 211/386 /kaggle/working/datatset/validation/Vehicle registration plate/85f0b4db3eb512ce.jpg: 448x640 1 reg plate, 9.1ms
# image 212/386 /kaggle/working/datatset/validation/Vehicle registration plate/86c92b0402fec141.jpg: 448x640 1 reg plate, 10.4ms
# image 213/386 /kaggle/working/datatset/validation/Vehicle registration plate/87793700161a7a6b.jpg: 448x640 1 reg plate, 9.6ms
# image 214/386 /kaggle/working/datatset/validation/Vehicle registration plate/87b4f1202cd06440.jpg: 480x640 2 reg plates, 10.4ms
# image 215/386 /kaggle/working/datatset/validation/Vehicle registration plate/88df55ff4e13b90d.jpg: 480x640 (no detections), 9.4ms
# image 216/386 /kaggle/working/datatset/validation/Vehicle registration plate/88fc866f92860d70.jpg: 640x640 1 reg plate, 9.5ms
# image 217/386 /kaggle/working/datatset/validation/Vehicle registration plate/894cacdb385fdb6b.jpg: 480x640 1 reg plate, 11.9ms
# image 218/386 /kaggle/working/datatset/validation/Vehicle registration plate/895d440e05b2a8d8.jpg: 480x640 1 reg plate, 9.8ms
# image 219/386 /kaggle/working/datatset/validation/Vehicle registration plate/8c63cf76166c3bd7.jpg: 512x640 1 reg plate, 9.9ms
# image 220/386 /kaggle/working/datatset/validation/Vehicle registration plate/8cb5553e75d3d311.jpg: 480x640 3 reg plates, 9.6ms
# image 221/386 /kaggle/working/datatset/validation/Vehicle registration plate/8cca720c410ee7f8.jpg: 640x480 1 reg plate, 9.5ms
# image 222/386 /kaggle/working/datatset/validation/Vehicle registration plate/8cdcb833ef1ef049.jpg: 480x640 1 reg plate, 9.9ms
# image 223/386 /kaggle/working/datatset/validation/Vehicle registration plate/8ceed1ec9bc3ac45.jpg: 640x480 1 reg plate, 9.8ms
# image 224/386 /kaggle/working/datatset/validation/Vehicle registration plate/9034927e7438bdd6.jpg: 640x480 2 reg plates, 8.8ms
# image 225/386 /kaggle/working/datatset/validation/Vehicle registration plate/90596bf3313e72e3.jpg: 352x640 2 reg plates, 9.7ms
# image 226/386 /kaggle/working/datatset/validation/Vehicle registration plate/908a3ac555a1a509.jpg: 448x640 1 reg plate, 9.8ms
# image 227/386 /kaggle/working/datatset/validation/Vehicle registration plate/90abd4265adf5a00.jpg: 448x640 2 reg plates, 9.2ms
# image 228/386 /kaggle/working/datatset/validation/Vehicle registration plate/911e694dcc0814bf.jpg: 480x640 2 reg plates, 10.9ms
# image 229/386 /kaggle/working/datatset/validation/Vehicle registration plate/9238f5062ff1dc8d.jpg: 480x640 1 reg plate, 9.2ms
# image 230/386 /kaggle/working/datatset/validation/Vehicle registration plate/9286a99f243b359a.jpg: 512x640 1 reg plate, 10.5ms
# image 231/386 /kaggle/working/datatset/validation/Vehicle registration plate/932eef14e5ee78b2.jpg: 448x640 1 reg plate, 9.6ms
# image 232/386 /kaggle/working/datatset/validation/Vehicle registration plate/934645379fe657e1.jpg: 480x640 1 reg plate, 9.5ms
# image 233/386 /kaggle/working/datatset/validation/Vehicle registration plate/944281d0485869f0.jpg: 448x640 1 reg plate, 9.3ms
# image 234/386 /kaggle/working/datatset/validation/Vehicle registration plate/9498d0aff8f9ff8c.jpg: 384x640 1 reg plate, 10.4ms
# image 235/386 /kaggle/working/datatset/validation/Vehicle registration plate/955a8e4c8ba8116e.jpg: 480x640 1 reg plate, 9.4ms
# image 236/386 /kaggle/working/datatset/validation/Vehicle registration plate/98bcfbc4d3c8abbc.jpg: 480x640 1 reg plate, 9.9ms
# image 237/386 /kaggle/working/datatset/validation/Vehicle registration plate/99732f172ac80128.jpg: 384x640 1 reg plate, 9.5ms
# image 238/386 /kaggle/working/datatset/validation/Vehicle registration plate/9995dfc6e0eae5a1.jpg: 448x640 1 reg plate, 9.6ms
# image 239/386 /kaggle/working/datatset/validation/Vehicle registration plate/99c9c657582f958f.jpg: 448x640 2 reg plates, 9.0ms
# image 240/386 /kaggle/working/datatset/validation/Vehicle registration plate/9a4fe6361597f264.jpg: 448x640 1 reg plate, 9.6ms
# image 241/386 /kaggle/working/datatset/validation/Vehicle registration plate/9a795bbf4e94d630.jpg: 448x640 1 reg plate, 9.0ms
# image 242/386 /kaggle/working/datatset/validation/Vehicle registration plate/9c92cadb0f6237c0.jpg: 448x640 1 reg plate, 8.7ms
# image 243/386 /kaggle/working/datatset/validation/Vehicle registration plate/9ebbaf4d1f8d6e7b.jpg: 352x640 1 reg plate, 9.5ms
# image 244/386 /kaggle/working/datatset/validation/Vehicle registration plate/a21aa7c1d7b93d12.jpg: 480x640 1 reg plate, 9.3ms
# image 245/386 /kaggle/working/datatset/validation/Vehicle registration plate/a3ad91fabd188be3.jpg: 448x640 2 reg plates, 9.4ms
# image 246/386 /kaggle/working/datatset/validation/Vehicle registration plate/a52079c6cc4050cd.jpg: 480x640 1 reg plate, 9.5ms
# image 247/386 /kaggle/working/datatset/validation/Vehicle registration plate/a54e7bb80448f3b0.jpg: 480x640 2 reg plates, 9.8ms
# image 248/386 /kaggle/working/datatset/validation/Vehicle registration plate/a56e82026bb71ad5.jpg: 448x640 1 reg plate, 9.6ms
# image 249/386 /kaggle/working/datatset/validation/Vehicle registration plate/a5d6f8d36672fa64.jpg: 448x640 1 reg plate, 9.1ms
# image 250/386 /kaggle/working/datatset/validation/Vehicle registration plate/a67bc3f5f8650c73.jpg: 640x640 1 reg plate, 9.3ms
# image 251/386 /kaggle/working/datatset/validation/Vehicle registration plate/a6e3b0b73220cd32.jpg: 448x640 1 reg plate, 9.5ms
# image 252/386 /kaggle/working/datatset/validation/Vehicle registration plate/a72a8cda1bb31e34.jpg: 480x640 1 reg plate, 10.2ms
# image 253/386 /kaggle/working/datatset/validation/Vehicle registration plate/a774a6f81fea258b.jpg: 480x640 1 reg plate, 9.1ms
# image 254/386 /kaggle/working/datatset/validation/Vehicle registration plate/a79296fb4a48245e.jpg: 448x640 2 reg plates, 9.7ms
# image 255/386 /kaggle/working/datatset/validation/Vehicle registration plate/a823532e163f5722.jpg: 480x640 1 reg plate, 10.1ms
# image 256/386 /kaggle/working/datatset/validation/Vehicle registration plate/a929dc75c20da7d8.jpg: 640x640 1 reg plate, 9.9ms
# image 257/386 /kaggle/working/datatset/validation/Vehicle registration plate/a9b2a2018f845393.jpg: 480x640 1 reg plate, 9.8ms
# image 258/386 /kaggle/working/datatset/validation/Vehicle registration plate/aac1aaaf824b63dd.jpg: 480x640 2 reg plates, 9.4ms
# image 259/386 /kaggle/working/datatset/validation/Vehicle registration plate/abca9401dcf8f7ba.jpg: 480x640 2 reg plates, 10.9ms
# image 260/386 /kaggle/working/datatset/validation/Vehicle registration plate/aca8821ff0368720.jpg: 480x640 1 reg plate, 9.7ms
# image 261/386 /kaggle/working/datatset/validation/Vehicle registration plate/ad10c7d29f111692.jpg: 480x640 1 reg plate, 9.6ms
# image 262/386 /kaggle/working/datatset/validation/Vehicle registration plate/ae6724423f0d111a.jpg: 512x640 1 reg plate, 9.6ms
# image 263/386 /kaggle/working/datatset/validation/Vehicle registration plate/aefe747315dd79fc.jpg: 480x640 1 reg plate, 9.5ms
# image 264/386 /kaggle/working/datatset/validation/Vehicle registration plate/affd16c51644a893.jpg: 480x640 1 reg plate, 9.0ms
# image 265/386 /kaggle/working/datatset/validation/Vehicle registration plate/b01d46f9911d558b.jpg: 288x640 1 reg plate, 47.2ms
# image 266/386 /kaggle/working/datatset/validation/Vehicle registration plate/b076ad266891d7aa.jpg: 448x640 2 reg plates, 9.6ms
# image 267/386 /kaggle/working/datatset/validation/Vehicle registration plate/b09813a8742277c7.jpg: 512x640 1 reg plate, 9.5ms
# image 268/386 /kaggle/working/datatset/validation/Vehicle registration plate/b101900b26128253.jpg: 480x640 (no detections), 10.1ms
# image 269/386 /kaggle/working/datatset/validation/Vehicle registration plate/b1096bc91a89b0cf.jpg: 448x640 1 reg plate, 9.9ms
# image 270/386 /kaggle/working/datatset/validation/Vehicle registration plate/b15d6c0bdf90226d.jpg: 480x640 1 reg plate, 9.8ms
# image 271/386 /kaggle/working/datatset/validation/Vehicle registration plate/b193070a9c45b5ab.jpg: 480x640 1 reg plate, 8.9ms
# image 272/386 /kaggle/working/datatset/validation/Vehicle registration plate/b1a50a3824887ee2.jpg: 448x640 1 reg plate, 9.4ms
# image 273/386 /kaggle/working/datatset/validation/Vehicle registration plate/b25d7d2cb7abf86b.jpg: 448x640 1 reg plate, 9.1ms
# image 274/386 /kaggle/working/datatset/validation/Vehicle registration plate/b32671b7cc279583.jpg: 640x640 1 reg plate, 10.1ms
# image 275/386 /kaggle/working/datatset/validation/Vehicle registration plate/b3b61da98e22cd4a.jpg: 480x640 1 reg plate, 9.5ms
# image 276/386 /kaggle/working/datatset/validation/Vehicle registration plate/b57fe3aa2ff9577e.jpg: 384x640 1 reg plate, 9.6ms
# image 277/386 /kaggle/working/datatset/validation/Vehicle registration plate/b5e7183b6a5abe6c.jpg: 480x640 1 reg plate, 9.4ms
# image 278/386 /kaggle/working/datatset/validation/Vehicle registration plate/b6580dec5ada277d.jpg: 448x640 1 reg plate, 9.6ms
# image 279/386 /kaggle/working/datatset/validation/Vehicle registration plate/b6e55f97085c3732.jpg: 480x640 1 reg plate, 9.9ms
# image 280/386 /kaggle/working/datatset/validation/Vehicle registration plate/b6ecda23586a6ba5.jpg: 480x640 1 reg plate, 8.9ms
# image 281/386 /kaggle/working/datatset/validation/Vehicle registration plate/b7cdb5c0c99002b7.jpg: 448x640 1 reg plate, 9.5ms
# image 282/386 /kaggle/working/datatset/validation/Vehicle registration plate/b8a3f2ea385e45b3.jpg: 384x640 3 reg plates, 9.3ms
# image 283/386 /kaggle/working/datatset/validation/Vehicle registration plate/b91c3aaba25bf914.jpg: 448x640 1 reg plate, 9.8ms
# image 284/386 /kaggle/working/datatset/validation/Vehicle registration plate/b94993a2d67b455e.jpg: 448x640 1 reg plate, 8.7ms
# image 285/386 /kaggle/working/datatset/validation/Vehicle registration plate/b9f5b9acf1777acf.jpg: 480x640 1 reg plate, 9.2ms
# image 286/386 /kaggle/working/datatset/validation/Vehicle registration plate/bacc80fafc0566c3.jpg: 480x640 1 reg plate, 9.0ms
# image 287/386 /kaggle/working/datatset/validation/Vehicle registration plate/bbcac63e32bd8137.jpg: 448x640 1 reg plate, 9.2ms
# image 288/386 /kaggle/working/datatset/validation/Vehicle registration plate/bd12ea92bcab1afd.jpg: 480x640 1 reg plate, 10.3ms
# image 289/386 /kaggle/working/datatset/validation/Vehicle registration plate/be654a7eabe0e891.jpg: 480x640 1 reg plate, 8.9ms
# image 290/386 /kaggle/working/datatset/validation/Vehicle registration plate/be9fd0014b5a4f2a.jpg: 448x640 1 reg plate, 9.4ms
# image 291/386 /kaggle/working/datatset/validation/Vehicle registration plate/bf0aac0878b0a3d2.jpg: 512x640 1 reg plate, 9.2ms
# image 292/386 /kaggle/working/datatset/validation/Vehicle registration plate/bf2f25f3ed9ff4d5.jpg: 448x640 1 reg plate, 9.3ms
# image 293/386 /kaggle/working/datatset/validation/Vehicle registration plate/c1d8b110186e095a.jpg: 480x640 1 reg plate, 10.8ms
# image 294/386 /kaggle/working/datatset/validation/Vehicle registration plate/c274e026ac907eb9.jpg: 480x640 1 reg plate, 15.9ms
# image 295/386 /kaggle/working/datatset/validation/Vehicle registration plate/c50d184afad1a9dc.jpg: 480x640 (no detections), 10.6ms
# image 296/386 /kaggle/working/datatset/validation/Vehicle registration plate/c650ff8d3e8e75b3.jpg: 416x640 2 reg plates, 10.0ms
# image 297/386 /kaggle/working/datatset/validation/Vehicle registration plate/c7b1e6f7c38fa1a0.jpg: 480x640 1 reg plate, 9.7ms
# image 298/386 /kaggle/working/datatset/validation/Vehicle registration plate/c7df5232291486a3.jpg: 640x640 1 reg plate, 9.3ms
# image 299/386 /kaggle/working/datatset/validation/Vehicle registration plate/c91ee912164d8ecb.jpg: 480x640 1 reg plate, 9.1ms
# image 300/386 /kaggle/working/datatset/validation/Vehicle registration plate/cb4b754537798d23.jpg: 448x640 2 reg plates, 9.2ms
# image 301/386 /kaggle/working/datatset/validation/Vehicle registration plate/cb8c75fc1c7ccf73.jpg: 640x640 1 reg plate, 9.3ms
# image 302/386 /kaggle/working/datatset/validation/Vehicle registration plate/ccc1a2d44a290368.jpg: 448x640 1 reg plate, 9.6ms
# image 303/386 /kaggle/working/datatset/validation/Vehicle registration plate/cdb1e8621d1c624e.jpg: 448x640 1 reg plate, 8.8ms
# image 304/386 /kaggle/working/datatset/validation/Vehicle registration plate/ce97f7bc90e97109.jpg: 448x640 2 reg plates, 9.2ms
# image 305/386 /kaggle/working/datatset/validation/Vehicle registration plate/d027c6e32db60e3c.jpg: 480x640 1 reg plate, 9.9ms
# image 306/386 /kaggle/working/datatset/validation/Vehicle registration plate/d27e094e98374ff8.jpg: 448x640 1 reg plate, 9.4ms
# image 307/386 /kaggle/working/datatset/validation/Vehicle registration plate/d28d71c2690c16ed.jpg: 480x640 2 reg plates, 9.4ms
# image 308/386 /kaggle/working/datatset/validation/Vehicle registration plate/d2fe2b47668e9d8e.jpg: 480x640 1 reg plate, 8.6ms
# image 309/386 /kaggle/working/datatset/validation/Vehicle registration plate/d3729058c6a4186e.jpg: 480x640 1 reg plate, 8.6ms
# image 310/386 /kaggle/working/datatset/validation/Vehicle registration plate/d44c0b2252bf8a92.jpg: 480x640 1 reg plate, 9.3ms
# image 311/386 /kaggle/working/datatset/validation/Vehicle registration plate/d5058059dc0ce0ad.jpg: 480x640 2 reg plates, 9.3ms
# image 312/386 /kaggle/working/datatset/validation/Vehicle registration plate/d53a3bc813477685.jpg: 384x640 1 reg plate, 9.9ms
# image 313/386 /kaggle/working/datatset/validation/Vehicle registration plate/d565d93637d4e76d.jpg: 448x640 1 reg plate, 9.5ms
# image 314/386 /kaggle/working/datatset/validation/Vehicle registration plate/d59b7a0ff294e3be.jpg: 576x640 1 reg plate, 9.6ms
# image 315/386 /kaggle/working/datatset/validation/Vehicle registration plate/d5f4069e6734ac06.jpg: 480x640 1 reg plate, 9.5ms
# image 316/386 /kaggle/working/datatset/validation/Vehicle registration plate/d648b2ae1abc09f3.jpg: 544x640 2 reg plates, 9.8ms
# image 317/386 /kaggle/working/datatset/validation/Vehicle registration plate/d6c5271e96ec1a61.jpg: 640x480 (no detections), 9.9ms
# image 318/386 /kaggle/working/datatset/validation/Vehicle registration plate/d7b71c9fd144d58d.jpg: 640x640 1 reg plate, 10.2ms
# image 319/386 /kaggle/working/datatset/validation/Vehicle registration plate/d7d49b1a3706f3eb.jpg: 448x640 1 reg plate, 9.6ms
# image 320/386 /kaggle/working/datatset/validation/Vehicle registration plate/d830c3573e57bfc0.jpg: 480x640 1 reg plate, 9.8ms
# image 321/386 /kaggle/working/datatset/validation/Vehicle registration plate/d8cc6d566d01054b.jpg: 640x640 1 reg plate, 10.3ms
# image 322/386 /kaggle/working/datatset/validation/Vehicle registration plate/d8daed582e6cce2d.jpg: 480x640 1 reg plate, 9.5ms
# image 323/386 /kaggle/working/datatset/validation/Vehicle registration plate/d8f6c135ec5486ff.jpg: 448x640 1 reg plate, 10.2ms
# image 324/386 /kaggle/working/datatset/validation/Vehicle registration plate/d9fa2abf3719a4bd.jpg: 480x640 1 reg plate, 10.2ms
# image 325/386 /kaggle/working/datatset/validation/Vehicle registration plate/da1352ab6054a2e4.jpg: 480x640 1 reg plate, 9.0ms
# image 326/386 /kaggle/working/datatset/validation/Vehicle registration plate/da8186b39f042cdf.jpg: 480x640 1 reg plate, 9.6ms
# image 327/386 /kaggle/working/datatset/validation/Vehicle registration plate/daac3a6c64a79bea.jpg: 640x512 1 reg plate, 46.8ms
# image 328/386 /kaggle/working/datatset/validation/Vehicle registration plate/de2b5afb7eda96cf.jpg: 448x640 1 reg plate, 10.7ms
# image 329/386 /kaggle/working/datatset/validation/Vehicle registration plate/dec4608715b2d28d.jpg: 384x640 1 reg plate, 9.8ms
# image 330/386 /kaggle/working/datatset/validation/Vehicle registration plate/defd8f4b30b3e1e1.jpg: 480x640 1 reg plate, 9.4ms
# image 331/386 /kaggle/working/datatset/validation/Vehicle registration plate/e08424f3cd5f6dac.jpg: 480x640 1 reg plate, 8.9ms
# image 332/386 /kaggle/working/datatset/validation/Vehicle registration plate/e1120bfe48f85c1b.jpg: 576x640 1 reg plate, 9.6ms
# image 333/386 /kaggle/working/datatset/validation/Vehicle registration plate/e1925cd0ae28fbd9.jpg: 416x640 1 reg plate, 9.4ms
# image 334/386 /kaggle/working/datatset/validation/Vehicle registration plate/e2427db217e5c3db.jpg: 448x640 1 reg plate, 10.1ms
# image 335/386 /kaggle/working/datatset/validation/Vehicle registration plate/e40cafe0f0d3a550.jpg: 480x640 2 reg plates, 9.2ms
# image 336/386 /kaggle/working/datatset/validation/Vehicle registration plate/e4d600a63db8bf3a.jpg: 640x640 1 reg plate, 9.9ms
# image 337/386 /kaggle/working/datatset/validation/Vehicle registration plate/e52d4f347b2cf90f.jpg: 480x640 1 reg plate, 9.4ms
# image 338/386 /kaggle/working/datatset/validation/Vehicle registration plate/e57d38ae6a921518.jpg: 480x640 1 reg plate, 8.9ms
# image 339/386 /kaggle/working/datatset/validation/Vehicle registration plate/e5edf93b7c9f5edb.jpg: 480x640 1 reg plate, 8.8ms
# image 340/386 /kaggle/working/datatset/validation/Vehicle registration plate/e6299b9e04680adb.jpg: 480x640 2 reg plates, 9.6ms
# image 341/386 /kaggle/working/datatset/validation/Vehicle registration plate/e742e284c7c9da96.jpg: 480x640 1 reg plate, 9.4ms
# image 342/386 /kaggle/working/datatset/validation/Vehicle registration plate/e79f6777f2fc08b2.jpg: 448x640 1 reg plate, 10.0ms
# image 343/386 /kaggle/working/datatset/validation/Vehicle registration plate/e82f13b4a2fe69f3.jpg: 480x640 1 reg plate, 9.8ms
# image 344/386 /kaggle/working/datatset/validation/Vehicle registration plate/e8b36c888a75d742.jpg: 480x640 (no detections), 9.6ms
# image 345/386 /kaggle/working/datatset/validation/Vehicle registration plate/e9561d7c16db565f.jpg: 448x640 1 reg plate, 10.0ms
# image 346/386 /kaggle/working/datatset/validation/Vehicle registration plate/e9cd346a4a84d594.jpg: 512x640 1 reg plate, 11.5ms
# image 347/386 /kaggle/working/datatset/validation/Vehicle registration plate/e9fdd0a41cb61da6.jpg: 480x640 1 reg plate, 9.5ms
# image 348/386 /kaggle/working/datatset/validation/Vehicle registration plate/ea02d99ba51372ee.jpg: 480x640 2 reg plates, 8.9ms
# image 349/386 /kaggle/working/datatset/validation/Vehicle registration plate/ebaefbcb87bfa8a1.jpg: 448x640 1 reg plate, 9.6ms
# image 350/386 /kaggle/working/datatset/validation/Vehicle registration plate/ec8a36f7874c0c34.jpg: 480x640 1 reg plate, 9.4ms
# image 351/386 /kaggle/working/datatset/validation/Vehicle registration plate/ed7d99098d4af8e6.jpg: 480x640 1 reg plate, 10.3ms
# image 352/386 /kaggle/working/datatset/validation/Vehicle registration plate/edecf3a6d569b7c9.jpg: 640x448 1 reg plate, 47.5ms
# image 353/386 /kaggle/working/datatset/validation/Vehicle registration plate/ee047c8ca2cca8a2.jpg: 480x640 1 reg plate, 9.4ms
# image 354/386 /kaggle/working/datatset/validation/Vehicle registration plate/ef1bd7b718a3f6e8.jpg: 480x640 1 reg plate, 8.9ms
# image 355/386 /kaggle/working/datatset/validation/Vehicle registration plate/efde2a25c1c9c924.jpg: 448x640 1 reg plate, 9.4ms
# image 356/386 /kaggle/working/datatset/validation/Vehicle registration plate/f0c7057612710f21.jpg: 384x640 1 reg plate, 9.8ms
# image 357/386 /kaggle/working/datatset/validation/Vehicle registration plate/f1131b93a33cefb9.jpg: 448x640 1 reg plate, 9.9ms
# image 358/386 /kaggle/working/datatset/validation/Vehicle registration plate/f194eaf4f3d1d835.jpg: 480x640 1 reg plate, 9.5ms
# image 359/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3814f4a6121838d.jpg: 320x640 1 reg plate, 9.6ms
# image 360/386 /kaggle/working/datatset/validation/Vehicle registration plate/f38265abb22a00e4.jpg: 448x640 2 reg plates, 10.8ms
# image 361/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3bd3adea149193b.jpg: 448x640 1 reg plate, 8.8ms
# image 362/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3c9af100984744f.jpg: 480x640 2 reg plates, 9.3ms
# image 363/386 /kaggle/working/datatset/validation/Vehicle registration plate/f3d472955c13cae0.jpg: 512x640 (no detections), 9.8ms
# image 364/386 /kaggle/working/datatset/validation/Vehicle registration plate/f5128e7a123b4fa8.jpg: 448x640 1 reg plate, 9.7ms
# image 365/386 /kaggle/working/datatset/validation/Vehicle registration plate/f53243c2bb551b8a.jpg: 448x640 (no detections), 9.3ms
# image 366/386 /kaggle/working/datatset/validation/Vehicle registration plate/f5c2a80a21ddb78c.jpg: 448x640 1 reg plate, 8.7ms
# image 367/386 /kaggle/working/datatset/validation/Vehicle registration plate/f5d1729aa333b284.jpg: 480x640 2 reg plates, 9.3ms
# image 368/386 /kaggle/working/datatset/validation/Vehicle registration plate/f6256bceaf66693f.jpg: 480x640 1 reg plate, 8.7ms
# image 369/386 /kaggle/working/datatset/validation/Vehicle registration plate/f700c5b69c973db6.jpg: 448x640 1 reg plate, 10.2ms
# image 370/386 /kaggle/working/datatset/validation/Vehicle registration plate/f73b754cdb1ab677.jpg: 448x640 1 reg plate, 8.7ms
# image 371/386 /kaggle/working/datatset/validation/Vehicle registration plate/f83d18919353c483.jpg: 448x640 1 reg plate, 8.6ms
# image 372/386 /kaggle/working/datatset/validation/Vehicle registration plate/f9170e8c13a99991.jpg: 544x640 1 reg plate, 10.2ms
# image 373/386 /kaggle/working/datatset/validation/Vehicle registration plate/f9f539977bfea25e.jpg: 448x640 1 reg plate, 9.7ms
# image 374/386 /kaggle/working/datatset/validation/Vehicle registration plate/fa897478280a2758.jpg: 480x640 1 reg plate, 9.3ms
# image 375/386 /kaggle/working/datatset/validation/Vehicle registration plate/fa9147596edc058f.jpg: 448x640 1 reg plate, 9.6ms
# image 376/386 /kaggle/working/datatset/validation/Vehicle registration plate/fb4e60b5cee8b88e.jpg: 640x416 2 reg plates, 9.3ms
# image 377/386 /kaggle/working/datatset/validation/Vehicle registration plate/fb55b73f241bf50a.jpg: 448x640 1 reg plate, 10.2ms
# image 378/386 /kaggle/working/datatset/validation/Vehicle registration plate/fc0a607ba5f38505.jpg: 448x640 1 reg plate, 8.7ms
# image 379/386 /kaggle/working/datatset/validation/Vehicle registration plate/fc0f46431cb1dbe9.jpg: 416x640 1 reg plate, 9.4ms
# image 380/386 /kaggle/working/datatset/validation/Vehicle registration plate/fd07d2db70cf53d5.jpg: 480x640 1 reg plate, 9.3ms
# image 381/386 /kaggle/working/datatset/validation/Vehicle registration plate/fdd963edc28bf163.jpg: 480x640 1 reg plate, 8.9ms
# image 382/386 /kaggle/working/datatset/validation/Vehicle registration plate/fe6139d150a3e2a8.jpg: 640x640 2 reg plates, 10.1ms
# image 383/386 /kaggle/working/datatset/validation/Vehicle registration plate/feaf383fc5de383f.jpg: 480x640 1 reg plate, 10.1ms
# image 384/386 /kaggle/working/datatset/validation/Vehicle registration plate/fed5c0275ff3a440.jpg: 448x640 2 reg plates, 9.4ms
# image 385/386 /kaggle/working/datatset/validation/Vehicle registration plate/ff69d090c735eccb.jpg: 480x640 1 reg plate, 9.5ms
# image 386/386 /kaggle/working/datatset/validation/Vehicle registration plate/ff85b09876d61631.jpg: 640x544 1 reg plate, 47.8ms
# Speed: 2.1ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode= val model='/kaggle/working/runs/detect/train/weights/best.pt' source= '/kaggle/working/datatset/validation/Vehicle registration plate' data='data.yaml' save_json=True
# Out:
# Ultralytics 8.3.5 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /kaggle/working/datatset/validation/Vehicle registration plate.cac
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        386        512      0.923      0.859      0.917      0.682
# Speed: 0.5ms preprocess, 4.0ms inference, 0.0ms loss, 1.4ms postprocess per image
# Saving runs/detect/val/predictions.json...
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# #  <font style="color:green">3. Inference [15 Points]</font>
#
# **You have to make predictions from your trained model on three images from the validation dataset.**
#
# The plotted images should be similar to the following:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-p1.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-p2.png'>
#
#
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/04/c3-w10-p3.png'>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Assuming your predicted images are in the following directory
image_dir = "/kaggle/working/runs/detect/predict" 

# List of image file names (replace with your actual image names)
image_files = ["003a5aaf6d17c917.jpg", "fa9147596edc058f.jpg", "ff85b09876d61631.jpg"]

# Create a figure and axes
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Iterate through the images and display them
for i, file in enumerate(image_files):
    image_path = os.path.join(image_dir, file)
    img = mpimg.imread(image_path)
    axes[i].imshow(img)
    axes[i].axis('off')  # Hide axes
    axes[i].set_title(f"Image {i+1}")

# Show the plot
plt.show()

# %% [markdown]
# #  <font style="color:green">4. COCO Detection Evaluation [25 Points]</font>
#
# **You have to evaluate your detection model on COCO detection evaluation metric.**
#
# For your reference here is the coco evaluation metric chart:
#
#
# ---
#
# <img src="https://www.learnopencv.com/wp-content/uploads/2020/03/c3-w9-coco_metric.png">
#
# ---
#
# #### <font style="color:red">The expected `AP` (primary challenge metric) is more than `0.5`.</font>
#
# **The expected output should look similar to the following:**
#
# ```
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.886
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.629
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.256
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.627
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.722
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
# ```

# %%
# !pip install pycocotools
# Out:
# Collecting pycocotools
#   Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 6.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.8

# %%
from pycocotools.cocoeval import COCOeval
from pycocotools.coco import COCO

# %%
import os
import json
from PIL import Image

createCocoLabelFile = True   # Do it only once
if createCocoLabelFile:
    # Paths to the images and labels folders
    images_path = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate'
    labels_path = '/kaggle/input/object-dectection-num-plate/Dataset/validation/Vehicle registration plate/Label'  # Labels in special format

    # Initialize the COCO dataset structure
    coco_format = {
        "info": {
            "description": "Vehicle Registration Plates Dataset",
            "version": "1.0",
            "year": 2024,
            "contributor": "",
            "date_created": "2024-08-24"
        },
        "licenses": [],
        "images": [],
        "annotations": [],
        "categories": [
            {
                "id": 1,
                "name": "Vehicle registration plate",
                "supercategory": "object"
            }
        ]
    }

    # Function to create the COCO annotations from bounding box information
    def create_coco_annotation(ann_id, image_id, bbox, category_id=1):
        x_min, y_min, x_max, y_max = bbox
        width = x_max - x_min
        height = y_max - y_min
        area = width * height

        return {
            "id": ann_id,
            "image_id": image_id,
            "category_id": category_id,
            "bbox": [x_min, y_min, width, height],
            "area": area,
            "segmentation": [],
            "iscrowd": 0
        }

    # Process each image and its corresponding label
    image_id = 0
    ann_id = 0
    for image_filename in os.listdir(images_path):
        if image_filename.endswith(('.jpg', '.jpeg', '.png')):
            print(image_filename)
            image_id += 1

            # Read image to get dimensions
            image_path = os.path.join(images_path, image_filename)
            img = Image.open(image_path)
            width, height = img.size

            # Append image info to the COCO structure
            coco_format["images"].append({
                "id": image_id,
                "file_name": image_filename,
                "width": width,
                "height": height
            })

            # Get corresponding label file
            label_filename = os.path.splitext(image_filename)[0] + '.txt'
            label_path = os.path.join(labels_path, label_filename)

            # Check if the label file exists
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    for line in f:
                        parts = line.strip().split()
                        if len(parts) == 7 and parts[0] == 'Vehicle':
                            # Convert bounding box coordinates to float
                            bbox = list(map(float, parts[3:]))
                            annotation = create_coco_annotation(ann_id, image_id, bbox)
                            coco_format["annotations"].append(annotation)
                            ann_id += 1

    # Save the COCO-format JSON to a file
    with open('/kaggle/working/coco_ground_truth.json', 'w') as json_file:
        json.dump(coco_format, json_file, indent=4)

        print("COCO ground truth JSON file created successfully.")
# Out:
# 6504632e0dc25997.jpg
# 485e5f37dd13ffab.jpg
# a67bc3f5f8650c73.jpg
# 64de505bd2bac82b.jpg
# e57d38ae6a921518.jpg
# ea02d99ba51372ee.jpg
# 246a0e4264a39433.jpg
# a6e3b0b73220cd32.jpg
# fa9147596edc058f.jpg
# 0170ea8e1a33375a.jpg
# bbcac63e32bd8137.jpg
# cb8c75fc1c7ccf73.jpg
# e4d600a63db8bf3a.jpg
# cb4b754537798d23.jpg
# 87b4f1202cd06440.jpg
# 27798906120ea394.jpg
# 4fa24c1abe969cb7.jpg
# 12d3b6665f7e1cf6.jpg
# 19ff847d0cd1c5ec.jpg
# 932eef14e5ee78b2.jpg
# 9c92cadb0f6237c0.jpg
# f6256bceaf66693f.jpg
# 54bd93e5a4de808a.jpg
# 5a122adbb1a776b7.jpg
# 18098dc9ee6aad80.jpg
# 2adddd0b09bb0f17.jpg
# 66be6b583048fa94.jpg
# ae6724423f0d111a.jpg
# 9a795bbf4e94d630.jpg
# 8cdcb833ef1ef049.jpg
# 6a0ef049e5ec4b16.jpg
# a9b2a2018f845393.jpg
# 26183d88c4f8012f.jpg
# 0c756c9366a8cb10.jpg
# COCO ground truth JSON file created successfully.

# %%
def load_coco_image_mapping(gt_annotations_path):
    # Load the COCO ground truth annotations and create a mapping from filenames to image IDs.
    coco_gt = COCO(gt_annotations_path)
    img_filename_to_id = {img['file_name']: img['id'] for img in coco_gt.loadImgs(coco_gt.getImgIds())}
    return img_filename_to_id

def convert_yolo_to_coco(yolo_json_path, img_filename_to_id_map):
    # Convert YOLO predictions to COCO format and replace the image filename with the corresponding image ID.
    with open(yolo_json_path, 'r') as f:
        yolo_predictions = json.load(f)

    coco_predictions = []
    for pred in yolo_predictions:
        img_filename  = str(pred['image_id']) + '.jpg' # directly using image_id as the filename
        if img_filename in img_filename_to_id_map:
            
            img_id = img_filename_to_id_map[img_filename]
            category_id = pred['category_id']+1
            x_min, y_min, width, height = pred['bbox']
        

            coco_pred = {
                "image_id": img_id,
                "category_id": category_id,  # COCO category IDs start at 1, not 0
                "bbox": [x_min, y_min, width, height],
                "score": pred['score']
            }
            coco_predictions.append(coco_pred)

    return coco_predictions

def compute_coco_metrics(gt_annotations_path, pred_annotations):
    # Compute COCO metrics based on ground truth and prediction annotations.
    
    # Load ground truth in COCO format
    coco_gt = COCO(gt_annotations_path)
    
    # Convert predictions to COCO format
    coco_dt = coco_gt.loadRes(pred_annotations)
    
    # Initialize COCO evaluation
    coco_eval = COCOeval(coco_gt, coco_dt, 'bbox')
    
    # Run evaluation
    coco_eval.evaluate()
    coco_eval.accumulate()
    coco_eval.summarize()

    # Extract metrics
    metrics = [
        coco_eval.stats[0],  # AP
        coco_eval.stats[1],  # AP50
        coco_eval.stats[2],  # AP75
        coco_eval.stats[3],  # APs
        coco_eval.stats[4],  # APm
        coco_eval.stats[5],  # APl
        coco_eval.stats[6],  # AR1
        coco_eval.stats[7],  # AR10
        coco_eval.stats[8],  # AR100
        coco_eval.stats[9],  # ARs
        coco_eval.stats[10], # ARm
        coco_eval.stats[11]  # ARl
    ]
    
    return metrics

# Paths to the COCO ground truth annotations and YOLO predictions JSON files
gt_annotations_path = '/kaggle/working/coco_ground_truth.json'  # Created in CreateCocoGtFile.py
yolo_json_path = '/kaggle/working/runs/detect/val/predictions.json'

# Load mapping from image filenames to COCO Image IDs
img_filename_to_id_map = load_coco_image_mapping(gt_annotations_path)

# Convert YOLO predictions to COCO format
coco_predictions = convert_yolo_to_coco(yolo_json_path, img_filename_to_id_map)

# Save the converted predictions to a new JSON file
pred_annotations_path = 'converted_yolo_predictions.json'
with open(pred_annotations_path, 'w') as f:
    json.dump(coco_predictions, f)

# Check if the JSON file is empty or improperly formatted
if not coco_predictions:
    print("No predictions available for evaluation.")
else:
    print("YOLO predictions are ready for evaluation.")
    # Compute COCO metrics
    metrics = compute_coco_metrics(gt_annotations_path, pred_annotations_path)
    print("COCO Metrics:", metrics)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# YOLO predictions are ready for evaluation.
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.45s).
# Accumulating evaluation results...
# DONE (t=0.11s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.910
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.801
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.796
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.472
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.813
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.845
# COCO Metrics: [0.6710575400833589, 0.9095128113722087, 0.8007368050482824, 0.3376046941597078, 0.7354509923152637, 0.7964158952591477, 0.608984375, 0.7373046875, 0.742578125, 0.4715447154471545, 0.8132352941176471, 0.8448648648648648]

# %% [markdown]
# # <font style="color:green">5. Run Inference on a Video [15 Points]</font>
#
# #### [Download the Input Video](https://www.dropbox.com/s/g88o4dx18zpgn8k/projet3-input-video.mp4?dl=1)
#
# **You have to run inference on a video.**
#
# You can download the video from [here](https://www.dropbox.com/s/g88o4dx18zpgn8k/projet3-input-video.mp4?dl=1).
#
# #### <font style="color:red">Upload the output video on youtube and share the link. Do not upload the video in the lab.</font>

# %%
https://youtu.be/8MEb1RHeghA

# %%
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("18HWHCevFdU", width=640, height=360)
display(video)

# %% [markdown]
# **Your output video should have a bounding box around the vehicle registration plate.**

# %%
video = YouTubeVideo("5SgCuee7AMs", width=640, height=360)
display(video)

# %% [markdown]
# **You can use the following sample code to read and write a video.**

# %%
from ultralytics import YOLO


model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")  # load a custom model

# Predict with the model
results = model.predict("/kaggle/input/input-video/projet3-input-video.mp4", conf=0.5, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 54.6ms
# video 1/1 (frame 2/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.9ms
# video 1/1 (frame 3/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 4/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 5/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 6/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 7/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 8/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 9/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 10/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 11/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 12/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 13/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (frame 14/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 15/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 16/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (frame 17/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 18/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 12.0ms
# video 1/1 (frame 19/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 20/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 21/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (frame 22/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.4ms
# video 1/1 (frame 23/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 11.1ms
# video 1/1 (frame 24/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 25/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.4ms
# video 1/1 (frame 26/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 27/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.3ms
# video 1/1 (frame 28/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 29/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 8.9ms
# video 1/1 (frame 30/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 8.9ms
# video 1/1 (frame 31/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 8.9ms
# video 1/1 (frame 32/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.2ms
# video 1/1 (frame 33/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 34/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.0ms
# video 1/1 (frame 35/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.0ms
# video 1/1 (frame 36/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.0ms
# video 1/1 (frame 37/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 38/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.4ms
# video 1/1 (frame 39/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 40/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 41/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.3ms
# video 1/1 (frame 42/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 43/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.0ms
# video 1/1 (frame 44/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.3ms
# video 1/1 (frame 45/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.7ms
# video 1/1 (frame 46/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.5ms
# video 1/1 (frame 47/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 12.5ms
# video 1/1 (frame 48/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.4ms
# video 1/1 (frame 49/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.3ms
# video 1/1 (frame 50/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.9ms
# video 1/1 (frame 51/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.3ms
# video 1/1 (frame 52/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 8.9ms
# video 1/1 (frame 53/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.3ms
# video 1/1 (frame 54/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 55/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.0ms
# video 1/1 (frame 56/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.7ms
# video 1/1 (frame 57/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 12.3ms
# video 1/1 (frame 58/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 11.9ms
# video 1/1 (frame 59/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.3ms
# video 1/1 (frame 60/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.5ms
# video 1/1 (frame 61/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.7ms
# video 1/1 (frame 62/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 63/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 64/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 65/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 11.0ms
# video 1/1 (frame 66/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.0ms
# video 1/1 (frame 67/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.2ms
# video 1/1 (frame 68/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 69/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.6ms
# video 1/1 (frame 70/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 12.2ms
# video 1/1 (frame 71/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.8ms
# video 1/1 (frame 72/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.8ms
# video 1/1 (frame 73/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 74/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 75/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 76/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.2ms
# video 1/1 (frame 77/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.0ms
# video 1/1 (frame 78/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 79/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 80/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 81/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 8.9ms
# video 1/1 (frame 82/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.2ms
# video 1/1 (frame 83/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 84/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 85/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 86/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 11.8ms
# video 1/1 (frame 87/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 88/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 89/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 90/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 91/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 92/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (frame 93/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 94/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 95/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 96/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 97/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.2ms
# video 1/1 (frame 98/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 99/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 100/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 101/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 102/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.4ms
# video 1/1 (frame 103/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 104/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 105/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.8ms
# video 1/1 (frame 106/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 107/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.2ms
# video 1/1 (frame 108/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 109/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 10.2ms
# video 1/1 (frame 110/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 8.9ms
# video 1/1 (frame 111/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.0ms
# video 1/1 (frame 112/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.1ms
# video 1/1 (frame 113/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.5ms
# video 1/1 (frame 114/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 13.9ms
# video 1/1 (frame 115/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.2ms
# video 1/1 (frame 116/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.1ms
# video 1/1 (frame 117/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.5ms
# video 1/1 (frame 118/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 119/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.6ms
# video 1/1 (frame 120/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 14.2ms
# video 1/1 (frame 121/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 11.6ms
# video 1/1 (frame 122/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.5ms
# video 1/1 (frame 123/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.2ms
# video 1/1 (frame 124/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.0ms
# video 1/1 (frame 125/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.7ms
# video 1/1 (frame 126/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.6ms
# video 1/1 (frame 127/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 10.7ms
# video 1/1 (frame 128/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 1 reg plate, 9.3ms
# video 1/1 (frame 129/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 2 reg plates, 9.4ms
# video 1/1 (frame 130/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 2 reg plates, 9.2ms
# video 1/1 (frame 131/131) /kaggle/input/input-video/projet3-input-video.mp4: 384x640 (no detections), 9.7ms
# Speed: 1.6ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
def video_read_write(video_path):
    """
    Read video frames one-by-one, flip it, and write in the other video.
    video_path (str): path/to/video
    """
    video = cv2.VideoCapture(video_path)
    
    # Check if camera opened successfully
    if not video.isOpened(): 
        print("Error opening video file")
        return
    
    # create video writer
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frames_per_second = video.get(cv2.CAP_PROP_FPS)
    num_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    
    output_fname = '{}_out.mp4'.format(os.path.splitext(video_path)[0])
    
    output_file = cv2.VideoWriter(
        filename=output_fname,
        # some installation of opencv may not support x264 (due to its license),
        # you can try other format (e.g. MPEG)
        fourcc = cv2.VideoWriter_fourcc(*'mpeg'),
        
        fps=float(frames_per_second),
        frameSize=(width, height),
        isColor=True,
    )
    
        
    i = 0
    while video.isOpened():
        ret, frame = video.read()
        if ret:
            
            output_file.write(frame[:, ::1, :])
#             cv2.imwrite('anpd_out/frame_{}.png'.format(str(i).zfill(3)), frame[:, ::-1, :])
            i += 1
        else:
            break
        
    video.release()
    output_file.release()
    
    return

# %%
video_read_write('/kaggle/working/runs/detect/predict2/projet3-input-video.avi')
# Out:
# OpenCV: FFMPEG: tag 0x6765706d/'mpeg' is not supported with codec id 2 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
